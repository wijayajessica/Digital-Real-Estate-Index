# %%
from collections import Counter
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
plt.rcParams.update({'font.size': 22})

# %%
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %%
listings_df = pd.read_csv('denver_listing_dates_with_ct.csv')

# %%
listings_df['ct_key'] = listings_df['ct_key'].astype('int')
listings_df['list_month'] = (pd.to_datetime(listings_df['list_date']) + 
                                            pd.offsets.MonthBegin(n=1) - pd.offsets.MonthBegin(n=1))
listings_df['sale_month'] = (pd.to_datetime(listings_df['sale_date']) + 
                                            pd.offsets.MonthBegin(n=1) - pd.offsets.MonthBegin(n=1))

# %%
num_listings_ct = (listings_df.dropna(subset=['list_month'])
                   .groupby(['ct_key', 'list_month']).count()[['property_id']].reset_index())
num_listings_ct = num_listings_ct.rename(columns={'property_id':'ct_count_listings', 'list_month':'month'})

num_sales_ct = (listings_df.dropna(subset=['sale_month'])
                .groupby(['ct_key', 'sale_month']).count()[['property_id']].reset_index())
num_sales_ct = num_sales_ct.rename(columns={'property_id':'ct_count_sales', 'sale_month':'month'})

num_sales_listings_df = pd.merge(num_listings_ct, num_sales_ct, left_on=['month','ct_key'], 
                                 right_on=['month','ct_key'], how='outer')
num_sales_listings_df = num_sales_listings_df.fillna(0.)

# %%
num_sales_listings_df.head()
# Out:
#        ct_key      month  ct_count_listings  ct_count_sales
# 0  8001007801 2016-03-01                3.0             3.0
# 1  8001007801 2016-04-01                3.0             1.0
# 2  8001007801 2016-05-01                4.0             2.0
# 3  8001007801 2016-06-01                5.0             2.0
# 4  8001007801 2016-07-01                1.0             2.0

# %%
ct_stats_df = pd.read_csv('census_tract_data_updated.csv')

# %%
df_merged = pd.merge(ct_stats_df, num_sales_listings_df, left_on='ct_key', right_on='ct_key')

# %%
df_merged.head()
# Out:
#        ct_key  median_rental_price  \
# 0  8001007801               1316.0
# 1  8001007801               1316.0
# 2  8001007801               1316.0
# 3  8001007801               1316.0
# 4  8001007801               1316.0
#
#    average_annual_rent_as_percentage_of_property_value  farm_score  \
# 0                                           6.024884         100.0
# 1                                           6.024884         100.0
# 2                                           6.024884         100.0
# 3                                           6.024884         100.0
# 4                                           6.024884         100.0
#
#     pop_density  densely_urban_score  urban_score  suburban_score  \
# 0  15066.473217                  7.0         10.0            33.0
# 1  15066.473217                  7.0         10.0            33.0
# 2  15066.473217                  7.0         10.0            33.0
# 3  15066.473217                  7.0         10.0            33.0
# 4  15066.473217                  7.0         10.0            33.0
#
#    rural_score  remote_score  built 1995 or later  built 1970-1994  \
# 0         83.0          93.0            13.033873        45.729013
# 1         83.0          93.0            13.033873        45.729013
# 2         83.0          93.0            13.033873        45.729013
# 3         83.0          93.0            13.033873        45.729013
# 4         83.0          93.0            13.033873        45.729013
#
#    built 1940-1969  built before 1940  single_family_detached_pct  \
# 0        36.745214             4.4919                   19.072165
# 1        36.745214             4.4919                   19.072165
# 2        36.745214             4.4919                   19.072165
# 3        36.745214             4.4919                   19.072165
# 4        36.745214             4.4919                   19.072165
#
#    rowhouses_and_attached_homes_pct  small_apt_buildings_pct  \
# 0                          4.639175                 12.81296
# 1                          4.639175                 12.81296
# 2                          4.639175                 12.81296
# 3                          4.639175                 12.81296
# 4                          4.639175                 12.81296
#
#    complexes/high_rise_apt_pct  mobile_home_pct  0_bedroom_pct  1_bedroom_pct  \
# 0                      63.4757              0.0      10.824742      42.341679
# 1                      63.4757              0.0      10.824742      42.341679
# 2                      63.4757              0.0      10.824742      42.341679
# 3                      63.4757              0.0      10.824742      42.341679
# 4                      63.4757              0.0      10.824742      42.341679
#
#    2_bedroom_pct  3_bedroom_pct  4_bedroom_pct  5_bedroom_pct  \
# 0      32.621502       6.701031       6.185567       1.325479
# 1      32.621502       6.701031       6.185567       1.325479
# 2      32.621502       6.701031       6.185567       1.325479
# 3      32.621502       6.701031       6.185567       1.325479
# 4      32.621502       6.701031       6.185567       1.325479
#
#    homeownership_rate  rental_rate  seasonal_housing_pct  vacant_homes_pct  \
# 0            8.234096    91.765904                   0.0          5.743741
# 1            8.234096    91.765904                   0.0          5.743741
# 2            8.234096    91.765904                   0.0          5.743741
# 3            8.234096    91.765904                   0.0          5.743741
# 4            8.234096    91.765904                   0.0          5.743741
#
#    family_friendly_score  first_time_homebuyer_score  \
# 0              88.003519                   88.709612
# 1              88.003519                   88.709612
# 2              88.003519                   88.709612
# 3              88.003519                   88.709612
# 4              88.003519                   88.709612
#
#    luxury_communities_score  retirement_friendly_score  \
# 0                 93.683181                  99.866645
# 1                 93.683181                  99.866645
# 2                 93.683181                  99.866645
# 3                 93.683181                  99.866645
# 4                 93.683181                  99.866645
#
#    young_single_professional_score  college_student_friendly_score  \
# 0                        53.691517                       88.873766
# 1                        53.691517                       88.873766
# 2                        53.691517                       88.873766
# 3                        53.691517                       88.873766
# 4                        53.691517                       88.873766
#
#    commute_under_15_min_pct  commute_15-30_min_pct  commute_30-45_min_pct  \
# 0                 11.347926              49.596774              17.914747
# 1                 11.347926              49.596774              17.914747
# 2                 11.347926              49.596774              17.914747
# 3                 11.347926              49.596774              17.914747
# 4                 11.347926              49.596774              17.914747
#
#    commute_45-60_min_pct  commute_over_60_min_pct  violent_crime_rate  \
# 0              21.140553                      0.0           14.201501
# 1              21.140553                      0.0           14.201501
# 2              21.140553                      0.0           14.201501
# 3              21.140553                      0.0           14.201501
# 4              21.140553                      0.0           14.201501
#
#    property_crime_rate  standardized_test_score_percentile  \
# 0            49.839228                           11.341791
# 1            49.839228                           11.341791
# 2            49.839228                           11.341791
# 3            49.839228                           11.341791
# 4            49.839228                           11.341791
#
#    pct_pop_at_least_college_degree  children_poverty_pct  \
# 0                         0.074121              0.420058
# 1                         0.074121              0.420058
# 2                         0.074121              0.420058
# 3                         0.074121              0.420058
# 4                         0.074121              0.420058
#
#    student_to_teacher_ratio_sd  state_index_total_achievement_sd  \
# 0                    18.064738                               2.0
# 1                    18.064738                               2.0
# 2                    18.064738                               2.0
# 3                    18.064738                               2.0
# 4                    18.064738                               2.0
#
#    national_index_total_achievemet_sd  \
# 0                                 3.0
# 1                                 3.0
# 2                                 3.0
# 3                                 3.0
# 4                                 3.0
#
#    national_percentile_total_achievement_sd  \
# 0                                 22.182277
# 1                                 22.182277
# 2                                 22.182277
# 3                                 22.182277
# 4                                 22.182277
#
#    state_percentile_total_achievement_sd  \
# 0                              14.754098
# 1                              14.754098
# 2                              14.754098
# 3                              14.754098
# 4                              14.754098
#
#    average_number_of_students_per_school_sd  number_of_students_sc  \
# 0                                643.419355                  485.0
# 1                                643.419355                  485.0
# 2                                643.419355                  485.0
# 3                                643.419355                  485.0
# 4                                643.419355                  485.0
#
#    student_to_teacher_ratio_sc  state_index_total_achievement_sc  \
# 0                    16.649502                               1.0
# 1                    16.649502                               1.0
# 2                    16.649502                               1.0
# 3                    16.649502                               1.0
# 4                    16.649502                               1.0
#
#    national_index_total_achievement_sc  \
# 0                                  2.0
# 1                                  2.0
# 2                                  2.0
# 3                                  2.0
# 4                                  2.0
#
#    national_percentile_total_achievement_sc  \
# 0                                 13.874447
# 1                                 13.874447
# 2                                 13.874447
# 3                                 13.874447
# 4                                 13.874447
#
#    state_percentile_total_achievement_sc  census_population       <18  \
# 0                               3.830084               4137  0.335992
# 1                               3.830084               4137  0.335992
# 2                               3.830084               4137  0.335992
# 3                               3.830084               4137  0.335992
# 4                               3.830084               4137  0.335992
#
#       18-24     25-34     35-49     50-59     60-64     65-74      75+  \
# 0  0.086778  0.170897  0.238095  0.062122  0.052937  0.032149  0.02103
# 1  0.086778  0.170897  0.238095  0.062122  0.052937  0.032149  0.02103
# 2  0.086778  0.170897  0.238095  0.062122  0.052937  0.032149  0.02103
# 3  0.086778  0.170897  0.238095  0.062122  0.052937  0.032149  0.02103
# 4  0.086778  0.170897  0.238095  0.062122  0.052937  0.032149  0.02103
#
#    Hispanic    White     Black     Asian  linear_pop_trend_since_2010  \
# 0  0.459753  0.14745  0.117718  0.239304                     0.035645
# 1  0.459753  0.14745  0.117718  0.239304                     0.035645
# 2  0.459753  0.14745  0.117718  0.239304                     0.035645
# 3  0.459753  0.14745  0.117718  0.239304                     0.035645
# 4  0.459753  0.14745  0.117718  0.239304                     0.035645
#
#    avg_annual_pop_change_since_2010  linear_pop_trend_since_2014  \
# 0                          0.033135                     0.011039
# 1                          0.033135                     0.011039
# 2                          0.033135                     0.011039
# 3                          0.033135                     0.011039
# 4                          0.033135                     0.011039
#
#    avg_annual_pop_change_since_2014  annual_births_per_resident  \
# 0                          0.001638                    0.014503
# 1                          0.001638                    0.014503
# 2                          0.001638                    0.014503
# 3                          0.001638                    0.014503
# 4                          0.001638                    0.014503
#
#    workforce_fraction       car   carpool  public_transportation      walk  \
# 0            0.423012  0.445714  0.258286               0.204571  0.029714
# 1            0.423012  0.445714  0.258286               0.204571  0.029714
# 2            0.423012  0.445714  0.258286               0.204571  0.029714
# 3            0.423012  0.445714  0.258286               0.204571  0.029714
# 4            0.423012  0.445714  0.258286               0.204571  0.029714
#
#     WFH  other_mode_of_transit  median_household_income  median_family_income  \
# 0  0.02               0.041714                    32744                 40921
# 1  0.02               0.041714                    32744                 40921
# 2  0.02               0.041714                    32744                 40921
# 3  0.02               0.041714                    32744                 40921
# 4  0.02               0.041714                    32744                 40921
#
#    median_nonfamily_income  mean_household_income  mean_family_income  \
# 0                    19534                  42004               49152
# 1                    19534                  42004               49152
# 2                    19534                  42004               49152
# 3                    19534                  42004               49152
# 4                    19534                  42004               49152
#
#    mean_nonfamily_income  family_households_fraction  \
# 0                  30554                    0.595313
# 1                  30554                    0.595313
# 2                  30554                    0.595313
# 3                  30554                    0.595313
# 4                  30554                    0.595313
#
#    nonfamily_households_fraction  STEM_jobs  education&health_care  \
# 0                       0.404687       17.2                    8.7
# 1                       0.404687       17.2                    8.7
# 2                       0.404687       17.2                    8.7
# 3                       0.404687       17.2                    8.7
# 4                       0.404687       17.2                    8.7
#
#    total_households  avg_family_size  avg_nonfamily_size  avg_household_size  \
# 0              1280             4.37                1.29                3.18
# 1              1280             4.37                1.29                3.18
# 2              1280             4.37                1.29                3.18
# 3              1280             4.37                1.29                3.18
# 4              1280             4.37                1.29                3.18
#
#       <200k  200-300k  300-400k  400-500k  500-750k  750-1000k       >1M  \
# 0  0.429907  0.429907       0.0       0.0  0.084112        0.0  0.056075
# 1  0.429907  0.429907       0.0       0.0  0.084112        0.0  0.056075
# 2  0.429907  0.429907       0.0       0.0  0.084112        0.0  0.056075
# 3  0.429907  0.429907       0.0       0.0  0.084112        0.0  0.056075
# 4  0.429907  0.429907       0.0       0.0  0.084112        0.0  0.056075
#
#    married  divorced/separated/widowed  never_married  percent_mortgage  \
# 0     33.7                        22.8           43.5          0.803738
# 1     33.7                        22.8           43.5          0.803738
# 2     33.7                        22.8           43.5          0.803738
# 3     33.7                        22.8           43.5          0.803738
# 4     33.7                        22.8           43.5          0.803738
#
#    median_mortgage_value  vacancy_rate  built 2014 or later  built 2010-2013  \
# 0               173000.0      0.057437                  0.0              0.0
# 1               173000.0      0.057437                  0.0              0.0
# 2               173000.0      0.057437                  0.0              0.0
# 3               173000.0      0.057437                  0.0              0.0
# 4               173000.0      0.057437                  0.0              0.0
#
#    built 2000-2009      month  ct_count_listings  ct_count_sales
# 0         0.130339 2016-03-01                3.0             3.0
# 1         0.130339 2016-04-01                3.0             1.0
# 2         0.130339 2016-05-01                4.0             2.0
# 3         0.130339 2016-06-01                5.0             2.0
# 4         0.130339 2016-07-01                1.0             2.0

# %%
listing_sales_overall = df_merged.groupby(['ct_key','month']).agg(
    {'ct_count_listings':'mean', 'ct_count_sales':'mean'}).reset_index()
listing_sales_overall = listing_sales_overall.groupby('month').agg(
    {'ct_count_listings':'sum', 'ct_count_sales':'sum'})

# sum up number of households for all CT in the house listing dataset and the CT-level feature dataset
listing_sales_overall['total_households'] = ct_stats_df[ct_stats_df['ct_key'].isin(
    num_sales_listings_df.ct_key.unique())]['total_households'].sum()

listing_sales_overall['sales_per_households'] = (listing_sales_overall['ct_count_sales'] /
                                                 listing_sales_overall['total_households'])
listing_sales_overall['listings_per_households'] = (listing_sales_overall['ct_count_listings'] /
                                                    listing_sales_overall['total_households'])

# %%
df_merged = pd.merge(df_merged, listing_sales_overall[['sales_per_households', 'listings_per_households']], 
                     left_on='month', right_index=True)
df_merged['ct_listings_per_households'] = df_merged['ct_count_listings'] / df_merged['total_households']
df_merged['ct_sales_per_households'] = df_merged['ct_count_sales'] / df_merged['total_households']

df_merged['relative_listings_toBaseline'] = (df_merged['ct_listings_per_households'] / 
                                             df_merged['listings_per_households'])
df_merged['relative_sales_toBaseline'] = df_merged['ct_sales_per_households'] / df_merged['sales_per_households']

# %%
df_merged.head()
# Out:
#          ct_key  median_rental_price  \
# 0    8001007801               1316.0
# 54   8001007802               1239.0
# 104  8001007900               1482.0
# 160  8001008000               1499.0
# 218  8001008200               2190.0
#
#      average_annual_rent_as_percentage_of_property_value  farm_score  \
# 0                                             6.024884         100.0
# 54                                            9.187587         100.0
# 104                                          10.041348         100.0
# 160                                           7.532211         100.0
# 218                                           9.419278         100.0
#
#       pop_density  densely_urban_score  urban_score  suburban_score  \
# 0    15066.473217                  7.0         10.0            33.0
# 54   15270.696288                  7.0         10.0            33.0
# 104   8644.378631                 14.0          6.0            26.0
# 160   7448.779496                 17.0          3.0            23.0
# 218   3255.950515                 41.0         21.0             0.0
#
#      rural_score  remote_score  built 1995 or later  built 1970-1994  \
# 0           83.0          93.0            13.033873        45.729013
# 54          83.0          93.0             1.555412        53.856124
# 104         76.0          86.0             2.570440        39.001483
# 160         73.0          83.0             0.767123        23.342466
# 218         49.0          59.0             0.850785        18.390052
#
#      built 1940-1969  built before 1940  single_family_detached_pct  \
# 0          36.745214           4.491900                   19.072165
# 54         43.097861           1.490603                   15.942968
# 104        49.085517           9.342561                   51.754820
# 160        73.643836           2.246575                   73.534247
# 218        80.759162           0.000000                   95.811518
#
#      rowhouses_and_attached_homes_pct  small_apt_buildings_pct  \
# 0                            4.639175                12.812960
# 54                           3.370058                 3.434867
# 104                          3.311913                 5.635195
# 160                          5.424658                 9.972603
# 218                          1.570681                 0.000000
#
#      complexes/high_rise_apt_pct  mobile_home_pct  0_bedroom_pct  \
# 0                      63.475700         0.000000      10.824742
# 54                     76.085548         1.166559       3.240441
# 104                    39.298072         0.000000       4.201681
# 160                    11.013699         0.054795       0.054795
# 218                     2.617801         0.000000       0.000000
#
#      1_bedroom_pct  2_bedroom_pct  3_bedroom_pct  4_bedroom_pct  \
# 0        42.341679      32.621502       6.701031       6.185567
# 54       46.143876      37.070642       8.101102       5.443940
# 104      18.388532      37.716263      25.259516      12.357884
# 160      12.931507      21.972603      29.972603      23.178082
# 218       2.617801       5.824607      35.863874      33.769634
#
#      5_bedroom_pct  homeownership_rate  rental_rate  seasonal_housing_pct  \
# 0         1.325479            8.234096    91.765904                   0.0
# 54        0.000000            8.741817    91.258183                   0.0
# 104       2.076125           34.526095    65.473905                   0.0
# 160      11.890411           51.528767    48.471233                   0.0
# 218      21.924084           71.249946    28.750054                   0.0
#
#      vacant_homes_pct  family_friendly_score  first_time_homebuyer_score  \
# 0            5.743741              88.003519                   88.709612
# 54           6.351264              94.606671                   88.951501
# 104          5.882353              82.335231                   46.875042
# 160          2.794521              66.152493                   27.052337
# 218          0.000000              48.583959                   59.251902
#
#      luxury_communities_score  retirement_friendly_score  \
# 0                   93.683181                  99.866645
# 54                  96.101273                  99.907889
# 104                 81.712204                  96.969947
# 160                 79.212530                  90.990954
# 218                 72.622694                  89.095108
#
#      young_single_professional_score  college_student_friendly_score  \
# 0                          53.691517                       88.873766
# 54                         52.739850                       91.316781
# 104                        50.823170                       61.079491
# 160                        58.412211                       74.119442
# 218                        64.226244                       93.810663
#
#      commute_under_15_min_pct  commute_15-30_min_pct  commute_30-45_min_pct  \
# 0                   11.347926              49.596774              17.914747
# 54                   9.666506              45.915901              23.006283
# 104                 11.917467              46.567058              22.198506
# 160                 11.238025              36.440678              18.865144
# 218                 23.629568              37.749169              25.456811
#
#      commute_45-60_min_pct  commute_over_60_min_pct  violent_crime_rate  \
# 0                21.140553                 0.000000           14.201501
# 54               17.738038                 3.673272           16.498137
# 104              16.435432                 2.881537           11.881188
# 160              23.139278                10.316875           13.061651
# 218              11.544850                 1.619601           10.211524
#
#      property_crime_rate  standardized_test_score_percentile  \
# 0              49.839228                           11.341791
# 54             59.872272                            8.345964
# 104            47.164716                            9.550928
# 160            46.151167                           10.130373
# 218            36.652079                           12.682216
#
#      pct_pop_at_least_college_degree  children_poverty_pct  \
# 0                           0.074121              0.420058
# 54                          0.029777              0.460476
# 104                         0.151132              0.279825
# 160                         0.119054              0.280513
# 218                         0.117309              0.140160
#
#      student_to_teacher_ratio_sd  state_index_total_achievement_sd  \
# 0                      18.064738                               2.0
# 54                     18.064738                               2.0
# 104                    18.064738                               2.0
# 160                    18.064738                               2.0
# 218                    18.064738                               2.0
#
#      national_index_total_achievemet_sd  \
# 0                                   3.0
# 54                                  3.0
# 104                                 3.0
# 160                                 3.0
# 218                                 3.0
#
#      national_percentile_total_achievement_sd  \
# 0                                   22.182277
# 54                                  22.182277
# 104                                 22.182277
# 160                                 22.182277
# 218                                 22.182277
#
#      state_percentile_total_achievement_sd  \
# 0                                14.754098
# 54                               14.754098
# 104                              14.754098
# 160                              14.754098
# 218                              14.754098
#
#      average_number_of_students_per_school_sd  number_of_students_sc  \
# 0                                  643.419355                  485.0
# 54                                 643.419355                  336.0
# 104                                643.419355                  109.0
# 160                                643.419355                  553.5
# 218                                643.419355                  380.0
#
#      student_to_teacher_ratio_sc  state_index_total_achievement_sc  \
# 0                      16.649502                               1.0
# 54                     18.300654                               1.0
# 104                    10.268959                               1.0
# 160                    18.225852                               1.0
# 218                    17.314378                               1.0
#
#      national_index_total_achievement_sc  \
# 0                                    2.0
# 54                                   1.0
# 104                                  1.0
# 160                                  1.5
# 218                                  2.0
#
#      national_percentile_total_achievement_sc  \
# 0                                   13.874447
# 54                                   7.145540
# 104                                  6.013003
# 160                                 12.736336
# 218                                 13.115999
#
#      state_percentile_total_achievement_sc  census_population       <18  \
# 0                                 3.830084               4137  0.335992
# 54                                0.313370               4664  0.286878
# 104                               1.602217               5684  0.294159
# 160                               3.429666               6241  0.331037
# 218                               3.360028               6133  0.282896
#
#         18-24     25-34     35-49     50-59     60-64     65-74       75+  \
# 0    0.086778  0.170897  0.238095  0.062122  0.052937  0.032149  0.021030
# 54   0.108276  0.164022  0.275515  0.082547  0.033662  0.032161  0.016938
# 104  0.107495  0.200915  0.250000  0.075123  0.033603  0.024982  0.013723
# 160  0.079474  0.173690  0.200449  0.094696  0.034289  0.065374  0.020990
# 218  0.065221  0.199739  0.167781  0.135170  0.032284  0.052340  0.064569
#
#      Hispanic     White     Black     Asian  linear_pop_trend_since_2010  \
# 0    0.459753  0.147450  0.117718  0.239304                     0.035645
# 54   0.569897  0.135077  0.182676  0.067753                     0.033413
# 104  0.552076  0.226249  0.143737  0.020936                    -0.018518
# 160  0.521231  0.215350  0.143086  0.055119                     0.007368
# 218  0.417251  0.314691  0.161585  0.032447                     0.045752
#
#      avg_annual_pop_change_since_2010  linear_pop_trend_since_2014  \
# 0                            0.033135                     0.011039
# 54                           0.029529                     0.024965
# 104                         -0.013602                    -0.029572
# 160                          0.001279                     0.010184
# 218                          0.038140                     0.054022
#
#      avg_annual_pop_change_since_2014  annual_births_per_resident  \
# 0                            0.001638                    0.014503
# 54                           0.024260                    0.012650
# 104                         -0.030480                    0.006510
# 160                          0.015024                    0.016664
# 218                          0.048877                    0.006522
#
#      workforce_fraction       car   carpool  public_transportation      walk  \
# 0              0.423012  0.445714  0.258286               0.204571  0.029714
# 54             0.447256  0.543145  0.233461               0.160594  0.012464
# 104            0.501407  0.675439  0.168421               0.090175  0.029825
# 160            0.444160  0.733766  0.152597               0.078283  0.005411
# 218            0.419371  0.770218  0.079316               0.068040  0.007776
#
#           WFH  other_mode_of_transit  median_household_income  \
# 0    0.020000               0.041714                    32744
# 54   0.009108               0.041227                    30598
# 104  0.016140               0.020000                    41738
# 160  0.021284               0.008658                    50483
# 218  0.063764               0.010886                    62689
#
#      median_family_income  median_nonfamily_income  mean_household_income  \
# 0                   40921                    19534                  42004
# 54                  31685                    26144                  41771
# 104                 47163                    30506                  48359
# 160                 52450                    30114                  60798
# 218                 62328                    40536                  75085
#
#      mean_family_income  mean_nonfamily_income  family_households_fraction  \
# 0                 49152                  30554                    0.595313
# 54                41349                  39394                    0.660900
# 104               53658                  38016                    0.576155
# 160               67342                  41587                    0.688275
# 218               76416                  57508                    0.785340
#
#      nonfamily_households_fraction  STEM_jobs  education&health_care  \
# 0                         0.404687       17.2                    8.7
# 54                        0.339100       16.6                    6.1
# 104                       0.423845       10.2                   13.7
# 160                       0.311725       17.8                   14.2
# 218                       0.214660        7.1                   18.1
#
#      total_households  avg_family_size  avg_nonfamily_size  \
# 0                1280             4.37                1.29
# 54               1445             3.83                1.74
# 104              1904             3.92                1.59
# 160              1774             4.42                1.35
# 218              1528             4.18                1.52
#
#      avg_household_size     <200k  200-300k  300-400k  400-500k  500-750k  \
# 0                  3.18  0.429907  0.429907  0.000000  0.000000  0.084112
# 54                 3.21  0.478632  0.521368  0.000000  0.000000  0.000000
# 104                2.98  0.595016  0.213396  0.176012  0.000000  0.000000
# 160                3.51  0.363333  0.526667  0.086667  0.015556  0.007778
# 218                3.85  0.319030  0.532649  0.138060  0.010261  0.000000
#
#      750-1000k       >1M  married  divorced/separated/widowed  never_married  \
# 0          0.0  0.056075     33.7                        22.8           43.5
# 54         0.0  0.000000     34.1                        16.1           49.8
# 104        0.0  0.015576     38.7                        14.9           46.5
# 160        0.0  0.000000     43.6                        18.4           37.9
# 218        0.0  0.000000     44.9                        21.6           33.4
#
#      percent_mortgage  median_mortgage_value  vacancy_rate  \
# 0            0.803738               173000.0      0.057437
# 54           0.724409               256600.0      0.063513
# 104          0.860395               174000.0      0.058824
# 160          0.757377               223400.0      0.027945
# 218          0.687831               231900.0      0.000000
#
#      built 2014 or later  built 2010-2013  built 2000-2009      month  \
# 0               0.000000         0.000000         0.130339 2016-03-01
# 54              0.000000         0.000000         0.015554 2016-03-01
# 104             0.002966         0.014829         0.007909 2016-03-01
# 160             0.003836         0.000000         0.003836 2016-03-01
# 218             0.000000         0.000000         0.008508 2016-03-01
#
#      ct_count_listings  ct_count_sales  sales_per_households  \
# 0                  3.0             3.0              0.003846
# 54                 4.0             1.0              0.003846
# 104               15.0             7.0              0.003846
# 160               12.0             7.0              0.003846
# 218                8.0             5.0              0.003846
#
#      listings_per_households  ct_listings_per_households  \
# 0                   0.009463                    0.002344
# 54                  0.009463                    0.002768
# 104                 0.009463                    0.007878
# 160                 0.009463                    0.006764
# 218                 0.009463                    0.005236
#
#      ct_sales_per_households  relative_listings_toBaseline  \
# 0                   0.002344                      0.247662
# 54                  0.000692                      0.292510
# 104                 0.003676                      0.832478
# 160                 0.003946                      0.714786
# 218                 0.003272                      0.553242
#
#      relative_sales_toBaseline
# 0                     0.609404
# 54                    0.179939
# 104                   0.955928
# 160                   1.025979
# 218                   0.850826

# %%
droppped_ct = df_merged.groupby('ct_key').count()['ct_count_sales'].reset_index(name='count')
droppped_ct = droppped_ct[droppped_ct['count']<10]['ct_key'].values
droppped_ct
# Out:
# array([8001008100, 8039961206, 8039961208, 8041007500, 8069000600,
#        8123002005, 8123002012, 8123002501])

# %%
# drop census tract with too few data (only 1/2 months of available data)
df_merged = df_merged[~df_merged['ct_key'].isin(droppped_ct)]
print(df_merged.shape)

print(df_merged.ct_key.nunique())
print(len(df_merged))

percent_unique = np.ceil(df_merged.ct_key.nunique()/len(df_merged)*1000)/1000. #round up 3 d.p.
print(percent_unique)
# Out:
# (41367, 121)
# 746
# 41367
# 0.019

# %%
remaining_cts = list(set(df_merged.ct_key))

# %%
mean_listing_ratio = df_merged.groupby('ct_key').agg({'relative_listings_toBaseline': 'mean'})
mean_listing_ratio.rename({'relative_listings_toBaseline': 'mean_listing_ratio'}, axis=1, inplace=True)
mean_sales_ratio = df_merged.groupby('ct_key').agg({'relative_sales_toBaseline': 'mean'})
mean_sales_ratio.rename({'relative_sales_toBaseline': 'mean_sales_ratio'}, axis=1, inplace=True)

# %%
redundant_columns = ['homeownership_rate', 'family_households_fraction']
columns_to_drop = ['census_population', 'month','ct_count_listings', 'ct_count_sales', 
                   'sales_per_households', 'listings_per_households', 'ct_listings_per_households', 
                   'ct_sales_per_households', 'relative_listings_toBaseline','relative_sales_toBaseline'] 

X = df_merged.drop(columns_to_drop + redundant_columns, axis=1)

# %%
X.shape
# Out:
# (41367, 109)

# %%
X.head()
# Out:
#          ct_key  median_rental_price  \
# 0    8001007801               1316.0
# 54   8001007802               1239.0
# 104  8001007900               1482.0
# 160  8001008000               1499.0
# 218  8001008200               2190.0
#
#      average_annual_rent_as_percentage_of_property_value  farm_score  \
# 0                                             6.024884         100.0
# 54                                            9.187587         100.0
# 104                                          10.041348         100.0
# 160                                           7.532211         100.0
# 218                                           9.419278         100.0
#
#       pop_density  densely_urban_score  urban_score  suburban_score  \
# 0    15066.473217                  7.0         10.0            33.0
# 54   15270.696288                  7.0         10.0            33.0
# 104   8644.378631                 14.0          6.0            26.0
# 160   7448.779496                 17.0          3.0            23.0
# 218   3255.950515                 41.0         21.0             0.0
#
#      rural_score  remote_score  built 1995 or later  built 1970-1994  \
# 0           83.0          93.0            13.033873        45.729013
# 54          83.0          93.0             1.555412        53.856124
# 104         76.0          86.0             2.570440        39.001483
# 160         73.0          83.0             0.767123        23.342466
# 218         49.0          59.0             0.850785        18.390052
#
#      built 1940-1969  built before 1940  single_family_detached_pct  \
# 0          36.745214           4.491900                   19.072165
# 54         43.097861           1.490603                   15.942968
# 104        49.085517           9.342561                   51.754820
# 160        73.643836           2.246575                   73.534247
# 218        80.759162           0.000000                   95.811518
#
#      rowhouses_and_attached_homes_pct  small_apt_buildings_pct  \
# 0                            4.639175                12.812960
# 54                           3.370058                 3.434867
# 104                          3.311913                 5.635195
# 160                          5.424658                 9.972603
# 218                          1.570681                 0.000000
#
#      complexes/high_rise_apt_pct  mobile_home_pct  0_bedroom_pct  \
# 0                      63.475700         0.000000      10.824742
# 54                     76.085548         1.166559       3.240441
# 104                    39.298072         0.000000       4.201681
# 160                    11.013699         0.054795       0.054795
# 218                     2.617801         0.000000       0.000000
#
#      1_bedroom_pct  2_bedroom_pct  3_bedroom_pct  4_bedroom_pct  \
# 0        42.341679      32.621502       6.701031       6.185567
# 54       46.143876      37.070642       8.101102       5.443940
# 104      18.388532      37.716263      25.259516      12.357884
# 160      12.931507      21.972603      29.972603      23.178082
# 218       2.617801       5.824607      35.863874      33.769634
#
#      5_bedroom_pct  rental_rate  seasonal_housing_pct  vacant_homes_pct  \
# 0         1.325479    91.765904                   0.0          5.743741
# 54        0.000000    91.258183                   0.0          6.351264
# 104       2.076125    65.473905                   0.0          5.882353
# 160      11.890411    48.471233                   0.0          2.794521
# 218      21.924084    28.750054                   0.0          0.000000
#
#      family_friendly_score  first_time_homebuyer_score  \
# 0                88.003519                   88.709612
# 54               94.606671                   88.951501
# 104              82.335231                   46.875042
# 160              66.152493                   27.052337
# 218              48.583959                   59.251902
#
#      luxury_communities_score  retirement_friendly_score  \
# 0                   93.683181                  99.866645
# 54                  96.101273                  99.907889
# 104                 81.712204                  96.969947
# 160                 79.212530                  90.990954
# 218                 72.622694                  89.095108
#
#      young_single_professional_score  college_student_friendly_score  \
# 0                          53.691517                       88.873766
# 54                         52.739850                       91.316781
# 104                        50.823170                       61.079491
# 160                        58.412211                       74.119442
# 218                        64.226244                       93.810663
#
#      commute_under_15_min_pct  commute_15-30_min_pct  commute_30-45_min_pct  \
# 0                   11.347926              49.596774              17.914747
# 54                   9.666506              45.915901              23.006283
# 104                 11.917467              46.567058              22.198506
# 160                 11.238025              36.440678              18.865144
# 218                 23.629568              37.749169              25.456811
#
#      commute_45-60_min_pct  commute_over_60_min_pct  violent_crime_rate  \
# 0                21.140553                 0.000000           14.201501
# 54               17.738038                 3.673272           16.498137
# 104              16.435432                 2.881537           11.881188
# 160              23.139278                10.316875           13.061651
# 218              11.544850                 1.619601           10.211524
#
#      property_crime_rate  standardized_test_score_percentile  \
# 0              49.839228                           11.341791
# 54             59.872272                            8.345964
# 104            47.164716                            9.550928
# 160            46.151167                           10.130373
# 218            36.652079                           12.682216
#
#      pct_pop_at_least_college_degree  children_poverty_pct  \
# 0                           0.074121              0.420058
# 54                          0.029777              0.460476
# 104                         0.151132              0.279825
# 160                         0.119054              0.280513
# 218                         0.117309              0.140160
#
#      student_to_teacher_ratio_sd  state_index_total_achievement_sd  \
# 0                      18.064738                               2.0
# 54                     18.064738                               2.0
# 104                    18.064738                               2.0
# 160                    18.064738                               2.0
# 218                    18.064738                               2.0
#
#      national_index_total_achievemet_sd  \
# 0                                   3.0
# 54                                  3.0
# 104                                 3.0
# 160                                 3.0
# 218                                 3.0
#
#      national_percentile_total_achievement_sd  \
# 0                                   22.182277
# 54                                  22.182277
# 104                                 22.182277
# 160                                 22.182277
# 218                                 22.182277
#
#      state_percentile_total_achievement_sd  \
# 0                                14.754098
# 54                               14.754098
# 104                              14.754098
# 160                              14.754098
# 218                              14.754098
#
#      average_number_of_students_per_school_sd  number_of_students_sc  \
# 0                                  643.419355                  485.0
# 54                                 643.419355                  336.0
# 104                                643.419355                  109.0
# 160                                643.419355                  553.5
# 218                                643.419355                  380.0
#
#      student_to_teacher_ratio_sc  state_index_total_achievement_sc  \
# 0                      16.649502                               1.0
# 54                     18.300654                               1.0
# 104                    10.268959                               1.0
# 160                    18.225852                               1.0
# 218                    17.314378                               1.0
#
#      national_index_total_achievement_sc  \
# 0                                    2.0
# 54                                   1.0
# 104                                  1.0
# 160                                  1.5
# 218                                  2.0
#
#      national_percentile_total_achievement_sc  \
# 0                                   13.874447
# 54                                   7.145540
# 104                                  6.013003
# 160                                 12.736336
# 218                                 13.115999
#
#      state_percentile_total_achievement_sc       <18     18-24     25-34  \
# 0                                 3.830084  0.335992  0.086778  0.170897
# 54                                0.313370  0.286878  0.108276  0.164022
# 104                               1.602217  0.294159  0.107495  0.200915
# 160                               3.429666  0.331037  0.079474  0.173690
# 218                               3.360028  0.282896  0.065221  0.199739
#
#         35-49     50-59     60-64     65-74       75+  Hispanic     White  \
# 0    0.238095  0.062122  0.052937  0.032149  0.021030  0.459753  0.147450
# 54   0.275515  0.082547  0.033662  0.032161  0.016938  0.569897  0.135077
# 104  0.250000  0.075123  0.033603  0.024982  0.013723  0.552076  0.226249
# 160  0.200449  0.094696  0.034289  0.065374  0.020990  0.521231  0.215350
# 218  0.167781  0.135170  0.032284  0.052340  0.064569  0.417251  0.314691
#
#         Black     Asian  linear_pop_trend_since_2010  \
# 0    0.117718  0.239304                     0.035645
# 54   0.182676  0.067753                     0.033413
# 104  0.143737  0.020936                    -0.018518
# 160  0.143086  0.055119                     0.007368
# 218  0.161585  0.032447                     0.045752
#
#      avg_annual_pop_change_since_2010  linear_pop_trend_since_2014  \
# 0                            0.033135                     0.011039
# 54                           0.029529                     0.024965
# 104                         -0.013602                    -0.029572
# 160                          0.001279                     0.010184
# 218                          0.038140                     0.054022
#
#      avg_annual_pop_change_since_2014  annual_births_per_resident  \
# 0                            0.001638                    0.014503
# 54                           0.024260                    0.012650
# 104                         -0.030480                    0.006510
# 160                          0.015024                    0.016664
# 218                          0.048877                    0.006522
#
#      workforce_fraction       car   carpool  public_transportation      walk  \
# 0              0.423012  0.445714  0.258286               0.204571  0.029714
# 54             0.447256  0.543145  0.233461               0.160594  0.012464
# 104            0.501407  0.675439  0.168421               0.090175  0.029825
# 160            0.444160  0.733766  0.152597               0.078283  0.005411
# 218            0.419371  0.770218  0.079316               0.068040  0.007776
#
#           WFH  other_mode_of_transit  median_household_income  \
# 0    0.020000               0.041714                    32744
# 54   0.009108               0.041227                    30598
# 104  0.016140               0.020000                    41738
# 160  0.021284               0.008658                    50483
# 218  0.063764               0.010886                    62689
#
#      median_family_income  median_nonfamily_income  mean_household_income  \
# 0                   40921                    19534                  42004
# 54                  31685                    26144                  41771
# 104                 47163                    30506                  48359
# 160                 52450                    30114                  60798
# 218                 62328                    40536                  75085
#
#      mean_family_income  mean_nonfamily_income  nonfamily_households_fraction  \
# 0                 49152                  30554                       0.404687
# 54                41349                  39394                       0.339100
# 104               53658                  38016                       0.423845
# 160               67342                  41587                       0.311725
# 218               76416                  57508                       0.214660
#
#      STEM_jobs  education&health_care  total_households  avg_family_size  \
# 0         17.2                    8.7              1280             4.37
# 54        16.6                    6.1              1445             3.83
# 104       10.2                   13.7              1904             3.92
# 160       17.8                   14.2              1774             4.42
# 218        7.1                   18.1              1528             4.18
#
#      avg_nonfamily_size  avg_household_size     <200k  200-300k  300-400k  \
# 0                  1.29                3.18  0.429907  0.429907  0.000000
# 54                 1.74                3.21  0.478632  0.521368  0.000000
# 104                1.59                2.98  0.595016  0.213396  0.176012
# 160                1.35                3.51  0.363333  0.526667  0.086667
# 218                1.52                3.85  0.319030  0.532649  0.138060
#
#      400-500k  500-750k  750-1000k       >1M  married  \
# 0    0.000000  0.084112        0.0  0.056075     33.7
# 54   0.000000  0.000000        0.0  0.000000     34.1
# 104  0.000000  0.000000        0.0  0.015576     38.7
# 160  0.015556  0.007778        0.0  0.000000     43.6
# 218  0.010261  0.000000        0.0  0.000000     44.9
#
#      divorced/separated/widowed  never_married  percent_mortgage  \
# 0                          22.8           43.5          0.803738
# 54                         16.1           49.8          0.724409
# 104                        14.9           46.5          0.860395
# 160                        18.4           37.9          0.757377
# 218                        21.6           33.4          0.687831
#
#      median_mortgage_value  vacancy_rate  built 2014 or later  \
# 0                 173000.0      0.057437             0.000000
# 54                256600.0      0.063513             0.000000
# 104               174000.0      0.058824             0.002966
# 160               223400.0      0.027945             0.003836
# 218               231900.0      0.000000             0.000000
#
#      built 2010-2013  built 2000-2009
# 0           0.000000         0.130339
# 54          0.000000         0.015554
# 104         0.014829         0.007909
# 160         0.000000         0.003836
# 218         0.000000         0.008508

# %% [markdown]
# ### Remove redundant features

# %%
feature_df = X.drop(columns=['ct_key'])

# %%
def compute_correlations(feature_df, threshold):
    feature_correlations = feature_df.corr()
    for column in feature_correlations.columns:
        corrs = feature_correlations[column]
        print(column)
        for i, corr in enumerate(corrs):
            if threshold < corr < 1.0:
                print(feature_correlations.index[i], corr)
        print('-------')

# %%
compute_correlations(feature_df, 0.9)
# Out:
# median_rental_price
# -------
# average_annual_rent_as_percentage_of_property_value
# -------
# farm_score
# -------
# pop_density
# -------
# densely_urban_score
# urban_score 0.9706743799495929
# -------
# urban_score
# densely_urban_score 0.9706743799495929
# -------
# suburban_score
# -------
# rural_score
# remote_score 0.9961198474175759
# -------
# remote_score
# rural_score 0.9961198474175759
# -------
# built 1995 or later
# built 2000-2009 0.9447342313734648
# -------
# built 1970-1994
# -------
# built 1940-1969
# -------
# built before 1940
# -------
# single_family_detached_pct
# -------
# rowhouses_and_attached_homes_pct
# -------
# small_apt_buildings_pct
# -------
# complexes/high_rise_apt_pct
# -------
# mobile_home_pct
# -------
# 0_bedroom_pct
# -------
# 1_bedroom_pct
# -------
# 2_bedroom_pct
# -------
# 3_bedroom_pct
# -------
# 4_bedroom_pct
# -------
# 5_bedroom_pct
# -------
# rental_rate
# -------
# seasonal_housing_pct
# -------
# vacant_homes_pct
# vacancy_rate 0.9999999999999769
# -------
# family_friendly_score
# -------
# first_time_homebuyer_score
# -------
# luxury_communities_score
# -------
# retirement_friendly_score
# -------
# young_single_professional_score
# -------
# college_student_friendly_score
# -------
# commute_under_15_min_pct
# -------
# commute_15-30_min_pct
# -------
# commute_30-45_min_pct
# -------
# commute_45-60_min_pct
# -------
# commute_over_60_min_pct
# -------
# violent_crime_rate
# -------
# property_crime_rate
# -------
# standardized_test_score_percentile
# -------
# pct_pop_at_least_college_degree
# -------
# children_poverty_pct
# -------
# student_to_teacher_ratio_sd
# -------
# state_index_total_achievement_sd
# national_index_total_achievemet_sd 0.9680847095962792
# national_percentile_total_achievement_sd 0.9779667025199599
# state_percentile_total_achievement_sd 0.9969079675440286
# -------
# national_index_total_achievemet_sd
# state_index_total_achievement_sd 0.9680847095962792
# national_percentile_total_achievement_sd 0.9941466304882706
# state_percentile_total_achievement_sd 0.9803346308706369
# -------
# national_percentile_total_achievement_sd
# state_index_total_achievement_sd 0.9779667025199599
# national_index_total_achievemet_sd 0.9941466304882706
# state_percentile_total_achievement_sd 0.9846919859524703
# -------
# state_percentile_total_achievement_sd
# state_index_total_achievement_sd 0.9969079675440286
# national_index_total_achievemet_sd 0.9803346308706369
# national_percentile_total_achievement_sd 0.9846919859524703
# -------
# average_number_of_students_per_school_sd
# -------
# number_of_students_sc
# -------
# student_to_teacher_ratio_sc
# -------
# state_index_total_achievement_sc
# national_index_total_achievement_sc 0.9893882711368231
# national_percentile_total_achievement_sc 0.9939683838530349
# state_percentile_total_achievement_sc 0.9968327841822414
# -------
# national_index_total_achievement_sc
# state_index_total_achievement_sc 0.9893882711368231
# national_percentile_total_achievement_sc 0.9964104484312137
# state_percentile_total_achievement_sc 0.9932496590796576
# -------
# national_percentile_total_achievement_sc
# state_index_total_achievement_sc 0.9939683838530349
# national_index_total_achievement_sc 0.9964104484312137
# state_percentile_total_achievement_sc 0.9966664690425397
# -------
# state_percentile_total_achievement_sc
# state_index_total_achievement_sc 0.9968327841822414
# national_index_total_achievement_sc 0.9932496590796576
# national_percentile_total_achievement_sc 0.9966664690425397
# -------
# <18
# -------
# 18-24
# -------
# 25-34
# -------
# 35-49
# -------
# 50-59
# -------
# 60-64
# -------
# 65-74
# -------
# 75+
# -------
# Hispanic
# -------
# White
# -------
# Black
# -------
# Asian
# -------
# linear_pop_trend_since_2010
# avg_annual_pop_change_since_2010 0.9672055659142721
# -------
# avg_annual_pop_change_since_2010
# linear_pop_trend_since_2010 0.9672055659142721
# -------
# linear_pop_trend_since_2014
# avg_annual_pop_change_since_2014 0.9878818942710641
# -------
# avg_annual_pop_change_since_2014
# linear_pop_trend_since_2014 0.9878818942710641
# -------
# annual_births_per_resident
# -------
# workforce_fraction
# -------
# car
# -------
# carpool
# -------
# public_transportation
# -------
# walk
# -------
# WFH
# -------
# other_mode_of_transit
# -------
# median_household_income
# median_family_income 0.9046389214870745
# mean_household_income 0.9379564868375365
# -------
# median_family_income
# median_household_income 0.9046389214870745
# mean_household_income 0.9168961575818616
# mean_family_income 0.9370233454814053
# -------
# median_nonfamily_income
# -------
# mean_household_income
# median_household_income 0.9379564868375365
# median_family_income 0.9168961575818616
# mean_family_income 0.9458556933907495
# -------
# mean_family_income
# median_family_income 0.9370233454814053
# mean_household_income 0.9458556933907495
# -------
# mean_nonfamily_income
# -------
# nonfamily_households_fraction
# -------
# STEM_jobs
# -------
# education&health_care
# -------
# total_households
# -------
# avg_family_size
# -------
# avg_nonfamily_size
# -------
# avg_household_size
# -------
# <200k
# -------
# 200-300k
# -------
# 300-400k
# -------
# 400-500k
# -------
# 500-750k
# -------
# 750-1000k
# -------
# >1M
# -------
# married
# -------
# divorced/separated/widowed
# -------
# never_married
# -------
# percent_mortgage
# -------
# median_mortgage_value
# -------
# vacancy_rate
# vacant_homes_pct 0.9999999999999769
# -------
# built 2014 or later
# -------
# built 2010-2013
# -------
# built 2000-2009
# built 1995 or later 0.9447342313734648
# -------

# %%
redundant_columns = [
    'densely_urban_score', 'remote_score', 'built 2000-2009', 'state_index_total_achievement_sd',
    'national_index_total_achievemet_sd', 'state_percentile_total_achievement_sd', 
    'state_index_total_achievement_sc', 'state_percentile_total_achievement_sc', 
    'national_index_total_achievement_sc', 'avg_annual_pop_change_since_2010',
    'linear_pop_trend_since_2014', 'avg_annual_pop_change_since_2014',
    'mean_household_income', 'median_family_income', 'mean_family_income', 'vacancy_rate',
    'standardized_test_score_percentile'
]

# %%
feature_df.drop(columns=redundant_columns, inplace=True, errors='ignore')

# %%
compute_correlations(feature_df, 0.8)
# Out:
# median_rental_price
# -------
# average_annual_rent_as_percentage_of_property_value
# -------
# farm_score
# -------
# pop_density
# rural_score 0.852596267726759
# -------
# urban_score
# -------
# suburban_score
# -------
# rural_score
# pop_density 0.852596267726759
# -------
# built 1995 or later
# -------
# built 1970-1994
# -------
# built 1940-1969
# -------
# built before 1940
# -------
# single_family_detached_pct
# -------
# rowhouses_and_attached_homes_pct
# -------
# small_apt_buildings_pct
# -------
# complexes/high_rise_apt_pct
# 1_bedroom_pct 0.8877648399564687
# rental_rate 0.8319893375391376
# -------
# mobile_home_pct
# -------
# 0_bedroom_pct
# -------
# 1_bedroom_pct
# complexes/high_rise_apt_pct 0.8877648399564687
# rental_rate 0.823297685803986
# -------
# 2_bedroom_pct
# -------
# 3_bedroom_pct
# -------
# 4_bedroom_pct
# -------
# 5_bedroom_pct
# -------
# rental_rate
# complexes/high_rise_apt_pct 0.8319893375391376
# 1_bedroom_pct 0.823297685803986
# family_friendly_score 0.8952952960221957
# -------
# seasonal_housing_pct
# vacant_homes_pct 0.8589959145117876
# -------
# vacant_homes_pct
# seasonal_housing_pct 0.8589959145117876
# -------
# family_friendly_score
# rental_rate 0.8952952960221957
# -------
# first_time_homebuyer_score
# -------
# luxury_communities_score
# Hispanic 0.8519880212515858
# -------
# retirement_friendly_score
# -------
# young_single_professional_score
# -------
# college_student_friendly_score
# -------
# commute_under_15_min_pct
# -------
# commute_15-30_min_pct
# -------
# commute_30-45_min_pct
# -------
# commute_45-60_min_pct
# -------
# commute_over_60_min_pct
# -------
# violent_crime_rate
# -------
# property_crime_rate
# -------
# pct_pop_at_least_college_degree
# -------
# children_poverty_pct
# -------
# student_to_teacher_ratio_sd
# -------
# national_percentile_total_achievement_sd
# -------
# average_number_of_students_per_school_sd
# -------
# number_of_students_sc
# -------
# student_to_teacher_ratio_sc
# -------
# national_percentile_total_achievement_sc
# -------
# <18
# avg_household_size 0.8368402577793452
# -------
# 18-24
# -------
# 25-34
# -------
# 35-49
# -------
# 50-59
# -------
# 60-64
# -------
# 65-74
# -------
# 75+
# -------
# Hispanic
# luxury_communities_score 0.8519880212515858
# -------
# White
# -------
# Black
# -------
# Asian
# -------
# linear_pop_trend_since_2010
# -------
# annual_births_per_resident
# -------
# workforce_fraction
# -------
# car
# -------
# carpool
# -------
# public_transportation
# -------
# walk
# -------
# WFH
# -------
# other_mode_of_transit
# -------
# median_household_income
# -------
# median_nonfamily_income
# -------
# mean_nonfamily_income
# -------
# nonfamily_households_fraction
# -------
# STEM_jobs
# -------
# education&health_care
# -------
# total_households
# -------
# avg_family_size
# avg_household_size 0.862173178841057
# -------
# avg_nonfamily_size
# -------
# avg_household_size
# <18 0.8368402577793452
# avg_family_size 0.862173178841057
# -------
# <200k
# -------
# 200-300k
# -------
# 300-400k
# -------
# 400-500k
# -------
# 500-750k
# -------
# 750-1000k
# -------
# >1M
# median_mortgage_value 0.8190811026593033
# -------
# married
# -------
# divorced/separated/widowed
# -------
# never_married
# -------
# percent_mortgage
# -------
# median_mortgage_value
# >1M 0.8190811026593033
# -------
# built 2014 or later
# -------
# built 2010-2013
# -------

# %%
vifs = [(feature_df.columns[i], variance_inflation_factor(feature_df.values, i)) 
        for i in range(len(feature_df.columns))]
# Out:
# /Users/wfried/anaconda3/envs/digital_index/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
for feature, vif in vifs:
    print(feature, vif)
# Out:
# median_rental_price 3.796257517594767
# average_annual_rent_as_percentage_of_property_value 2.9226141144190994
# farm_score 1.8162785287974026
# pop_density 14.956783002729763
# urban_score 66.92156209475854
# suburban_score 3.9921238440935762
# rural_score 111.9129049912226
# built 1995 or later 2251799813685248.0
# built 1970-1994 3002399751580330.5
# built 1940-1969 2251799813685248.0
# built before 1940 643371375338642.2
# single_family_detached_pct 3023.51590806175
# rowhouses_and_attached_homes_pct 264.9333930999622
# small_apt_buildings_pct 96.45849454483884
# complexes/high_rise_apt_pct 2188.143330673394
# mobile_home_pct 255.62215613476866
# 0_bedroom_pct 22076468761620.08
# 1_bedroom_pct 321685687669321.1
# 2_bedroom_pct 409418147942772.4
# 3_bedroom_pct 346430740566961.25
# 4_bedroom_pct 321685687669321.1
# 5_bedroom_pct 128674275067728.45
# rental_rate 27.270679496135696
# seasonal_housing_pct 6.501263196608353
# vacant_homes_pct 6.918186049776011
# family_friendly_score 29.336266540084846
# first_time_homebuyer_score 2.8394851405256394
# luxury_communities_score 49.72484095838512
# retirement_friendly_score 9.556879634271493
# young_single_professional_score 21.52777296776933
# college_student_friendly_score 2.0694065612722596
# commute_under_15_min_pct 281474976710656.0
# commute_15-30_min_pct 200159983438688.72
# commute_30-45_min_pct 176611750092960.62
# commute_45-60_min_pct 136472715980924.12
# commute_over_60_min_pct 9052461562553.762
# violent_crime_rate 7.155965651549917
# property_crime_rate 2.0597694399721527
# pct_pop_at_least_college_degree 24.266693063614117
# children_poverty_pct 2.3223144217357286
# student_to_teacher_ratio_sd 3.5557403755982757
# national_percentile_total_achievement_sd 3.95119050771067
# average_number_of_students_per_school_sd 3.573344839458547
# number_of_students_sc 1.4901746117450392
# student_to_teacher_ratio_sc 1.4685257522056097
# national_percentile_total_achievement_sc 3.2842364758238056
# <18 inf
# 18-24 inf
# 25-34 inf
# 35-49 inf
# 50-59 inf
# 60-64 inf
# 65-74 inf
# 75+ inf
# Hispanic 122.05398796218968
# White 166.94402879031924
# Black 22.946762320637266
# Asian 6.818871863696951
# linear_pop_trend_since_2010 2.783654777150136
# annual_births_per_resident 1.4027472505906042
# workforce_fraction 5.550212316566634
# car 3002399751580330.5
# carpool inf
# public_transportation inf
# walk inf
# WFH inf
# other_mode_of_transit inf
# median_household_income 20.772532421252908
# median_nonfamily_income 3.9097189059515003
# mean_nonfamily_income 4.410613371549417
# nonfamily_households_fraction 48.74230648636248
# STEM_jobs 2.4549748324101937
# education&health_care 2.5236463779881513
# total_households 1.5240227206678332
# avg_family_size 26.61419262562157
# avg_nonfamily_size 3.0387761001884206
# avg_household_size 58.69458215864988
# <200k inf
# 200-300k inf
# 300-400k inf
# 400-500k inf
# 500-750k inf
# 750-1000k inf
# >1M inf
# married 48793.506063074325
# divorced/separated/widowed 8197.113657317988
# never_married 38666.4160478082
# percent_mortgage 3.167082518598615
# median_mortgage_value 22.378058903107025
# built 2014 or later 2.164671563427543
# built 2010-2013 2.7083087108945954

# %%
high_vif_columns = [
    'other_mode_of_transit', 'White', 'commute_15-30_min_pct', 'commute_30-45_min_pct', 'commute_45-60_min_pct',
    '35-49', '50-59', '60-64', '0_bedroom_pct', '5_bedroom_pct', 'divorced/separated/widowed',
    '>1M', 'rural_score', 'built before 1940', 'built 1940-1969', 'single_family_detached_pct',
    '4_bedroom_pct', 'WFH', '18-24', 'average_annual_rent_as_percentage_of_property_value',
    'built 1970-1994', '3_bedroom_pct', 'family_friendly_score', 'student_to_teacher_ratio_sd',
    'national_percentile_total_achievement_sc', '25-34', 'carpool', 'median_mortgage_value',
    'avg_household_size', 'median_rental_price', 'farm_score', '2_bedroom_pct', 'luxury_communities_score',
    'national_percentile_total_achievement_sd', 'average_number_of_students_per_school_sd', '65-74',
    'complexes/high_rise_apt_pct', '1_bedroom_pct', '<18', 'mean_nonfamily_income', '<200k', 'never_married',
    'retirement_friendly_score', 'young_single_professional_score', 'workforce_fraction', 'percent_mortgage',
    'avg_nonfamily_size', 'urban_score', 'car', 'median_nonfamily_income', 'college_student_friendly_score',
    'pct_pop_at_least_college_degree', 'student_to_teacher_ratio_sc', 'avg_family_size', 
    'median_household_income', 'married', 'nonfamily_households_fraction', 'education&health_care',
    'STEM_jobs'
]

# %%
feature_df.drop(columns=high_vif_columns, inplace=True, errors='ignore')

# %%
vifs = [(feature_df.columns[i], variance_inflation_factor(feature_df.values, i)) 
        for i in range(len(feature_df.columns))]

# %%
for feature, vif in vifs:
    if vif > 10:
        print(feature, vif)
# Out:
# pop_density 10.28218555161742
# rental_rate 11.112822172257653
# commute_under_15_min_pct 10.181159227112198
# violent_crime_rate 11.183611380413021

# %%
list(feature_df.columns)
# Out:
# ['pop_density',
#  'suburban_score',
#  'built 1995 or later',
#  'rowhouses_and_attached_homes_pct',
#  'small_apt_buildings_pct',
#  'mobile_home_pct',
#  'rental_rate',
#  'seasonal_housing_pct',
#  'vacant_homes_pct',
#  'first_time_homebuyer_score',
#  'commute_under_15_min_pct',
#  'commute_over_60_min_pct',
#  'violent_crime_rate',
#  'property_crime_rate',
#  'children_poverty_pct',
#  'number_of_students_sc',
#  '75+',
#  'Hispanic',
#  'Black',
#  'Asian',
#  'linear_pop_trend_since_2010',
#  'annual_births_per_resident',
#  'public_transportation',
#  'walk',
#  'total_households',
#  '200-300k',
#  '300-400k',
#  '400-500k',
#  '500-750k',
#  '750-1000k',
#  'built 2014 or later',
#  'built 2010-2013']

# %%
X.drop(columns=redundant_columns + high_vif_columns, inplace=True, errors='ignore')

# %% [markdown]
# ### Feature engineering

# %%
y = df_merged['relative_listings_toBaseline'].values
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=df_merged.ct_key.nunique(), random_state=100, stratify=df_merged.ct_key)

# %%
X_test = X_test.merge(mean_listing_ratio, on='ct_key', how='inner')

# %%
X_test_ct = X_test['ct_key']

# %%
y_test = np.array(X_test['mean_listing_ratio'])
X_train.drop(columns=['ct_key'], inplace=True)
X_test.drop(columns=['ct_key', 'mean_listing_ratio'], inplace=True)

# %%
std_scaler = StandardScaler()
X_train_std = std_scaler.fit_transform(X_train)
X_test_std = std_scaler.fit_transform(X_test)

# %%
plt.figure(figsize=(20, 10))
plt.hist(np.log(y_train + 0.1), bins=20)
plt.show()

# %%
def log_transform(x):
    return np.log(x + offset)
def undo_log_transform(x):
    return np.exp(x) - offset

# %%
offset = 0.1
y_train = log_transform(y_train)

# %% [markdown]
# ### Linear regression model

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train_std, y_train)
preds = lin_reg.predict(X_test_std)
preds = undo_log_transform(preds)
print(mean_squared_error(y_test, preds))
# Out:
# 0.1426979116495078

# %%
for idx, slope in enumerate(lin_reg.coef_):
    column = list(X_train.columns)[idx]
    feature = X_train_std[:, idx]
    plt.figure(figsize=(20, 10))
    plt.scatter(feature, y_train, color='b')
    plt.xlabel(column)
    plt.ylabel('log listings ratio')
    x_vals = np.array([min(feature), max(feature)])
    y_vals = (x_vals * slope) + lin_reg.intercept_
    plt.plot(x_vals, y_vals, color='r')
    plt.title(str(slope) + ' ' + str(np.corrcoef(feature, y_train)[0, 1]))
    plt.show()

# %%
# take 15 random test points, and plot the predicted rate of sales/households (compared to the distributions of known rate)
plt.rcParams.update({'font.size': 14})
fig, ax = plt.subplots(3,5, sharex=True, figsize=(25,10))
fig.suptitle("Ratio of each Census Tract's Listings Rate vs. Overall Denver's Listing Rate", fontsize=25, y=1.05)
for idx, i in enumerate(np.random.choice(len(X_test_ct), 15, replace=False)):
    ct = X_test_ct.iloc[i]
    ax[idx//5, idx%5].set_title(f"census tract {ct}")

    # plot the distribution of known rates
    ax[idx//5, idx%5].hist(df_merged[df_merged['ct_key']==ct]['relative_listings_toBaseline'], alpha=0.5, label='actual rates')
    ax[idx//5, idx%5].axvline(np.mean(df_merged[df_merged['ct_key']==ct]['relative_listings_toBaseline']), c='k', linestyle=':', label='mean ratio')

    # plot the prediction
    # ax[idx//5, idx%5].axvline(preds[i], c='b',label='lin reg pred') 
    # ax[idx//5, idx%5].legend()

    # axis label
    if idx//5 == 2: ax[idx//5, idx%5].set_xlabel("ratio of CT sales rate to Denver sales rate")
    if idx%5 == 0: ax[idx//5, idx%5].set_ylabel("number of monthly data")

plt.tight_layout()

# %%
avg_ratios = df_merged.groupby('ct_key').agg({'relative_listings_toBaseline': np.mean}).values.flatten()

# %%
plt.figure(figsize=(20, 10))
plt.hist(avg_ratios, bins=20)
plt.xlabel('average ratio of CT across all months')
plt.ylabel('number of census tracts')
plt.axvline(x=np.mean(avg_ratios), color='r', linestyle='--', label='mean of average ratios')
plt.legend()
plt.show()

# %%
p = 100
n = 20
eta = 0.001
tol = 1e-5
np.random.seed(123)
X = np.random.multivariate_normal(mean=np.random.normal(0, 1, p), cov=np.eye(p), size=n)
Y = np.random.normal(0, 5, n)

# %%
#GRADIENT DESCENT

alpha = 0.01 #Step size
iterations = 2000 #No. of iterations
m = len(Y) #No. of data points
np.random.seed(123) #Set the seed
theta = np.zeros(p) #Pick some random values to start with
theta_0 = np.random.normal(0, 1, p)
theta = theta_0

#GRADIENT DESCENT
def gradient_descent(x, y, theta, iterations, alpha):
    past_costs = []
    past_thetas = [theta]
    for i in range(iterations):
        prediction = np.dot(x, theta)
        error = prediction - y
        cost = 1/(2*m) * np.dot(error.T, error)
        past_costs.append(cost)
        theta = theta - (alpha * (1/m) * np.dot(x.T, error))
        past_thetas.append(theta)
        
    return past_thetas, past_costs

#Pass the relevant variables to the function and get the new values back...
past_thetas, past_costs = gradient_descent(X, Y, theta, iterations, alpha)
theta = past_thetas[-1]

#Print the results...
#print("Gradient Descent: {:.2f}, {:.2f}".format(theta[0], theta[1]))

# %%
theta
# Out:
# array([ 0.16879014,  0.44288796, -0.06952441, -0.37130667,  0.30288178,
#         0.08237119, -0.12821755,  0.6397359 , -0.21634227,  0.18012055,
#        -0.12562532, -0.35453113,  0.56043436, -0.23364123, -0.40493673,
#         0.09018264,  0.18882858, -0.3285883 ,  0.13874293,  0.47366841,
#        -0.05845087, -0.0533692 ,  0.13679959,  0.06300183, -0.13130815,
#         0.09105941, -0.14773378, -0.11620632,  0.26051089,  0.1115511 ,
#        -0.02105439, -0.44728524,  0.14508157,  0.01396671,  0.29811266,
#        -0.26932465, -0.15175741, -0.10801352, -0.00238938,  0.08534291,
#         0.13039821,  0.13746348,  0.47064318, -0.10828769,  0.54001192,
#        -0.12680693, -0.00586791, -0.19007127,  0.04640731, -0.02766685,
#        -0.31937062, -0.34306903,  0.26167574,  0.22356482,  0.21865044,
#         0.47542581, -0.18955108, -0.08737281,  0.44977601, -0.07482351,
#        -0.46828224,  0.38394644,  0.09113312,  0.4541651 ,  0.19150955,
#        -0.0253627 , -0.47734397, -0.11734279, -0.21626964,  0.05842403,
#         0.16712864, -0.17907849, -0.45223865,  0.08739121,  0.4238583 ,
#         0.008519  ,  0.08758329,  0.23725976,  0.1841701 , -0.39409639,
#         0.10291556,  0.20336756,  0.10127572,  0.39551778,  0.75477204,
#         0.17132273, -0.17356362,  0.26806708, -0.27909827, -0.18946464,
#         0.31965711, -0.60392398, -0.24852838,  0.10734561,  0.19733273,
#         0.58371949,  0.05447526, -0.26655239,  0.00909038, -0.01132202])

# %%
theta_0 + X.T @ np.linalg.inv(X @ X.T) @ (Y - X @ theta_0)
# Out:
# array([ 0.16879014,  0.44288796, -0.06952441, -0.37130667,  0.30288178,
#         0.08237119, -0.12821755,  0.6397359 , -0.21634227,  0.18012055,
#        -0.12562532, -0.35453113,  0.56043436, -0.23364123, -0.40493673,
#         0.09018264,  0.18882858, -0.3285883 ,  0.13874293,  0.47366841,
#        -0.05845087, -0.0533692 ,  0.13679959,  0.06300183, -0.13130815,
#         0.09105941, -0.14773378, -0.11620632,  0.26051089,  0.1115511 ,
#        -0.02105439, -0.44728524,  0.14508157,  0.01396671,  0.29811266,
#        -0.26932465, -0.15175741, -0.10801352, -0.00238938,  0.08534291,
#         0.13039821,  0.13746348,  0.47064318, -0.10828769,  0.54001192,
#        -0.12680693, -0.00586791, -0.19007127,  0.04640731, -0.02766685,
#        -0.31937062, -0.34306903,  0.26167574,  0.22356482,  0.21865044,
#         0.47542581, -0.18955108, -0.08737281,  0.44977601, -0.07482351,
#        -0.46828224,  0.38394644,  0.09113312,  0.4541651 ,  0.19150955,
#        -0.0253627 , -0.47734397, -0.11734279, -0.21626964,  0.05842403,
#         0.16712864, -0.17907849, -0.45223865,  0.08739121,  0.4238583 ,
#         0.008519  ,  0.08758329,  0.23725976,  0.1841701 , -0.39409639,
#         0.10291556,  0.20336756,  0.10127572,  0.39551778,  0.75477204,
#         0.17132273, -0.17356362,  0.26806708, -0.27909827, -0.18946464,
#         0.31965711, -0.60392398, -0.24852838,  0.10734561,  0.19733273,
#         0.58371949,  0.05447526, -0.26655239,  0.00909038, -0.01132202])

# %%
X.T @ np.linalg.inv(X @ X.T) @ Y
# Out:
# array([ 0.30237534,  0.31758644,  0.09929945,  0.08872507,  0.18469441,
#         0.08170689, -0.00376054,  0.08076657, -0.19641205, -0.08338354,
#        -0.00385387, -0.2835767 ,  0.44843355, -0.22954211, -0.11405775,
#        -0.06016697, -0.15447034,  0.06324019,  0.18303775,  0.40327684,
#        -0.27248635,  0.07303234,  0.2060669 , -0.22999563, -0.07482589,
#         0.0987327 ,  0.08917459, -0.08754889,  0.26888241, -0.09286464,
#        -0.04494537, -0.23086819,  0.06350062,  0.06904888, -0.01720513,
#         0.20902936, -0.07756637,  0.09048461,  0.04627685,  0.06721767,
#        -0.08871883, -0.00794493,  0.07406351, -0.02528982,  0.2204156 ,
#         0.03434465, -0.26290733, -0.1707586 , -0.02521932,  0.00249613,
#        -0.15656134, -0.28144088, -0.06157325,  0.01825324,  0.06784733,
#         0.18672392,  0.03992683,  0.01174164,  0.21502628, -0.15497342,
#        -0.39954135,  0.191657  , -0.11493544,  0.31290541,  0.10869142,
#        -0.1217841 , -0.23467606,  0.0226969 , -0.02929512,  0.15357259,
#         0.07942154,  0.01395426, -0.04690872,  0.25109641,  0.39286116,
#         0.03162441,  0.25235344,  0.30295636,  0.25483098, -0.19441437,
#        -0.21438923,  0.0326078 , -0.01941105,  0.28632409,  0.38081108,
#         0.15725075, -0.23021041,  0.18924507, -0.12658605, -0.13712128,
#        -0.06926857, -0.36670895, -0.11383729,  0.19785893, -0.09289457,
#         0.73875973,  0.08603233, -0.33274861,  0.09720301, -0.08072878])

# %%
def gradient(b):
    return -2 * np.dot(X.T, Y - np.dot(X, b))

# %%
b = np.zeros(p)

# %%
X.T @ (Y - X @ b)
# Out:
# array([ -1.75976356,  45.63691337,  15.9647438 , -23.3728969 ,
#         -4.90705911,  39.92170801, -60.41879336, -22.27092328,
#         13.78027948, -40.36039267, -22.54134945, -16.74530078,
#         72.03599318, -27.27694155, -13.30828614, -25.97336445,
#         39.81064188,  72.32925555,  40.09214308,  28.58121868,
#         -9.03280803,  52.21101797,  -7.64739527,  16.19836795,
#        -36.81988   ,  -5.76989313,  38.90467793, -47.62844608,
#          5.32278914, -30.28328309,  -1.45635908, -87.65277679,
#        -45.10572998,  -7.34956585,  13.00845784,  23.43785342,
#         -1.34067734,  19.53942789, -24.89570526,  20.99941455,
#        -26.13492361, -57.63098164, -15.95057799,  23.50971422,
#         12.93749301,   6.73102219,  25.34077433,  -5.51962451,
#         22.35593281,  57.29136424, -38.93055076, -38.72784337,
#         40.19043511, -20.94099435,  16.1522205 ,  28.56089168,
#         39.40130561,  35.41376521,  52.88951462,  25.26885033,
#        -37.3274443 ,  20.16372966,  -5.73160945, -21.05883979,
#         43.24126525,  19.13637419, -19.45345191,   9.87276321,
#        -25.32848359,  10.91608945,  18.16612231, -13.23188925,
#         45.00863499,  -7.69482978, -22.36806457,  23.23747651,
#         10.57789442,  23.04054856,  -2.82045202, -41.1931292 ,
#          3.04135595, -11.46715588,  48.51336886,  45.31975046,
#         -7.22935402, -14.60474384, -31.0645512 , -26.61494613,
#         59.40776635,   4.60188241,  19.91421157, -52.62109243,
#         -4.13463106,  47.00868742, -11.51452205,  66.85599525,
#        -15.82221459, -49.50029633,  17.86518349, -23.25870851])

# %%
# Out:
# array([-2.94279751, -0.24544412, -1.70849991,  2.52069278,  7.83695959,
#         2.66077271, -0.56952206, -6.73150005,  3.88981566, -6.11473574,
#        -0.93566534,  4.79117822,  4.0561273 ,  4.19356638,  3.49460618,
#         0.72929731,  1.51077312,  0.46035132,  2.41288716,  2.67618221])

# %%
from sklearn.metrics import mean_squared_error

# %%
def objective_function(b):
    preds = X @ b
    return mean_squared_error(Y, preds)

# %%
b = np.zeros(p)
#norm_prev = 
prev_objective = np.float('inf')
cnt = 0
for i in range(3):
    grad = gradient(b)
    b -= eta * grad
    print(b)
    #norm = np.linalg.norm(b)
    objective = objective_function(b)
    if abs(objective - prev_objective) < tol:
        break
    prev_objective = objective
    print(objective)
    
#     cnt += 1
#     if cnt % 100 == 0:
#         print(cnt)
# Out:
# [-0.00351953  0.09127383  0.03192949 -0.04674579 -0.00981412  0.07984342
#  -0.12083759 -0.04454185  0.02756056 -0.08072079 -0.0450827  -0.0334906
#   0.14407199 -0.05455388 -0.02661657 -0.05194673  0.07962128  0.14465851
#   0.08018429  0.05716244 -0.01806562  0.10442204 -0.01529479  0.03239674
#  -0.07363976 -0.01153979  0.07780936 -0.09525689  0.01064558 -0.06056657
#  -0.00291272 -0.17530555 -0.09021146 -0.01469913  0.02601692  0.04687571
#  -0.00268135  0.03907886 -0.04979141  0.04199883 -0.05226985 -0.11526196
#  -0.03190116  0.04701943  0.02587499  0.01346204  0.05068155 -0.01103925
#   0.04471187  0.11458273 -0.0778611  -0.07745569  0.08038087 -0.04188199
#   0.03230444  0.05712178  0.07880261  0.07082753  0.10577903  0.0505377
#  -0.07465489  0.04032746 -0.01146322 -0.04211768  0.08648253  0.03827275
#  -0.0389069   0.01974553 -0.05065697  0.02183218  0.03633224 -0.02646378
#   0.09001727 -0.01538966 -0.04473613  0.04647495  0.02115579  0.0460811
#  -0.0056409  -0.08238626  0.00608271 -0.02293431  0.09702674  0.0906395
#  -0.01445871 -0.02920949 -0.0621291  -0.05322989  0.11881553  0.00920376
#   0.03982842 -0.10524218 -0.00826926  0.09401737 -0.02302904  0.13371199
#  -0.03164443 -0.09900059  0.03573037 -0.04651742]
# 37.00788150538246
# [ 0.20976895 -0.0585734  -0.09259507  0.21419342  0.1436508  -0.26422664
#   0.36915701  0.1952845  -0.28510786  0.11531987  0.0530141  -0.06161504
#  -0.1187276   0.0786748   0.00322284  0.06411077 -0.36701612 -0.39669215
#  -0.11641708  0.00691907 -0.15169829 -0.21353922  0.19863848 -0.15081732
#   0.18548702  0.15270895 -0.12529442  0.17814343  0.104648    0.15273142
#   0.09270425  0.33832444  0.33318139  0.15947329 -0.1351958   0.00053295
#  -0.06445639 -0.118452    0.12486633 -0.01133132  0.16088706  0.30291892
#   0.14316618 -0.09049797  0.03427754 -0.00189758 -0.44075321 -0.10442024
#  -0.11497642 -0.42126806  0.11354223  0.13043614 -0.25386976  0.21857175
#   0.03179425 -0.07667324 -0.16435927 -0.35234045 -0.09331326 -0.20631646
#   0.0568041  -0.06000268 -0.03040884  0.3260081  -0.22547572 -0.15221206
#  -0.10401293  0.02194729  0.14862565 -0.04664251 -0.0496172   0.13820409
#  -0.264296    0.24120959  0.49282334 -0.18950239  0.08422212  0.0985543
#   0.16241153  0.21525434 -0.21389415  0.19432404 -0.19720157 -0.04697089
#   0.17657475  0.23519574  0.08817766  0.20856536 -0.32586698 -0.05550682
#  -0.14926722  0.06008733 -0.08513329 -0.13789264  0.1230818  -0.07643555
#   0.18016711  0.17830213 -0.08277054  0.04161391]
# 479.12907301340886
# [-0.48798121  0.72009007  0.42801596 -0.7870029  -0.3852081   1.14508468
#  -1.61736811 -0.72969467  0.82803625 -0.76879866 -0.41100264 -0.07941625
#   1.2121362  -0.54464224 -0.17975041 -0.47847401  1.34838999  1.84167739
#   0.79222337  0.36968348  0.22049847  1.16046339 -0.5461693   0.54508076
#  -0.90362897 -0.43038806  0.77969903 -1.02559502 -0.15537884 -0.73282091
#  -0.24823311 -1.90252122 -1.353754   -0.46468763  0.47483382  0.30220818
#   0.13305108  0.52700544 -0.60596425  0.29210208 -0.70431358 -1.43281218
#  -0.53111951  0.50764344  0.10623262  0.08535406  1.33596444  0.15795752
#   0.54983637  1.71756579 -0.75837495 -0.82345147  1.09534874 -0.78503397
#   0.13073652  0.56031113  0.88030254  1.28496383  0.89753686  0.79168331
#  -0.63551812  0.41663485 -0.02028225 -1.01193259  1.07671886  0.58092643
#  -0.02093211  0.07317457 -0.66328166  0.26277564  0.34965627 -0.49381537
#   1.18671406 -0.65110076 -1.40823424  0.74724012 -0.06181184  0.08268807
#  -0.39453982 -1.04211848  0.53027544 -0.60235411  1.05777826  0.70043686
#  -0.47440927 -0.72601359 -0.61382061 -0.80708053  1.49515163  0.17570058
#   0.58181616 -0.83347943  0.13862091  0.93918448 -0.45584057  1.07997203
#  -0.61374243 -1.07137239  0.42603339 -0.38792876]
# 7844.853322800164
