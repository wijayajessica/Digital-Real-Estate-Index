# %%
from collections import Counter, defaultdict
import datetime
import geopandas as gpd
import json
import numpy as np
from math import radians
import matplotlib.pyplot as plt
import pandas as pd
import pgeocode
from shapely.geometry import Point
from sklearn.linear_model import LinearRegression
from sklearn.metrics.pairwise import haversine_distances
from uszipcode import SearchEngine

# %%
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
plt.rcParams.update({'font.size': 22})

# %%
market_area = 'atlanta'
state = 'GA'

# %%
with open(f'{market_area}_zipcodes.txt', 'r') as f:
    market_area_zipcodes = sorted(json.loads(f.read()))

# %% [markdown]
# ### Process Neighborhood Scout data

# %%
neighborhood_scout_dir = 'neighborhood_scout_data'

# %%
# dataframe mapping ZIP code to census tract (note: a census tract can be in multiple ZIP codes)
zipcode_mapping_df = pd.read_csv(f'{neighborhood_scout_dir}/zip_tract_crosswalk_2020.csv')
zipcode_mapping_df = zipcode_mapping_df[zipcode_mapping_df['ZIP'].isin(market_area_zipcodes)]

# %%
zipcode_mapping_df.head()
# Out:
#          ZIP        TRACT  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 50459  30002  13089023102   0.177713   0.005797   0.179104   0.162219
# 50460  30002  13089023113   0.323754   0.098551   0.268657   0.302459
# 50461  30002  13089022005   0.046334   0.005797   0.000000   0.041863
# 50462  30002  13089023000   0.336364   0.828986   0.343284   0.380952
# 50463  30002  13089022100   0.115836   0.060870   0.208955   0.112507

# %%
# census tracts in market area
market_area_census_tracts = set(zipcode_mapping_df['TRACT'])

# %%
len(market_area_census_tracts)
# Out:
# 646

# %%
# dataframe reporting census tract-level statistics
all_ct_stats_df = pd.read_csv(f'{neighborhood_scout_dir}/census_tract_2020_q3.csv')

# %%
# census tracts in entire state of interest
statewide_census_tracts = set(all_ct_stats_df[all_ct_stats_df['state'] == state]['ct_key'])

# %%
# limit analysis to census tracts in market area
ct_stats_df = all_ct_stats_df[all_ct_stats_df['ct_key'].isin(market_area_census_tracts)]
ct_stats_df.drop(columns=['state'], inplace=True)

# %%
ct_stats_df.shape
# Out:
# (643, 61)

# %%
ct_stats_df.isna().sum()
# Out:
# ct_key                 0
# rent.ct                0
# grrent_yield.ct        0
# rent_br3.ct            0
# rent_br2.ct            0
# rent_br1.ct            0
# rent_br0.ct            0
# cos.ct                 0
# lake.ct                0
# frm.ct                 0
# pop_density.ct         0
# den.ct                 0
# urb.ct                 0
# sub.ct                 0
# rur.ct                 0
# rmt.ct                 0
# new_pct.ct             0
# est_pct.ct             0
# old_pct.ct             0
# his_pct.ct             0
# det_pct.ct             0
# att_pct.ct             0
# sap_pct.ct             0
# lap_pct.ct             0
# mob_pct.ct             0
# oth_pct.ct             0
# bed0_pct.ct            0
# bed1_pct.ct            0
# bed2_pct.ct            0
# bed3_pct.ct            0
# bed4_pct.ct            0
# bed5_pct.ct            0
# base_pct.ct            0
# dorms_pct.ct           0
# incarc_pct.ct          0
# publichou_pct.ct       0
# own_pct.ct             0
# rnt_pct.ct             0
# seasonal_pct.ct        0
# vacant_pct.ct          0
# family_fr.ct           0
# ft_homebuyer.ct        0
# luxury.ct              0
# vac_home.ct            0
# retire_fr.ct           0
# young_sng_pro.ct       0
# college_fr.ct          0
# commtime15_pct.ct      0
# commtime30_pct.ct      0
# commtime45_pct.ct      0
# commtime60_pct.ct      0
# commtime90_pct.ct      0
# count_violent.ct       0
# count_property.ct      0
# count_total.ct         0
# pt_violent.ct          0
# pt_property.ct         0
# pt_total.ct            0
# education_score.ct     0
# college_grads.ct       0
# children_poverty.ct    0
# dtype: int64

# %% [markdown]
# ### School district data

# %%
# dataframe mapping school district to census tract
school_mapping_df = pd.read_csv(f'{neighborhood_scout_dir}/ct_schooldist_crosswalk_2020.csv')
school_mapping_df = school_mapping_df[['ct_key', 'leaid']]
ct_stats_df = ct_stats_df.merge(school_mapping_df, how='inner', on='ct_key')

# %%
ct_stats_df.shape
# Out:
# (692, 62)

# %%
# dataframe reporting statistics for each school district
school_district_df = pd.read_csv(f'{neighborhood_scout_dir}/school_district_2020.csv')
school_district_df.head()
# Out:
#   state   leaid                                district_name.sd  member.sd  \
# 0    AZ  400001              CAVE CREEK UNIFIED DISTRICT (4244)       5406
# 1    AZ  400003            CHINO VALLEY UNIFIED DISTRICT (4474)       2348
# 2    AZ  400004     CLARKDALE-JEROME ELEMENTARY DISTRICT (4486)        472
# 3    AZ  400005  SALOME CONSOLIDATED ELEMENTARY DISTRICT (4514)        113
# 4    AZ  400021           COLORADO CITY UNIFIED DISTRICT (4370)        673
#
#    sch.sd  puptch.sd stcls_total.sd uscls_total.sd usrpct_total.sd  \
# 0       8  23.102564              8              9       81.810155
# 1       4  20.271087              6              5       43.544623
# 2       1  20.521739              7              7       65.234942
# 3       1     14.125              2              1        5.994954
# 4       2  23.614035              7              7       65.689057
#
#   strpct_total.sd
# 0       77.117117
# 1       50.630631
# 2       66.306306
# 3       13.603604
# 4       66.846847

# %%
school_district_df['avg_member.sd'] = school_district_df['member.sd'] / school_district_df['sch.sd']

# %%
school_district_df.drop(columns=['state', 'district_name.sd', 'member.sd', 'sch.sd'], 
                        inplace=True, errors='ignore')

# %%
ct_stats_df = ct_stats_df.merge(school_district_df, how='inner', on='leaid')

# %%
ct_stats_df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
# convert string columns to float
for column in ct_stats_df.columns:
    if ct_stats_df[column].dtype == 'object':
        ct_stats_df[column] = ct_stats_df[column].astype('float64')

# %%
ct_stats_df.shape
# Out:
# (692, 68)

# %%
# average statistics for census tracts that encompass multiple school districts
ct_stats_df = ct_stats_df.groupby('ct_key').mean().reset_index()
ct_stats_df.shape
# Out:
# (643, 68)

# %% [markdown]
# ### Individual school data

# %%
# dataframe reporting statistics for each school 
school_building_df = pd.read_csv(f'{neighborhood_scout_dir}/school_building_2020.csv')
school_building_df = school_building_df[school_building_df['ct_key'].isin(market_area_census_tracts)]
school_building_df.drop(columns=['state', 'ncessch', 'name.sc', 'street.sc', 'city.sc'],
                        inplace=True)

# %%
school_building_df.head(5)
# Out:
#       state.sc  zip.sc       ct_key member.sc  puptch.sc stcls_total.sc  \
# 19260       GA   30184  13015960102      1518  18.787129              6
# 19261       GA   30184  13015960102       552  14.300518              8
# 19262       GA   30171  13015960102       402  13.311258              7
# 19263       GA   30103  13015960200       712  14.989474              7
# 19264       GA   30103  13015960200       786  18.068966              6
#
#       uscls_total.sc usrpct_total.sc strpct_total.sc
# 19260              4       37.255155       56.067961
# 19261              8       71.409626        75.87769
# 19262              6       57.205394       63.816535
# 19263              6       58.012839       64.552661
# 19264              5       43.291044       50.736127

# %%
print('fraction of census tracts with data on schools:', (len(school_building_df['ct_key'].unique()) / 
                                                          len(market_area_census_tracts)))
# Out:
# fraction of census tracts with data on schools: 0.6099071207430341

# %%
# the fact that the set is empty confirms that each census tract is served by at least one school that
# we have data on
school_building_df_no_missing_vals = school_building_df[school_building_df['stcls_total.sc'] != ' ']
set(school_building_df_no_missing_vals['ct_key']) - set(school_building_df['ct_key'])
# Out:
# set()

# %%
school_building_df = school_building_df_no_missing_vals

# %%
print(school_building_df.shape)
school_building_df = school_building_df[school_building_df['ct_key'].notna()]
print(school_building_df.shape)
# Out:
# (666, 9)
# (666, 9)

# %%
missing_poptch_indices = list(school_building_df[school_building_df['puptch.sc'] == ' '].index)

# %%
mean_inputation = np.mean([float(x) for x in school_building_df['puptch.sc'] if x != ' '])
for idx in missing_poptch_indices:
    school_building_df.at[idx, 'puptch.sc'] = mean_inputation

# %%
for column in ['stcls_total.sc', 'uscls_total.sc', 'member.sc', 'zip.sc']:
    school_building_df[column] = school_building_df[column].astype(int)
for column in ['puptch.sc', 'usrpct_total.sc', 'strpct_total.sc']:
    school_building_df[column] = school_building_df[column].astype(float)

# %%
school_building_df_zipcode = school_building_df.groupby('zip.sc').mean().reset_index().drop(columns=['ct_key'])

# %%
school_building_df_zipcode.head()
# Out:
#    zip.sc    member.sc  puptch.sc  stcls_total.sc  uscls_total.sc  \
# 0   30002   487.750000  13.439795        7.500000        7.250000
# 1   30004  1177.230769  16.172912        9.615385        9.384615
# 2   30005  1281.500000  15.366505       10.000000       10.000000
# 3   30008   399.000000  11.915889        4.000000        3.750000
# 4   30009   630.500000  11.967636        9.500000        9.500000
#
#    usrpct_total.sc  strpct_total.sc
# 0        68.061309        70.625708
# 1        89.917676        91.368493
# 2        96.817750        97.115966
# 3        31.175843        37.271782
# 4        89.101834        90.515289

# %%
# calculate average school statistics for census tracts that encompass multiple schools
school_building_df_ct = school_building_df.groupby('ct_key').mean().reset_index()
school_building_df_ct.drop(columns=['zip.sc'], inplace=True)

# %%
census_tracts_with_school = set(school_building_df_ct['ct_key'])
has_school_df = pd.DataFrame([(ct, int(ct in census_tracts_with_school)) for ct in market_area_census_tracts],
                             columns=['ct_key', 'has_school'])

# %%
census_tracts_no_school = set(has_school_df[has_school_df['has_school'] == 0]['ct_key'])

# %%
ct_no_school_zipcode_df = (zipcode_mapping_df[zipcode_mapping_df['TRACT'].isin(census_tracts_no_school)]
                           [['ZIP', 'TRACT']])

# %%
ct_no_school_zipcode_school_df = ct_no_school_zipcode_df.merge(school_building_df_zipcode,
                                                               left_on='ZIP',
                                                               right_on='zip.sc',
                                                               how='left')
ct_no_school_zipcode_school_df.drop(['ZIP', 'zip.sc'], axis=1, inplace=True)

# %%
ct_no_school_zipcode_school_df.head()
# Out:
#          TRACT    member.sc  puptch.sc  stcls_total.sc  uscls_total.sc  \
# 0  13117130304  1177.230769  16.172912        9.615385        9.384615
# 1  13121011505  1177.230769  16.172912        9.615385        9.384615
# 2  13057090802  1177.230769  16.172912        9.615385        9.384615
# 3  13117130305  1177.230769  16.172912        9.615385        9.384615
# 4  13117130603  1177.230769  16.172912        9.615385        9.384615
#
#    usrpct_total.sc  strpct_total.sc
# 0        89.917676        91.368493
# 1        89.917676        91.368493
# 2        89.917676        91.368493
# 3        89.917676        91.368493
# 4        89.917676        91.368493

# %%
ct_no_school_zipcode_school_df = ct_no_school_zipcode_school_df.groupby('TRACT').mean().reset_index()

# %%
missing_tracts = ct_no_school_zipcode_school_df[ct_no_school_zipcode_school_df['member.sc'].isna()]['TRACT']
missing_school_indices = list(ct_no_school_zipcode_school_df[ct_no_school_zipcode_school_df['TRACT'].
                                                             isin(missing_tracts)].index)

# %%
ct_no_school_zipcode_school_df.columns
# Out:
# Index(['TRACT', 'member.sc', 'puptch.sc', 'stcls_total.sc', 'uscls_total.sc',
#        'usrpct_total.sc', 'strpct_total.sc'],
#       dtype='object')

# %%
for idx in missing_school_indices:
    for col in ct_no_school_zipcode_school_df.columns:
        if col not in {'TRACT', 'ncessch'}:
            if col == 'member.sc':
                ct_no_school_zipcode_school_df.at[idx, col] = np.mean(ct_no_school_zipcode_school_df['member.sc'])
            else:
                statistic = col.split('.')[0]
                ct_no_school_zipcode_school_df.at[idx, col] = ct_stats_df[statistic + '.sd'][idx]

# %%
ct_no_school_zipcode_school_df.rename({'TRACT': 'ct_key'}, axis=1, inplace=True)

# %%
combined_school_building_df = pd.concat([school_building_df_ct, ct_no_school_zipcode_school_df])

# %%
combined_school_building_df.shape
# Out:
# (646, 7)

# %%
ct_stats_df = ct_stats_df.merge(combined_school_building_df, on='ct_key', how='left')

# %% [markdown]
# ### Population Estimates

# %%
data_dir = f'{market_area}_census_tract_data'

# %%
def convert_to_ct_key(df, l=-11):
    df['id'] = [int(ct[l:]) for ct in df['id']]
    df.rename({'id': 'ct_key'}, inplace=True, axis=1)
    return df

# %%
def read_in_dataset(filename):
    df = pd.read_csv(f'{data_dir}/{filename}.csv', header=1)
    df = convert_to_ct_key(df)
    df = df[df['ct_key'].isin(ct_stats_df['ct_key'])]
    return df

# %%
# AGE AND SEX (2018: ACS 5-Year Estimates Subject Tables)
# https://data.census.gov/cedsci/table?t=Populations%20and%20People&g=0400000US08.140000&tid=ACSST5Y2018.S0101&hidePreview=false
age_demographics_df = read_in_dataset('age_demographics')
age_demographics_df.rename({'Estimate!!Total!!Total population': 'census_population'}, axis=1, inplace=True)
age_census_pop_df = age_demographics_df[['ct_key', 'census_population']]

# %%
age_census_pop_df.head()
# Out:
#          ct_key  census_population
# 44  13015960101               1379
# 45  13015960102               9810
# 46  13015960200              11388
# 47  13015960300               6393
# 48  13015960401              10034

# %%
population_threshold = 1000
census_tracts_low_pop_df = age_census_pop_df[
    (age_census_pop_df['census_population'].isna()) |
    (age_census_pop_df['census_population'] < population_threshold)]

# %%
census_tracts_low_pop_df
# Out:
#            ct_key  census_population
# 388   13063980000                  0
# 741   13089980000                  0
# 954   13121003700                148
# 1127  13121980000                  0

# %%
census_tracts_low_pop = list(census_tracts_low_pop_df['ct_key'])

# %%
# HOUSEHOLDS AND FAMILIES
household_size_df = read_in_dataset('household_size')
column_to_new_column = {'Estimate!!Total!!HOUSEHOLDS!!Total households': 'total_households'}
household_size_df = household_size_df[['ct_key'] + list(column_to_new_column)]
household_size_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
census_tracts_no_households_df = household_size_df[household_size_df['total_households'] == 0]

# %%
census_tracts_no_households_df
# Out:
#            ct_key  total_households
# 388   13063980000                 0
# 693   13089023115                 0
# 741   13089980000                 0
# 980   13121006801                 0
# 1127  13121980000                 0

# %%
census_tracts_no_households = list(census_tracts_no_households_df['ct_key'])

# %%
census_tracts_to_ignore = census_tracts_low_pop + census_tracts_no_households

# %%
# ignore census tracts that have 0 population or 0 households according to the Census Bureau
print(len(ct_stats_df))
ct_stats_df = ct_stats_df[~ct_stats_df['ct_key'].isin(census_tracts_to_ignore)]
print(len(ct_stats_df))
# Out:
# 643
# 637

# %%
# add population to the census tract level features
ct_stats_df = ct_stats_df.merge(age_census_pop_df, on='ct_key', how='left')
ct_stats_df['census_population'] = ct_stats_df['census_population'].astype(int)

# %%
plt.figure(figsize=(20, 10))
plt.hist(ct_stats_df['census_population'])
plt.xlabel('population of census tract')
plt.ylabel('number of census tracts')
plt.show()

# %% [markdown]
# ## Adding features from Census Bureau

# %% [markdown]
# ### Age demographics

# %% [markdown]
# Age brackets:
# 1. < 18
# 2. 18-24
# 3. 25-34
# 4. 35-49
# 5. 50-59
# 6. 60-64
# 7. 65-74
# 8. 75+

# %%
age_demographics_df.head(2)
# Out:
#          ct_key                          Geographic Area Name  \
# 44  13015960101  Census Tract 9601.01, Bartow County, Georgia
# 45  13015960102  Census Tract 9601.02, Bartow County, Georgia
#
#     census_population Margin of Error!!Total MOE!!Total population  \
# 44               1379                                          129
# 45               9810                                          679
#
#    Estimate!!Percent!!Total population  \
# 44                                 (X)
# 45                                 (X)
#
#    Margin of Error!!Percent MOE!!Total population  \
# 44                                            (X)
# 45                                            (X)
#
#     Estimate!!Male!!Total population  \
# 44                               705
# 45                              5000
#
#     Margin of Error!!Male MOE!!Total population  \
# 44                                           85
# 45                                          374
#
#    Estimate!!Percent Male!!Total population  \
# 44                                      (X)
# 45                                      (X)
#
#    Margin of Error!!Percent Male MOE!!Total population  \
# 44                                                (X)
# 45                                                (X)
#
#     Estimate!!Female!!Total population  \
# 44                                 674
# 45                                4810
#
#     Margin of Error!!Female MOE!!Total population  \
# 44                                             86
# 45                                            417
#
#    Estimate!!Percent Female!!Total population  \
# 44                                        (X)
# 45                                        (X)
#
#    Margin of Error!!Percent Female MOE!!Total population  \
# 44                                                (X)
# 45                                                (X)
#
#     Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 44                                                 49
# 45                                                566
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!Under 5 years  \
# 44                                                 38
# 45                                                241
#
#    Estimate!!Percent!!Total population!!AGE!!Under 5 years  \
# 44                                                3.6
# 45                                                5.8
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!Under 5 years  \
# 44                                                2.7
# 45                                                2.3
#
#     Estimate!!Male!!Total population!!AGE!!Under 5 years  \
# 44                                                 12
# 45                                                255
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!Under 5 years  \
# 44                                                 15
# 45                                                132
#
#    Estimate!!Percent Male!!Total population!!AGE!!Under 5 years  \
# 44                                                1.7
# 45                                                5.1
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!Under 5 years  \
# 44                                                2.2
# 45                                                2.5
#
#     Estimate!!Female!!Total population!!AGE!!Under 5 years  \
# 44                                                 37
# 45                                                311
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!Under 5 years  \
# 44                                                 34
# 45                                                148
#
#    Estimate!!Percent Female!!Total population!!AGE!!Under 5 years  \
# 44                                                5.5
# 45                                                6.5
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!Under 5 years  \
# 44                                                4.8
# 45                                                2.8
#
#     Estimate!!Total!!Total population!!AGE!!5 to 9 years  \
# 44                                                 81
# 45                                                651
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!5 to 9 years  \
# 44                                                 50
# 45                                                187
#
#    Estimate!!Percent!!Total population!!AGE!!5 to 9 years  \
# 44                                                5.9
# 45                                                6.6
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!5 to 9 years  \
# 44                                                3.6
# 45                                                1.8
#
#     Estimate!!Male!!Total population!!AGE!!5 to 9 years  \
# 44                                                 53
# 45                                                303
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!5 to 9 years  \
# 44                                                 37
# 45                                                100
#
#    Estimate!!Percent Male!!Total population!!AGE!!5 to 9 years  \
# 44                                                7.5
# 45                                                6.1
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!5 to 9 years  \
# 44                                                5.0
# 45                                                2.0
#
#     Estimate!!Female!!Total population!!AGE!!5 to 9 years  \
# 44                                                 28
# 45                                                348
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!5 to 9 years  \
# 44                                                 24
# 45                                                143
#
#    Estimate!!Percent Female!!Total population!!AGE!!5 to 9 years  \
# 44                                                4.2
# 45                                                7.2
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!5 to 9 years  \
# 44                                                3.6
# 45                                                2.7
#
#     Estimate!!Total!!Total population!!AGE!!10 to 14 years  \
# 44                                                 52
# 45                                                672
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!10 to 14 years  \
# 44                                                 27
# 45                                                144
#
#    Estimate!!Percent!!Total population!!AGE!!10 to 14 years  \
# 44                                                3.8
# 45                                                6.9
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!10 to 14 years  \
# 44                                                1.8
# 45                                                1.5
#
#     Estimate!!Male!!Total population!!AGE!!10 to 14 years  \
# 44                                                 35
# 45                                                300
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!10 to 14 years  \
# 44                                                 22
# 45                                                111
#
#    Estimate!!Percent Male!!Total population!!AGE!!10 to 14 years  \
# 44                                                5.0
# 45                                                6.0
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!10 to 14 years  \
# 44                                                3.1
# 45                                                2.1
#
#     Estimate!!Female!!Total population!!AGE!!10 to 14 years  \
# 44                                                 17
# 45                                                372
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!10 to 14 years  \
# 44                                                 14
# 45                                                116
#
#    Estimate!!Percent Female!!Total population!!AGE!!10 to 14 years  \
# 44                                                2.5
# 45                                                7.7
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!10 to 14 years  \
# 44                                                2.0
# 45                                                2.4
#
#     Estimate!!Total!!Total population!!AGE!!15 to 19 years  \
# 44                                                 58
# 45                                                554
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!15 to 19 years  \
# 44                                                 39
# 45                                                208
#
#    Estimate!!Percent!!Total population!!AGE!!15 to 19 years  \
# 44                                                4.2
# 45                                                5.6
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!15 to 19 years  \
# 44                                                2.8
# 45                                                2.1
#
#     Estimate!!Male!!Total population!!AGE!!15 to 19 years  \
# 44                                                 28
# 45                                                197
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!15 to 19 years  \
# 44                                                 27
# 45                                                102
#
#    Estimate!!Percent Male!!Total population!!AGE!!15 to 19 years  \
# 44                                                4.0
# 45                                                3.9
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!15 to 19 years  \
# 44                                                3.9
# 45                                                2.0
#
#     Estimate!!Female!!Total population!!AGE!!15 to 19 years  \
# 44                                                 30
# 45                                                357
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!15 to 19 years  \
# 44                                                 26
# 45                                                139
#
#    Estimate!!Percent Female!!Total population!!AGE!!15 to 19 years  \
# 44                                                4.5
# 45                                                7.4
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!15 to 19 years  \
# 44                                                3.7
# 45                                                2.9
#
#     Estimate!!Total!!Total population!!AGE!!20 to 24 years  \
# 44                                                 15
# 45                                                698
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!20 to 24 years  \
# 44                                                 16
# 45                                                168
#
#    Estimate!!Percent!!Total population!!AGE!!20 to 24 years  \
# 44                                                1.1
# 45                                                7.1
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!20 to 24 years  \
# 44                                                1.1
# 45                                                1.7
#
#     Estimate!!Male!!Total population!!AGE!!20 to 24 years  \
# 44                                                  8
# 45                                                439
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!20 to 24 years  \
# 44                                                 11
# 45                                                139
#
#    Estimate!!Percent Male!!Total population!!AGE!!20 to 24 years  \
# 44                                                1.1
# 45                                                8.8
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!20 to 24 years  \
# 44                                                1.6
# 45                                                2.8
#
#     Estimate!!Female!!Total population!!AGE!!20 to 24 years  \
# 44                                                  7
# 45                                                259
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!20 to 24 years  \
# 44                                                 12
# 45                                                127
#
#    Estimate!!Percent Female!!Total population!!AGE!!20 to 24 years  \
# 44                                                1.0
# 45                                                5.4
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!20 to 24 years  \
# 44                                                1.7
# 45                                                2.6
#
#     Estimate!!Total!!Total population!!AGE!!25 to 29 years  \
# 44                                                 46
# 45                                                398
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!25 to 29 years  \
# 44                                                 32
# 45                                                171
#
#    Estimate!!Percent!!Total population!!AGE!!25 to 29 years  \
# 44                                                3.3
# 45                                                4.1
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!25 to 29 years  \
# 44                                                2.3
# 45                                                1.7
#
#     Estimate!!Male!!Total population!!AGE!!25 to 29 years  \
# 44                                                 20
# 45                                                258
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!25 to 29 years  \
# 44                                                 21
# 45                                                135
#
#    Estimate!!Percent Male!!Total population!!AGE!!25 to 29 years  \
# 44                                                2.8
# 45                                                5.2
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!25 to 29 years  \
# 44                                                3.1
# 45                                                2.6
#
#     Estimate!!Female!!Total population!!AGE!!25 to 29 years  \
# 44                                                 26
# 45                                                140
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!25 to 29 years  \
# 44                                                 31
# 45                                                 83
#
#    Estimate!!Percent Female!!Total population!!AGE!!25 to 29 years  \
# 44                                                3.9
# 45                                                2.9
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!25 to 29 years  \
# 44                                                4.5
# 45                                                1.7
#
#     Estimate!!Total!!Total population!!AGE!!30 to 34 years  \
# 44                                                 61
# 45                                                576
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!30 to 34 years  \
# 44                                                 39
# 45                                                179
#
#    Estimate!!Percent!!Total population!!AGE!!30 to 34 years  \
# 44                                                4.4
# 45                                                5.9
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!30 to 34 years  \
# 44                                                2.8
# 45                                                1.7
#
#     Estimate!!Male!!Total population!!AGE!!30 to 34 years  \
# 44                                                 25
# 45                                                315
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!30 to 34 years  \
# 44                                                 30
# 45                                                123
#
#    Estimate!!Percent Male!!Total population!!AGE!!30 to 34 years  \
# 44                                                3.5
# 45                                                6.3
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!30 to 34 years  \
# 44                                                4.3
# 45                                                2.4
#
#     Estimate!!Female!!Total population!!AGE!!30 to 34 years  \
# 44                                                 36
# 45                                                261
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!30 to 34 years  \
# 44                                                 23
# 45                                                 93
#
#    Estimate!!Percent Female!!Total population!!AGE!!30 to 34 years  \
# 44                                                5.3
# 45                                                5.4
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!30 to 34 years  \
# 44                                                3.5
# 45                                                1.7
#
#     Estimate!!Total!!Total population!!AGE!!35 to 39 years  \
# 44                                                 55
# 45                                                569
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!35 to 39 years  \
# 44                                                 39
# 45                                                159
#
#    Estimate!!Percent!!Total population!!AGE!!35 to 39 years  \
# 44                                                4.0
# 45                                                5.8
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!35 to 39 years  \
# 44                                                2.8
# 45                                                1.6
#
#     Estimate!!Male!!Total population!!AGE!!35 to 39 years  \
# 44                                                 24
# 45                                                316
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!35 to 39 years  \
# 44                                                 29
# 45                                                110
#
#    Estimate!!Percent Male!!Total population!!AGE!!35 to 39 years  \
# 44                                                3.4
# 45                                                6.3
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!35 to 39 years  \
# 44                                                4.0
# 45                                                2.2
#
#     Estimate!!Female!!Total population!!AGE!!35 to 39 years  \
# 44                                                 31
# 45                                                253
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!35 to 39 years  \
# 44                                                 26
# 45                                                 92
#
#    Estimate!!Percent Female!!Total population!!AGE!!35 to 39 years  \
# 44                                                4.6
# 45                                                5.3
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!35 to 39 years  \
# 44                                                3.7
# 45                                                2.0
#
#     Estimate!!Total!!Total population!!AGE!!40 to 44 years  \
# 44                                                173
# 45                                                684
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!40 to 44 years  \
# 44                                                 56
# 45                                                210
#
#    Estimate!!Percent!!Total population!!AGE!!40 to 44 years  \
# 44                                               12.5
# 45                                                7.0
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!40 to 44 years  \
# 44                                                3.8
# 45                                                2.1
#
#     Estimate!!Male!!Total population!!AGE!!40 to 44 years  \
# 44                                                 82
# 45                                                338
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!40 to 44 years  \
# 44                                                 30
# 45                                                128
#
#    Estimate!!Percent Male!!Total population!!AGE!!40 to 44 years  \
# 44                                               11.6
# 45                                                6.8
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!40 to 44 years  \
# 44                                                4.0
# 45                                                2.6
#
#     Estimate!!Female!!Total population!!AGE!!40 to 44 years  \
# 44                                                 91
# 45                                                346
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!40 to 44 years  \
# 44                                                 39
# 45                                                114
#
#    Estimate!!Percent Female!!Total population!!AGE!!40 to 44 years  \
# 44                                               13.5
# 45                                                7.2
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!40 to 44 years  \
# 44                                                5.8
# 45                                                2.3
#
#     Estimate!!Total!!Total population!!AGE!!45 to 49 years  \
# 44                                                 54
# 45                                                750
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!45 to 49 years  \
# 44                                                 37
# 45                                                211
#
#    Estimate!!Percent!!Total population!!AGE!!45 to 49 years  \
# 44                                                3.9
# 45                                                7.6
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!45 to 49 years  \
# 44                                                2.7
# 45                                                1.9
#
#     Estimate!!Male!!Total population!!AGE!!45 to 49 years  \
# 44                                                 30
# 45                                                465
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!45 to 49 years  \
# 44                                                 25
# 45                                                163
#
#    Estimate!!Percent Male!!Total population!!AGE!!45 to 49 years  \
# 44                                                4.3
# 45                                                9.3
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!45 to 49 years  \
# 44                                                3.5
# 45                                                3.0
#
#     Estimate!!Female!!Total population!!AGE!!45 to 49 years  \
# 44                                                 24
# 45                                                285
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!45 to 49 years  \
# 44                                                 26
# 45                                                100
#
#    Estimate!!Percent Female!!Total population!!AGE!!45 to 49 years  \
# 44                                                3.6
# 45                                                5.9
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!45 to 49 years  \
# 44                                                3.8
# 45                                                2.0
#
#     Estimate!!Total!!Total population!!AGE!!50 to 54 years  \
# 44                                                140
# 45                                                842
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!50 to 54 years  \
# 44                                                 73
# 45                                                178
#
#    Estimate!!Percent!!Total population!!AGE!!50 to 54 years  \
# 44                                               10.2
# 45                                                8.6
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!50 to 54 years  \
# 44                                                5.1
# 45                                                1.8
#
#     Estimate!!Male!!Total population!!AGE!!50 to 54 years  \
# 44                                                 72
# 45                                                366
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!50 to 54 years  \
# 44                                                 67
# 45                                                122
#
#    Estimate!!Percent Male!!Total population!!AGE!!50 to 54 years  \
# 44                                               10.2
# 45                                                7.3
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!50 to 54 years  \
# 44                                                9.1
# 45                                                2.5
#
#     Estimate!!Female!!Total population!!AGE!!50 to 54 years  \
# 44                                                 68
# 45                                                476
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!50 to 54 years  \
# 44                                                 36
# 45                                                132
#
#    Estimate!!Percent Female!!Total population!!AGE!!50 to 54 years  \
# 44                                               10.1
# 45                                                9.9
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!50 to 54 years  \
# 44                                                5.0
# 45                                                2.7
#
#     Estimate!!Total!!Total population!!AGE!!55 to 59 years  \
# 44                                                185
# 45                                                820
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!55 to 59 years  \
# 44                                                 58
# 45                                                215
#
#    Estimate!!Percent!!Total population!!AGE!!55 to 59 years  \
# 44                                               13.4
# 45                                                8.4
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!55 to 59 years  \
# 44                                                3.9
# 45                                                2.2
#
#     Estimate!!Male!!Total population!!AGE!!55 to 59 years  \
# 44                                                107
# 45                                                400
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!55 to 59 years  \
# 44                                                 50
# 45                                                158
#
#    Estimate!!Percent Male!!Total population!!AGE!!55 to 59 years  \
# 44                                               15.2
# 45                                                8.0
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!55 to 59 years  \
# 44                                                6.7
# 45                                                3.2
#
#     Estimate!!Female!!Total population!!AGE!!55 to 59 years  \
# 44                                                 78
# 45                                                420
#
#    Estimate!!Percent Female!!Total population!!AGE!!55 to 59 years  \
# 44                                               11.6
# 45                                                8.7
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!55 to 59 years  \
# 44                                                5.6
# 45                                                2.7
#
#     Estimate!!Total!!Total population!!AGE!!60 to 64 years  \
# 44                                                133
# 45                                                595
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!60 to 64 years  \
# 44                                                 52
# 45                                                227
#
#    Estimate!!Percent!!Total population!!AGE!!60 to 64 years  \
# 44                                                9.6
# 45                                                6.1
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!60 to 64 years  \
# 44                                                3.6
# 45                                                2.3
#
#     Estimate!!Male!!Total population!!AGE!!60 to 64 years  \
# 44                                                 73
# 45                                                277
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!60 to 64 years  \
# 44                                                 38
# 45                                                128
#
#    Estimate!!Percent Male!!Total population!!AGE!!60 to 64 years  \
# 44                                               10.4
# 45                                                5.5
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!60 to 64 years  \
# 44                                                5.4
# 45                                                2.6
#
#     Estimate!!Female!!Total population!!AGE!!60 to 64 years  \
# 44                                                 60
# 45                                                318
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!60 to 64 years  \
# 44                                                 29
# 45                                                141
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!55 to 59 years  \
# 44                                                 39
# 45                                                128
#
#    Estimate!!Percent Female!!Total population!!AGE!!60 to 64 years  \
# 44                                                8.9
# 45                                                6.6
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!60 to 64 years  \
# 44                                                4.4
# 45                                                3.0
#
#     Estimate!!Total!!Total population!!AGE!!65 to 69 years  \
# 44                                                117
# 45                                                545
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!65 to 69 years  \
# 44                                                 38
# 45                                                157
#
#    Estimate!!Percent!!Total population!!AGE!!65 to 69 years  \
# 44                                                8.5
# 45                                                5.6
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!65 to 69 years  \
# 44                                                2.6
# 45                                                1.5
#
#     Estimate!!Male!!Total population!!AGE!!65 to 69 years  \
# 44                                                 74
# 45                                                294
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!65 to 69 years  \
# 44                                                 30
# 45                                                132
#
#    Estimate!!Percent Male!!Total population!!AGE!!65 to 69 years  \
# 44                                               10.5
# 45                                                5.9
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!65 to 69 years  \
# 44                                                3.9
# 45                                                2.6
#
#     Estimate!!Female!!Total population!!AGE!!65 to 69 years  \
# 44                                                 43
# 45                                                251
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!65 to 69 years  \
# 44                                                 23
# 45                                                 87
#
#    Estimate!!Percent Female!!Total population!!AGE!!65 to 69 years  \
# 44                                                6.4
# 45                                                5.2
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!65 to 69 years  \
# 44                                                3.3
# 45                                                1.7
#
#     Estimate!!Total!!Total population!!AGE!!70 to 74 years  \
# 44                                                104
# 45                                                294
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!70 to 74 years  \
# 44                                                 42
# 45                                                132
#
#    Estimate!!Percent!!Total population!!AGE!!70 to 74 years  \
# 44                                                7.5
# 45                                                3.0
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!70 to 74 years  \
# 44                                                3.2
# 45                                                1.3
#
#     Estimate!!Male!!Total population!!AGE!!70 to 74 years  \
# 44                                                 35
# 45                                                156
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!70 to 74 years  \
# 44                                                 26
# 45                                                 87
#
#    Estimate!!Percent Male!!Total population!!AGE!!70 to 74 years  \
# 44                                                5.0
# 45                                                3.1
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!70 to 74 years  \
# 44                                                3.7
# 45                                                1.7
#
#     Estimate!!Female!!Total population!!AGE!!70 to 74 years  \
# 44                                                 69
# 45                                                138
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!70 to 74 years  \
# 44                                                 30
# 45                                                 78
#
#    Estimate!!Percent Female!!Total population!!AGE!!70 to 74 years  \
# 44                                               10.2
# 45                                                2.9
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!70 to 74 years  \
# 44                                                4.4
# 45                                                1.6
#
#     Estimate!!Total!!Total population!!AGE!!75 to 79 years  \
# 44                                                 28
# 45                                                278
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!75 to 79 years  \
# 44                                                 24
# 45                                                132
#
#    Estimate!!Percent!!Total population!!AGE!!75 to 79 years  \
# 44                                                2.0
# 45                                                2.8
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!75 to 79 years  \
# 44                                                1.8
# 45                                                1.3
#
#     Estimate!!Male!!Total population!!AGE!!75 to 79 years  \
# 44                                                 21
# 45                                                185
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!75 to 79 years  \
# 44                                                 23
# 45                                                102
#
#    Estimate!!Percent Male!!Total population!!AGE!!75 to 79 years  \
# 44                                                3.0
# 45                                                3.7
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!75 to 79 years  \
# 44                                                3.2
# 45                                                2.0
#
#     Estimate!!Female!!Total population!!AGE!!75 to 79 years  \
# 44                                                  7
# 45                                                 93
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!75 to 79 years  \
# 44                                                 11
# 45                                                 60
#
#    Estimate!!Percent Female!!Total population!!AGE!!75 to 79 years  \
# 44                                                1.0
# 45                                                1.9
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!75 to 79 years  \
# 44                                                1.6
# 45                                                1.3
#
#     Estimate!!Total!!Total population!!AGE!!80 to 84 years  \
# 44                                                 18
# 45                                                117
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!80 to 84 years  \
# 44                                                 19
# 45                                                 74
#
#    Estimate!!Percent!!Total population!!AGE!!80 to 84 years  \
# 44                                                1.3
# 45                                                1.2
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!80 to 84 years  \
# 44                                                1.4
# 45                                                0.7
#
#     Estimate!!Male!!Total population!!AGE!!80 to 84 years  \
# 44                                                  6
# 45                                                 81
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!80 to 84 years  \
# 44                                                  8
# 45                                                 66
#
#    Estimate!!Percent Male!!Total population!!AGE!!80 to 84 years  \
# 44                                                0.9
# 45                                                1.6
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!80 to 84 years  \
# 44                                                1.2
# 45                                                1.3
#
#     Estimate!!Female!!Total population!!AGE!!80 to 84 years  \
# 44                                                 12
# 45                                                 36
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!80 to 84 years  \
# 44                                                 12
# 45                                                 28
#
#    Estimate!!Percent Female!!Total population!!AGE!!80 to 84 years  \
# 44                                                1.8
# 45                                                0.7
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!80 to 84 years  \
# 44                                                1.8
# 45                                                0.6
#
#     Estimate!!Total!!Total population!!AGE!!85 years and over  \
# 44                                                 10
# 45                                                201
#
#     Margin of Error!!Total MOE!!Total population!!AGE!!85 years and over  \
# 44                                                 14
# 45                                                168
#
#    Estimate!!Percent!!Total population!!AGE!!85 years and over  \
# 44                                                0.7
# 45                                                2.0
#
#    Margin of Error!!Percent MOE!!Total population!!AGE!!85 years and over  \
# 44                                                1.0
# 45                                                1.7
#
#     Estimate!!Male!!Total population!!AGE!!85 years and over  \
# 44                                                  0
# 45                                                 55
#
#     Margin of Error!!Male MOE!!Total population!!AGE!!85 years and over  \
# 44                                                 13
# 45                                                 62
#
#    Estimate!!Percent Male!!Total population!!AGE!!85 years and over  \
# 44                                                0.0
# 45                                                1.1
#
#    Margin of Error!!Percent Male MOE!!Total population!!AGE!!85 years and over  \
# 44                                                5.5
# 45                                                1.2
#
#     Estimate!!Female!!Total population!!AGE!!85 years and over  \
# 44                                                 10
# 45                                                146
#
#     Margin of Error!!Female MOE!!Total population!!AGE!!85 years and over  \
# 44                                                 14
# 45                                                131
#
#    Estimate!!Percent Female!!Total population!!AGE!!85 years and over  \
# 44                                                1.5
# 45                                                3.0
#
#    Margin of Error!!Percent Female MOE!!Total population!!AGE!!85 years and over  \
# 44                                                2.0
# 45                                                2.7
#
#     Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years  \
# 44                                                133
# 45                                               1323
#
#     Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years  \
# 44                                                 66
# 45                                                258
#
# ...
# 45                                                (X)
#
#    Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                               58.3
# 45                                               60.2
#
#    Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                               11.3
# 45                                                5.7
#
#    Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Total!!PERCENT ALLOCATED!!Sex  \
# 44                                     (X)
# 45                                     (X)
#
#    Margin of Error!!Total MOE!!PERCENT ALLOCATED!!Sex  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent!!PERCENT ALLOCATED!!Sex  \
# 44                                       0.0
# 45                                       0.0
#
#    Margin of Error!!Percent MOE!!PERCENT ALLOCATED!!Sex  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Male!!PERCENT ALLOCATED!!Sex  \
# 44                                    (X)
# 45                                    (X)
#
#    Margin of Error!!Male MOE!!PERCENT ALLOCATED!!Sex  \
# 44                                               (X)
# 45                                               (X)
#
#    Estimate!!Percent Male!!PERCENT ALLOCATED!!Sex  \
# 44                                            (X)
# 45                                            (X)
#
#    Margin of Error!!Percent Male MOE!!PERCENT ALLOCATED!!Sex  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                               31.8
# 45                                               23.4
#
#    Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                               10.1
# 45                                                4.6
#
#    Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                               26.5
# 45                                               36.8
#
#    Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                7.4
# 45                                                3.5
#
#    Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Female!!PERCENT ALLOCATED!!Sex  \
# 44                                      (X)
# 45                                      (X)
#
#    Margin of Error!!Female MOE!!PERCENT ALLOCATED!!Sex  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Female!!PERCENT ALLOCATED!!Sex  \
# 44                                              (X)
# 45                                              (X)
#
#    Margin of Error!!Percent Female MOE!!PERCENT ALLOCATED!!Sex  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Total!!PERCENT ALLOCATED!!Age  \
# 44                                     (X)
# 45                                     (X)
#
#    Margin of Error!!Total MOE!!PERCENT ALLOCATED!!Age  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent!!PERCENT ALLOCATED!!Age  \
# 44                                       1.6
# 45                                       0.6
#
#    Margin of Error!!Percent MOE!!PERCENT ALLOCATED!!Age  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Male!!PERCENT ALLOCATED!!Age  \
# 44                                    (X)
# 45                                    (X)
#
#    Margin of Error!!Male MOE!!PERCENT ALLOCATED!!Age  \
# 44                                               (X)
# 45                                               (X)
#
#    Estimate!!Percent Male!!PERCENT ALLOCATED!!Age  \
# 44                                            (X)
# 45                                            (X)
#
#    Margin of Error!!Percent Male MOE!!PERCENT ALLOCATED!!Age  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Female!!PERCENT ALLOCATED!!Age  \
# 44                                      (X)
# 45                                      (X)
#
#    Margin of Error!!Female MOE!!PERCENT ALLOCATED!!Age  \
# 44                                                (X)
# 45                                                (X)
#
#    Estimate!!Percent Female!!PERCENT ALLOCATED!!Age  \
# 44                                              (X)
# 45                                              (X)
#
#    Margin of Error!!Percent Female MOE!!PERCENT ALLOCATED!!Age
# 44                                                (X)
# 45                                                (X)

# %%
age_group_to_column_endings = {'<18': ['Under 18 years'],
                               '18-24': ['18 to 24'],
                               '25-34': ['25 to 29', '30 to 34'],
                               '35-49': ['35 to 39', '40 to 44', '45 to 49'],
                               '50-59': ['50 to 54', '55 to 59'],
                               '60-64': ['60 to 64'],
                               '65-74': ['65 to 69', '70 to 74'],
                               '75+': ['75 to 79', '80 to 84', '85 years and over']}

# %%
age_breakdown_df = pd.DataFrame(age_demographics_df['ct_key'])

# %%
for age_group, column_endings in age_group_to_column_endings.items():
    cnt_array = np.zeros(len(age_demographics_df))
    for column_ending in column_endings:
        relevant_column = [column for column in age_demographics_df.columns
                           if (column.startswith('Estimate!!Total') 
                               and column.split('!!')[-1].startswith(column_ending))][0]
        cnt_array += age_demographics_df[relevant_column]
    age_breakdown_df[age_group] = cnt_array / age_demographics_df['census_population']

# %%
age_breakdown_df.head()
# Out:
#          ct_key       <18     18-24     25-34     35-49     50-59     60-64  \
# 44  13015960101  0.167513  0.017404  0.077592  0.204496  0.235678  0.096447
# 45  13015960102  0.229460  0.090724  0.099286  0.204179  0.169419  0.060652
# 46  13015960200  0.265806  0.101862  0.110379  0.231735  0.143484  0.037671
# 47  13015960300  0.233067  0.060848  0.096981  0.233380  0.128891  0.073674
# 48  13015960401  0.265298  0.101355  0.165537  0.217162  0.116006  0.025414
#
#        65-74       75+
# 44  0.160261  0.040609
# 45  0.085525  0.060754
# 46  0.064454  0.044608
# 47  0.121226  0.051932
# 48  0.067371  0.041858

# %%
ct_stats_df = ct_stats_df.merge(age_breakdown_df, on='ct_key', how='left')

# %% [markdown]
# ### Racial demographics

# %%
# ACS demographic and housing estimates (2018: ACS 5-Year Estimates Data Profiles)
# (https://data.census.gov/cedsci/table?t=Housing&g=0400000US08.140000&tid=ACSDP5Y2010.DP05&hidePreview=false)
racial_demographics_df = read_in_dataset('racial_demographics')

# %%
race_to_column_ending = {'Hispanic': 'Hispanic or Latino (of any race)',
                         'White': 'White alone',
                         'Black': 'Black or African American alone',
                         'Asian': 'Asian alone'}

# %%
racial_breakdown_df = pd.DataFrame(racial_demographics_df['ct_key'])

# %%
for race, column_ending in race_to_column_ending.items():
    relevant_column = [column for column in racial_demographics_df.columns
                       if column.startswith('Estimate') and column.split('!!')[-1] == column_ending][0]
    racial_breakdown_df[race] = (racial_demographics_df[relevant_column] / 
                                 racial_demographics_df['Estimate!!RACE!!Total population'])

# %%
for race in race_to_column_ending:
    print(f'percentage of population in market area that is {race}:', 
          round(100 * np.mean(racial_breakdown_df[race]), 2))
# Out:
# percentage of population in market area that is Hispanic: 9.66
# percentage of population in market area that is White: 45.05
# percentage of population in market area that is Black: 36.98
# percentage of population in market area that is Asian: 5.74

# %%
ct_stats_df = ct_stats_df.merge(racial_breakdown_df, on='ct_key', how='left')

# %% [markdown]
# ### Population growth

# %%
sorted_filenames = ['ACSST5Y' + str(year) + '.S0101_data_with_overlays_2020-11-12T155736.csv'
                    for year in range(2010, 2019)]

ct_key_to_population_trend = defaultdict(list)

age_demographics_directory = f'{data_dir}/age_demographics_2010_2018'
for f in sorted_filenames:
    df = pd.read_csv(f'{age_demographics_directory}/{f}', header=1)
    df = convert_to_ct_key(df)
    try:
        population_column = 'Total!!Estimate!!Total population'
        df = df[['ct_key', population_column]]
    except KeyError:
        population_column = 'Estimate!!Total!!Total population'
        df = df[['ct_key', population_column]]
    
    for _, row in df.iterrows():
        ct_key_to_population_trend[row['ct_key']].append(row[population_column])

# %%
market_area_census_tracts = set(ct_stats_df['ct_key'])

# %%
lin_reg = LinearRegression()

# clip zipcodes that grow faster than an average of 10% per year
def calculate_growth_rate(population_trend, max_annual_growth=0.1):
    lin_reg.fit(np.arange(len(population_trend)).reshape(-1, 1), population_trend)
    slope = lin_reg.coef_[0] / population_trend[0]
    avg_yoy_change = np.mean([(population_trend[i + 1] - population_trend[i]) / population_trend[i] 
                               for i in range(len(population_trend) - 1)])
    
    return min(slope, max_annual_growth), min(avg_yoy_change, max_annual_growth)

# %%
population_growth_rate_lst = []
for ct_key, population_trend in ct_key_to_population_trend.items():
    if ct_key in market_area_census_tracts:
        population_trend_last_5_years = population_trend[-5:]
        slope_9_yr, avg_yoy_change_9_yr = calculate_growth_rate(population_trend)
        slope_5_yr, avg_yoy_change_5_yr = calculate_growth_rate(population_trend_last_5_years)
        population_growth_rate_lst.append((ct_key, slope_9_yr, avg_yoy_change_9_yr, 
                                           slope_5_yr, avg_yoy_change_5_yr))

# %%
columns = ['ct_key', 'linear_pop_trend_since_2010', 'avg_annual_pop_change_since_2010',
           'linear_pop_trend_since_2014', 'avg_annual_pop_change_since_2014']
ct_population_growth_df = pd.DataFrame(population_growth_rate_lst, columns=columns)

# %%
ct_population_growth_df.head()
# Out:
#         ct_key  linear_pop_trend_since_2010  avg_annual_pop_change_since_2010  \
# 0  13057090100                     0.040542                          0.041156
# 1  13057090200                     0.027875                          0.026006
# 2  13057090300                     0.020663                          0.020272
# 3  13057090400                     0.022455                          0.013112
# 4  13057090501                     0.030781                          0.027362
#
#    linear_pop_trend_since_2014  avg_annual_pop_change_since_2014
# 0                     0.022623                          0.028453
# 1                     0.029781                          0.029761
# 2                    -0.001373                         -0.003733
# 3                    -0.008821                         -0.007426
# 4                     0.028871                          0.023583

# %%
plt.figure(figsize=(20, 10))
plt.hist(ct_population_growth_df['avg_annual_pop_change_since_2010'], bins=20, alpha=0.5,
         label='avg_annual_pop_change_since_2010')
plt.hist(ct_population_growth_df['linear_pop_trend_since_2010'], bins=20, alpha=0.5,
         label='linear_pop_trend_since_2010')
plt.hist(ct_population_growth_df['avg_annual_pop_change_since_2014'], bins=20, alpha=0.5,
         label='avg_annual_pop_change_since_2014')
plt.hist(ct_population_growth_df['linear_pop_trend_since_2014'], bins=20, alpha=0.5,
         label='linear_pop_trend_since_2014')
plt.xlabel('annual percent change')
plt.ylabel('number of census tracts')
plt.legend()
plt.show()

# %%
ct_stats_df = ct_stats_df.merge(ct_population_growth_df, on='ct_key', how='left')

# %% [markdown]
# ### Fertility

# %%
# Fertility 
# https://data.census.gov/cedsci/table?t=Fertility&g=0400000US08.140000&tid=ACSST5Y2018.S1301&hidePreview=false
fertility_df = read_in_dataset('fertility')
fertility_df.rename({'Estimate!!Women with births in the past 12 months!!Number!!Women 15 to 50 years': 
                     'number_of_births'}, axis=1, inplace=True)

# %%
fertility_df = fertility_df[['ct_key', 'number_of_births']]
fertility_df = fertility_df.merge(ct_stats_df[['ct_key', 'census_population']], on='ct_key', how='right')
fertility_df['annual_births_per_resident'] = fertility_df['number_of_births'] / fertility_df['census_population']

# %%
fertility_df.head()
# Out:
#         ct_key  number_of_births  census_population  \
# 0  13015960101                24               1379
# 1  13015960102                67               9810
# 2  13015960200               175              11388
# 3  13015960300               134               6393
# 4  13015960401                86              10034
#
#    annual_births_per_resident
# 0                    0.017404
# 1                    0.006830
# 2                    0.015367
# 3                    0.020960
# 4                    0.008571

# %%
plt.figure(figsize=(20, 10))
plt.hist(fertility_df['annual_births_per_resident'], bins=20)
plt.xlabel('annual_births_per_resident')
plt.ylabel('number of census tracts')
plt.show()

# %%
ct_stats_df = ct_stats_df.merge(fertility_df[['ct_key', 'annual_births_per_resident']], on='ct_key', how='left')

# %% [markdown]
# ### Commuting

# %%
# MEANS OF TRANSPORTATION TO WORK BY TENURE
# https://data.census.gov/cedsci/table?t=Housing&g=0400000US08.140000&tid=ACSDT5Y2018.B08137&hidePreview=false
commuting_df = read_in_dataset('commuting_mode')
commuting_df.rename({'Estimate!!Total': 'workforce_size'}, axis=1, inplace=True)

# %%
commuting_df = commuting_df.merge(ct_stats_df[['ct_key', 'census_population']], on='ct_key', how='right')
commuting_df['workforce_fraction'] = commuting_df['workforce_size'] / commuting_df['census_population']
transit_mode_df = commuting_df[['ct_key', 'workforce_fraction']]

# %%
plt.figure(figsize=(20, 10))
plt.hist(transit_mode_df['workforce_fraction'], bins=20)
plt.xlabel('fraction of population in workforce')
plt.ylabel('number of census tracts')
plt.show()

# %%
transit_mode_to_column_ending = {'car': 'Car, truck, or van - drove alone', 
                                 'carpool': 'Car, truck, or van - carpooled',
                                 'public_transportation': 'Public transportation',
                                 'walk': 'Walked',
                                 'WFH': 'Worked at home',
                                 'other_mode_of_transit': 'Taxicab, motorcycle, bicycle'}

# %%
for transit_mode, column_ending in transit_mode_to_column_ending.items():
    relevant_column = [column for column in commuting_df.columns
                       if (column.startswith('Estimate!!Total') 
                           and column.split('!!')[-1].startswith(column_ending))][0]
    transit_mode_df[transit_mode] = commuting_df[relevant_column] / commuting_df['workforce_size']

# %%
transit_mode_df.head()
# Out:
#         ct_key  workforce_fraction       car   carpool  public_transportation  \
# 0  13015960101            0.498187  0.783115  0.100437               0.000000
# 1  13015960102            0.464730  0.808511  0.095416               0.010748
# 2  13015960200            0.484457  0.801704  0.103136               0.015588
# 3  13015960300            0.406851  0.848520  0.050365               0.014994
# 4  13015960401            0.497508  0.846554  0.113381               0.000000
#
#        walk       WFH  other_mode_of_transit
# 0  0.000000  0.096070               0.020378
# 1  0.000000  0.071946               0.013380
# 2  0.010694  0.056009               0.012869
# 3  0.000000  0.036909               0.049212
# 4  0.005409  0.025641               0.009014

# %%
for transit_mode in transit_mode_to_column_ending:
    plt.figure(figsize=(10, 4))
    plt.hist(transit_mode_df[transit_mode], bins=20)
    plt.xlabel(f'fraction of workforce that commutes by {transit_mode}')
    plt.ylabel('number of census tracts')

# %%
ct_stats_df = ct_stats_df.merge(transit_mode_df, on='ct_key', how='left')

# %% [markdown]
# ### Income

# %%
# INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)
# https://data.census.gov/cedsci/table?t=Income%20%28Households,%20Families,%20Individuals%29&g=0400000US08.140000&tid=ACSST5Y2018.S1901&hidePreview=false
income_df = read_in_dataset('income')
income_df = income_df[income_df['ct_key'].isin(market_area_census_tracts)]

# %% [markdown]
# According to https://www.census.gov/programs-surveys/cps/technical-documentation/subject-definitions.html
#
# A household consists of all the people who occupy a housing unit. A house, an apartment or other group of rooms, or a single room, is regarded as a housing unit when it is occupied or intended for occupancy as separate living quarters; that is, when the occupants do not live with any other persons in the structure and there is direct access from the outside or through a common hall.
#
# A household includes the related family members and all the unrelated people, if any, such as lodgers, foster children, wards, or employees who share the housing unit. A person living alone in a housing unit, or a group of unrelated people sharing a housing unit such as partners or roomers, is also counted as a household. The count of households excludes group quarters. There are two major categories of households, "family" and "nonfamily".
#
# A family is a group of two people or more (one of whom is the householder) related by birth, marriage, or adoption and residing together; all such people (including related subfamily members) are considered as members of one family.
#
# A nonfamily household consists of a householder living alone (a one-person household) or where the householder shares the home exclusively with people to whom he/she is not related.

# %%
column_to_new_column = {'Estimate!!Households!!Total': 'total_households',
                        'Estimate!!Families!!Total': 'total_families_households',
                        'Estimate!!Nonfamily households!!Total': 'total_nonfamily_households',
                        'Estimate!!Households!!Median income (dollars)': 'median_household_income',
                        'Estimate!!Families!!Median income (dollars)': 'median_family_income',
                        'Estimate!!Nonfamily households!!Median income (dollars)': 'median_nonfamily_income',
                        'Estimate!!Households!!Mean income (dollars)': 'mean_household_income',
                        'Estimate!!Families!!Mean income (dollars)': 'mean_family_income',
                        'Estimate!!Nonfamily households!!Mean income (dollars)': 'mean_nonfamily_income'}

# %%
income_df = income_df[['ct_key'] + list(column_to_new_column)]
income_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
income_df['family_households_fraction'] = income_df['total_families_households'] / income_df['total_households']
income_df['nonfamily_households_fraction'] = (income_df['total_nonfamily_households'] / 
                                              income_df['total_households'])

income_df.drop(['total_households', 'total_families_households', 'total_nonfamily_households'], axis=1,
               inplace=True)

# %%
income_df[(income_df['median_family_income'] == '-') |
          (income_df['median_nonfamily_income'] == '-') |
          (income_df['mean_nonfamily_income'] == 'N')]
# Out:
#            ct_key median_household_income median_family_income  \
# 44    13015960101                   72841                82688
# 47    13015960300                   63701                63703
# 359   13063040510                   45750                48042
# 415   13067030236                  144836               149300
# 416   13067030238                  111741               113750
# 605   13089020802                   63315                93906
# 698   13089023210                   38750                40641
# 854   13115000100                   44288                47176
# 887   13117130304                  124028               132222
# 891   13117130403                   73467                77313
# 942   13121002100                   47917                    -
# 953   13121003600                   43906                    -
# 970   13121005800                   31288                30000
# 1100  13121011426                  110650               111500
# 1103  13121011504                  209484               226184
# 1109  13121011613                  106417               121389
# 1120  13121011624                  198641               199402
# 1897  13297110507                   69661                65923
#
#      median_nonfamily_income mean_household_income mean_family_income  \
# 44                         -                 76531              83771
# 47                         -                 67210              70391
# 359                        -                 55700              59270
# 415                        -                162831             167830
# 416                        -                130582             134188
# 605                        -                104153             131619
# 698                        -                 43994              47455
# 854                        -                 54670              61022
# 887                        -                131916             141262
# 891                        -                 96430             103344
# 942                    46538                 79848             107075
# 953                    44115                 50765              57311
# 970                        -                 49001              48319
# 1100                       -                151116             160492
# 1103                       -                293219             308859
# 1109                       -                125805             133639
# 1120                       -                220846             223932
# 1897                       -                 86753              86053
#
#      mean_nonfamily_income  family_households_fraction  \
# 44                   51588                    0.724710
# 47                   37674                    0.846546
# 359                  41122                    0.708398
# 415                  31409                    0.963322
# 416                  69504                    0.936069
# 605                  49722                    0.636875
# 698                  35683                    0.648805
# 854                  34606                    0.751016
# 887                  68451                    0.871646
# 891                  55843                    0.838662
# 942                  63676                    0.369021
# 953                  49278                    0.185053
# 970                  49853                    0.555184
# 1100                 72949                    0.838451
# 1103                 73279                    0.930927
# 1109                 89308                    0.756193
# 1120                108444                    0.955409
# 1897                 69948                    0.839968
#
#       nonfamily_households_fraction
# 44                         0.275290
# 47                         0.153454
# 359                        0.291602
# 415                        0.036678
# 416                        0.063931
# 605                        0.363125
# 698                        0.351195
# 854                        0.248984
# 887                        0.128354
# 891                        0.161338
# 942                        0.630979
# 953                        0.814947
# 970                        0.444816
# 1100                       0.161549
# 1103                       0.069073
# 1109                       0.243807
# 1120                       0.044591
# 1897                       0.160032

# %%
income_df.replace(to_replace='250,000+', value='250000', inplace=True)

# %%
for summary_stat in ['median', 'mean']:
    col_name = f'{summary_stat}_household_income'
    mean_val = int(np.mean([int(x) for x in income_df[col_name] if x not in {'-', 'N'}]))
    income_df[col_name] = [mean_val if x in {'-', 'N'} else int(x) for x in income_df[col_name]]

# %%
for summary_stat in ['median', 'mean']:
    for family_type in ['family', 'nonfamily']:
        income_df[f'{summary_stat}_{family_type}_income'] = (
            income_df.apply(lambda x: x[f'{summary_stat}_household_income']                         
            if x[f'{summary_stat}_{family_type}_income'] in {'-', 'N'} 
            else x[f'{summary_stat}_{family_type}_income'], axis=1))

# %%
for column in income_df.columns:
    if column.split('_')[0] in {'median', 'mean'}:
        income_df[column] = income_df[column].astype(float)

# %%
plt.figure(figsize=(20, 8))
plt.hist(income_df['family_households_fraction'], bins=20)
plt.xlabel('fraction of households that are occupied by families')
plt.ylabel('number of census tracts')
plt.show()

# %%
for column in income_df.columns:
    if column.split('_')[0] in {'median', 'mean'}:
        plt.figure(figsize=(10, 4))
        plt.hist(income_df[column], bins=20)
        plt.xlabel(column)
        plt.ylabel('number of census tracts')
        plt.show()

# %%
ct_stats_df = ct_stats_df.merge(income_df, on='ct_key', how='left')

# %% [markdown]
# ### Poverty

# %%
# FOOD STAMPS/SUPPLEMENTAL NUTRITION ASSISTANCE PROGRAM (SNAP)
# https://data.census.gov/cedsci/table?t=SNAP%2FFood%20Stamps&g=0400000US08.140000&tid=ACSST5Y2018.S2201&hidePreview=false
food_stamps_df = read_in_dataset('food_stamps')

# %%
column_to_new_column = {
    'Estimate!!Percent!!Households!!POVERTY STATUS IN THE PAST 12 MONTHS!!At or above poverty level': 'above_poverty_line',
    'Estimate!!Percent households not receiving food stamps/SNAP!!Households!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level': 'below_poverty_line'
}

# %%
poverty_df = food_stamps_df[['ct_key'] + list(column_to_new_column)]
poverty_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
poverty_df.head()
# Out:
#          ct_key above_poverty_line below_poverty_line
# 44  13015960101               92.5                6.3
# 45  13015960102               90.8                7.5
# 46  13015960200               88.0               11.3
# 47  13015960300               89.1                9.4
# 48  13015960401               92.0                4.3

# %%
for column in ['above_poverty_line', 'below_poverty_line']:
    poverty_df[column] = [x if x != '-' else np.nan for x in poverty_df[column]]
    poverty_df[column] = poverty_df[column].astype(float)

# %%
plt.figure(figsize=(20, 10))
plt.hist(poverty_df['below_poverty_line'], bins=20)
plt.xlabel('fraction of households below poverty line')
plt.ylabel('number of census tracts')
plt.show()

# %%
ct_stats_df = ct_stats_df.merge(poverty_df, on='ct_key', how='left')

# %% [markdown]
# ### Occupation

# %%
# SELECTED ECONOMIC CHARACTERISTICS
# https://data.census.gov/cedsci/table?t=Income%20%28Households,%20Families,%20Individuals%29%3APoverty&g=0400000US08.140000&tid=ACSDP5Y2018.DP03&hidePreview=false
economic_df = read_in_dataset('economic_characteristics')

# %%
column_to_new_column = {
    'Percent Estimate!!INDUSTRY!!Civilian employed population 16 years and over!!Professional, scientific, and management, and administrative and waste management services': 'STEM_jobs',
    'Percent Estimate!!INDUSTRY!!Civilian employed population 16 years and over!!Educational services, and health care and social assistance': 'education&health_care'
}

# %%
occupation_df = economic_df[['ct_key'] + list(column_to_new_column)]
occupation_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
occupation_df.head()
# Out:
#          ct_key STEM_jobs education&health_care
# 44  13015960101       4.0                  20.4
# 45  13015960102       6.2                  23.3
# 46  13015960200       7.1                  17.3
# 47  13015960300       5.5                  15.3
# 48  13015960401       8.1                  18.9

# %%
for column in ['STEM_jobs', 'education&health_care']:
    occupation_df[column] = [x if x != '-' else np.nan for x in occupation_df[column]]
    occupation_df[column] = occupation_df[column].astype(float)

# %%
for column in ['STEM_jobs', 'education&health_care']:
    plt.figure(figsize=(20, 10))
    plt.hist(occupation_df[column], bins=20)
    plt.xlabel(column + ' percentage of jobs')
    plt.ylabel('number of census tracts')
    plt.show()

# %%
ct_stats_df = ct_stats_df.merge(occupation_df, on='ct_key', how='left')

# %% [markdown]
# ### Household size

# %%
# HOUSEHOLDS AND FAMILIES
household_size_df = read_in_dataset('household_size')

# %%
column_to_new_column = {
    'Estimate!!Total!!HOUSEHOLDS!!Total households': 'total_households',
    'Estimate!!Total!!FAMILIES!!Average family size': 'avg_family_size',
    'Estimate!!Married-couple family household!!HOUSEHOLDS!!Average household size': 'avg_married_family_size',
    'Estimate!!Nonfamily household!!HOUSEHOLDS!!Average household size': 'avg_nonfamily_size',
    'Estimate!!Total!!HOUSEHOLDS!!Average household size': 'avg_household_size'
}

# %%
household_size_df = household_size_df[['ct_key'] + list(column_to_new_column)]
household_size_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
household_size_df[(household_size_df['avg_family_size'] == '-') | 
                  (household_size_df['avg_married_family_size'] == '-') |
                  (household_size_df['avg_nonfamily_size'] == '-') |
                  (household_size_df['avg_household_size'] == '-')]
# Out:
#            ct_key  total_households avg_family_size avg_married_family_size  \
# 410   13067030231              2814            3.17                    3.27
# 415   13067030236              1445            3.32                    3.40
# 428   13067030326              1423            3.35                    3.57
# 438   13067030336              2398            3.22                    3.24
# 495   13067031309              2533            3.46                    3.32
# 699   13089023211              1355            3.87                    3.54
# 717   13089023414              2283            3.55                    3.53
# 836   13113140203              2071            3.09                    3.12
# 880   13117130202              1441            3.41                    3.46
# 914   13117130609              1842            3.64                    3.76
# 981   13121006802               567            4.86                    7.29
# 999   13121007806              2416            4.42                    3.90
# 1000  13121007807              1078            4.35                    3.12
# 1007  13121008202               740            3.65                    3.45
# 1040  13121010108              1541            3.00                    2.99
# 1069  13121010513              4906            3.64                    3.90
# 1194  13135050308              1254            3.49                    3.58
# 1750  13247060307              3695            3.35                    3.27
#
#      avg_nonfamily_size avg_household_size
# 410                   -               2.89
# 415                   -               3.26
# 428                   -               3.17
# 438                   -               3.02
# 495                   -               3.00
# 699                   -               2.61
# 717                   -               2.76
# 836                   -               2.83
# 880                   -               3.17
# 914                   -               3.54
# 981                   -               4.01
# 999                   -               3.00
# 1000                  -               3.12
# 1007                  -               2.86
# 1040                  -               2.47
# 1069                  -               2.93
# 1194                  -               3.27
# 1750                  -               2.88

# %%
for idx, row in household_size_df.iterrows():
    for column in ['avg_family_size', 'avg_married_family_size', 'avg_household_size']:
        if row[column] == '-':
            mean_val = np.mean([float(x) for x in household_size_df[column] if x != '-'])
            household_size_df.loc[idx, column] = mean_val
        if row['avg_nonfamily_size'] == '-':
            try:
                impute_val = 2 * float(row['avg_household_size']) - float(row['avg_family_size'])
            except ValueError:
                mean_avg_household_size = np.mean([float(x) for x in household_size_df['avg_household_size']
                                                   if x != '-'])
                mean_avg_family_size = np.mean([float(x) for x in household_size_df['avg_family_size']
                                                    if x != '-'])
                impute_val = 2 * mean_avg_household_size - mean_avg_family_size
            household_size_df.loc[idx, 'avg_nonfamily_size'] = impute_val

# %%
for column in list(column_to_new_column.values())[1:]:
    household_size_df[column] = household_size_df[column].astype(float)

# %%
for column in household_size_df.columns:
    if column != 'ct_key':
        plt.figure(figsize=(10, 6))
        plt.hist(household_size_df[column], bins=20)
        plt.xlabel(column)
        plt.ylabel('number of census tracts')
        plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(household_size_df['avg_married_family_size'] - household_size_df['avg_family_size'], bins=20)
plt.xlabel('difference between avg_married_family_size and avg_family_size')
plt.ylabel('number of census tracts')
plt.show()

# %%
household_size_df.drop('avg_married_family_size', axis=1, inplace=True, errors='ignore')

# %%
ct_stats_df = ct_stats_df.merge(household_size_df, on='ct_key', how='left')

# %% [markdown]
# ### Home Value

# %%
# VALUE (2018: ACS 5-Year Estimates Detailed Tables)
# https://data.census.gov/cedsci/table?t=Housing&g=0400000US08.140000&tid=ACSDT5Y2018.B25075&hidePreview=false
valuation_df = read_in_dataset('house_value')

# %% [markdown]
# Home price brackets:
# 1. `<200k`
# 2. `200-300k`
# 3. `300-400k`
# 3. `400-500k`
# 4. `500-750k`
# 5. `750k-1000k`
# 6. `>1M`

# %%
value_bracket_to_column_endings = {
    '<200k': ['$80,000 to $89,999', '$90,000 to $99,999', '$100,000 to $124,999', '$125,000 to $149,999',
              '$150,000 to $174,999', '$175,000 to $199,999'],
    '200-300k': ['$200,000 to $249,999', '$250,000 to $299,999'],
    '300-400k': ['$300,000 to $399,999'],
    '400-500k': ['$400,000 to $499,999'],
    '500-750k': ['$500,000 to $749,999'],
    '750-1000k': ['$750,000 to $999,999'],
    '>1M': ['$1,000,000 to $1,499,999', '$1,500,000 to $1,999,999', '$2,000,000 or more']
}

# %%
valuation_breakdown_df = pd.DataFrame(valuation_df['ct_key'])

# %%
columns_to_subtract = ['Less than $10,000', '$10,000 to $14,999', '$15,000 to $19,999', '$20,000 to $24,999',
                       '$25,000 to $29,999', '$30,000 to $34,999', '$35,000 to $39,999', '$40,000 to $49,999',
                       '$50,000 to $59,999', '$60,000 to $69,999', '$70,000 to $79,999']
total_homes = np.array(valuation_df['Estimate!!Total'])
for column in columns_to_subtract:
    total_homes -= np.array(valuation_df['Estimate!!Total!!' + column])
    
valuation_breakdown_df['total_homes'] = total_homes

# %%
for value_bracket, column_endings in value_bracket_to_column_endings.items():
    cnt_array = np.zeros(len(valuation_breakdown_df))
    for column_ending in column_endings:
        relevant_column = [column for column in valuation_df.columns
                           if column == 'Estimate!!Total!!' + column_ending][0]
        cnt_array += valuation_df[relevant_column]
    valuation_breakdown_df[value_bracket] = cnt_array / valuation_breakdown_df['total_homes']

# %%
valuation_breakdown_df.head()
# Out:
#          ct_key  total_homes     <200k  200-300k  300-400k  400-500k  \
# 3   13063040409          719  0.949930  0.043115  0.000000  0.000000
# 4   13063040410         1054  0.967742  0.030361  0.000000  0.001898
# 5   13063040509          700  0.977143  0.010000  0.012857  0.000000
# 6   13063040407          565  0.858407  0.127434  0.000000  0.000000
# 56  13089021602         1140  0.164912  0.250877  0.237719  0.182456
#
#     500-750k  750-1000k       >1M
# 3   0.006954   0.000000  0.000000
# 4   0.000000   0.000000  0.000000
# 5   0.000000   0.000000  0.000000
# 6   0.000000   0.010619  0.003540
# 56  0.136842   0.014035  0.013158

# %%
plt.figure(figsize=(20, 10))
plt.hist(valuation_breakdown_df['total_homes'], bins=20)
plt.xlabel('number of homes valued at over 80k')
plt.ylabel('humber of census tracts')
plt.show()

# %%
for column in valuation_breakdown_df.columns:
    if column not in {'ct_key', 'total_homes'}:
        plt.figure(figsize=(10, 4))
        plt.hist(valuation_breakdown_df[column], bins=20)
        plt.xlabel(f'fraction of homes valued in range: {column}')
        plt.ylabel('humber of census tracts')
        plt.show()

# %%
valuation_breakdown_df[valuation_breakdown_df['total_homes'] < 100]
# Out:
#            ct_key  total_homes     <200k  200-300k  300-400k  400-500k  \
# 63    13089022007           63  1.000000  0.000000  0.000000  0.000000
# 74    13089021204            0       NaN       NaN       NaN       NaN
# 170   13063040306           20  1.000000  0.000000  0.000000  0.000000
# 173   13063040414           48  1.000000  0.000000  0.000000  0.000000
# 174   13063040415           88  0.829545  0.170455  0.000000  0.000000
# 177   13063040519           19  1.000000  0.000000  0.000000  0.000000
# 594   13089022402           70  0.000000  0.057143  0.371429  0.414286
# 697   13121002300           49  0.775510  0.224490  0.000000  0.000000
# 698   13121002800           93  0.677419  0.182796  0.139785  0.000000
# 699   13121004800           11  0.000000  0.545455  0.454545  0.000000
# 707   13121005700           39  0.487179  0.512821  0.000000  0.000000
# 709   13121006602           55  0.763636  0.145455  0.090909  0.000000
# 727   13121006802           27  1.000000  0.000000  0.000000  0.000000
# 746   13121003800           11  1.000000  0.000000  0.000000  0.000000
# 774   13121006400           59  0.254237  0.067797  0.000000  0.372881
# 795   13121002600           56  0.928571  0.071429  0.000000  0.000000
# 796   13121004400           27  1.000000  0.000000  0.000000  0.000000
# 832   13121001002            7  0.000000  0.000000  0.428571  0.571429
# 835   13121007603           83  0.481928  0.518072  0.000000  0.000000
# 942   13121007807           63  0.873016  0.000000  0.000000  0.000000
# 943   13121007808           55  0.672727  0.327273  0.000000  0.000000
# 1001  13089021813            0       NaN       NaN       NaN       NaN
# 1073  13067030411           82  0.817073  0.000000  0.000000  0.182927
# 1074  13067030412           69  0.884058  0.115942  0.000000  0.000000
# 1076  13067030414            0       NaN       NaN       NaN       NaN
# 1393  13089021911           10  0.000000  0.000000  0.000000  0.000000
# 1395  13089021913           56  0.660714  0.142857  0.000000  0.000000
# 1396  13089022009           19  1.000000  0.000000  0.000000  0.000000
#
#       500-750k  750-1000k       >1M
# 63    0.000000        0.0  0.000000
# 74         NaN        NaN       NaN
# 170   0.000000        0.0  0.000000
# 173   0.000000        0.0  0.000000
# 174   0.000000        0.0  0.000000
# 177   0.000000        0.0  0.000000
# 594   0.157143        0.0  0.000000
# 697   0.000000        0.0  0.000000
# 698   0.000000        0.0  0.000000
# 699   0.000000        0.0  0.000000
# 707   0.000000        0.0  0.000000
# 709   0.000000        0.0  0.000000
# 727   0.000000        0.0  0.000000
# 746   0.000000        0.0  0.000000
# 774   0.305085        0.0  0.000000
# 795   0.000000        0.0  0.000000
# 796   0.000000        0.0  0.000000
# 832   0.000000        0.0  0.000000
# 835   0.000000        0.0  0.000000
# 942   0.000000        0.0  0.126984
# 943   0.000000        0.0  0.000000
# 1001       NaN        NaN       NaN
# 1073  0.000000        0.0  0.000000
# 1074  0.000000        0.0  0.000000
# 1076       NaN        NaN       NaN
# 1393  1.000000        0.0  0.000000
# 1395  0.196429        0.0  0.000000
# 1396  0.000000        0.0  0.000000

# %%
valuation_breakdown_df.drop('total_homes', axis=1, inplace=True, errors='ignore')
ct_stats_df = ct_stats_df.merge(valuation_breakdown_df, on='ct_key', how='left')

# %% [markdown]
# ### Marital Status

# %%
# MARITAL STATUS
marital_status_df = read_in_dataset('marital_status')

# %%
relationship_status_to_categories = {'married': ['Now married'],
                                     'divorced/separated/widowed': ['Widowed', 'Divorced', 'Separated'],
                                     'never_married': ['Never married']}

# %%
relationship_status_df = pd.DataFrame(marital_status_df['ct_key'])

# %%
for relationship_status, categories in relationship_status_to_categories.items():
    percent_array = np.zeros(len(relationship_status_df))
    for category in categories:
        relevant_column = [column for column in marital_status_df.columns
                           if column.startswith('Estimate!!' + category)][0]
        percent_array += marital_status_df[relevant_column].astype(float)
    relationship_status_df[relationship_status] = percent_array

# %%
relationship_status_df.head()
# Out:
#          ct_key  married  divorced/separated/widowed  never_married
# 44  13015960101     68.9                        23.3            7.8
# 45  13015960102     59.2                        20.5           20.3
# 46  13015960200     53.2                        23.4           23.4
# 47  13015960300     60.9                        19.6           19.5
# 48  13015960401     44.4                        25.1           30.4

# %%
for column in relationship_status_df.columns:
    if column != 'ct_key':
        plt.figure(figsize=(20, 10))
        plt.hist(relationship_status_df[column], bins=20)
        plt.xlabel(f'percent {column}')
        plt.ylabel('humber of census tracts')
        plt.show()

# %%
ct_stats_df = ct_stats_df.merge(relationship_status_df, on='ct_key', how='left')

# %% [markdown]
# ### Mortgage

# %%
# MORTGAGE STATUS
# https://data.census.gov/cedsci/table?q=ACSDT1Y2019.B25081&g=0400000US08.140000&tid=ACSDT5Y2018.B25081&hidePreview=true
mortgage_status_df = read_in_dataset('mortgage_status')

# %%
mortgage_status_df.head(2)
# Out:
#         ct_key                          Geographic Area Name  Estimate!!Total  \
# 3  13063040409  Census Tract 404.09, Clayton County, Georgia             1038
# 4  13063040410  Census Tract 404.10, Clayton County, Georgia             1656
#
#    Margin of Error!!Total  \
# 3                     144
# 4                     202
#
#    Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt  \
# 3                                                749
# 4                                               1142
#
#    Margin of Error!!Total!!Housing units with a mortgage, contract to purchase, or similar debt  \
# 3                                                145
# 4                                                198
#
#    Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!With either a second mortgage or home equity loan, but not both  \
# 3                                                 33
# 4                                                131
#
#    Margin of Error!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!With either a second mortgage or home equity loan, but not both  \
# 3                                                 26
# 4                                                112
#
#    Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!With either a second mortgage or home equity loan, but not both!!Second mortgage only  \
# 3                                                 25
# 4                                                 94
#
#    Margin of Error!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!With either a second mortgage or home equity loan, but not both!!Second mortgage only  \
# 3                                                 24
# 4                                                111
#
#    Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!With either a second mortgage or home equity loan, but not both!!Home equity loan only  \
# 3                                                  8
# 4                                                 37
#
#    Margin of Error!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!With either a second mortgage or home equity loan, but not both!!Home equity loan only  \
# 3                                                 15
# 4                                                 45
#
#    Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!Both second mortgage and home equity loan  \
# 3                                                  0
# 4                                                  0
#
#    Margin of Error!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!Both second mortgage and home equity loan  \
# 3                                                 19
# 4                                                 19
#
#    Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!No second mortgage and no home equity loan  \
# 3                                                716
# 4                                               1011
#
#    Margin of Error!!Total!!Housing units with a mortgage, contract to purchase, or similar debt!!No second mortgage and no home equity loan  \
# 3                                                145
# 4                                                201
#
#    Estimate!!Total!!Housing units without a mortgage  \
# 3                                                289
# 4                                                514
#
#    Margin of Error!!Total!!Housing units without a mortgage
# 3                                                 65
# 4                                                152

# %%
column_to_new_column = {
    'Estimate!!Total': 'house_num',
    'Estimate!!Total!!Housing units with a mortgage, contract to purchase, or similar debt': 'mortgage_num',
    'Estimate!!Total!!Housing units without a mortgage': 'no_mortgage_num'
}

# %%
mortgage_info_df = mortgage_status_df[['ct_key'] + list(column_to_new_column)]
mortgage_info_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
for column in ['mortgage_num', 'no_mortgage_num']:
    new_column = 'percent_' + '_'.join(column.split('_')[:-1])
    mortgage_info_df[new_column] = mortgage_info_df[column] / mortgage_info_df['house_num']

mortgage_info_df.drop(column_to_new_column.values(), axis=1, inplace=True, errors='ignore')

# %%
for column in mortgage_info_df.columns:
    if column != 'ct_key':
        plt.figure(figsize=(20, 10))
        plt.hist(mortgage_info_df[column], bins=20)
        plt.xlabel(column)
        plt.ylabel('humber of census tracts')
        plt.show()

# %%
# FINANCIAL CHARACTERISTICS FOR HOUSING UNITS WITH A MORTGAGE
mortgage_amount_df = read_in_dataset('mortgage_amount')

# %%
col = 'Estimate!!Owner-occupied housing units with a mortgage!!Owner-occupied housing units with a mortgage!!VALUE!!Median (dollars)'
mortgage_amount_df.rename(columns={col: 'median_mortgage_value'}, inplace=True)

# %%
mortgage_info_df = mortgage_info_df.merge(mortgage_amount_df[['ct_key', 'median_mortgage_value']],
                                          on='ct_key', how='left')

# %%
mortgage_info_df[(mortgage_info_df['median_mortgage_value'] == '-') |
                  mortgage_info_df['percent_mortgage'].isna() |
                  mortgage_info_df['percent_no_mortgage'].isna()]
# Out:
#           ct_key  percent_mortgage  percent_no_mortgage median_mortgage_value
# 19   13089021204               NaN                  NaN                     -
# 49   13063040519          0.000000             1.000000                     -
# 145  13121007100          0.331081             0.668919                     -
# 233  13121004800          0.769231             0.230769                     -
# 253  13121006802          0.452055             0.547945                     -
# 271  13121003800          0.529412             0.470588                     -
# 273  13121004200          0.693227             0.306773                     -
# 299  13121006400          0.870690             0.129310                     -
# 350  13121001002          1.000000             0.000000                     -
# 353  13121007603          0.901163             0.098837                     -
# 363  13121009102          0.823045             0.176955                     -
# 427  13089021813          0.000000             1.000000                     -
# 474  13067030414               NaN                  NaN                     -

# %%
mean_median_mortgage_value = np.mean([int(x) for x in mortgage_info_df['median_mortgage_value'] if x != '-'])
mortgage_info_df['median_mortgage_value'] = [int(x) if x != '-' else mean_median_mortgage_value
                                             for x in mortgage_info_df['median_mortgage_value']]


for column in ['percent_mortgage', 'percent_no_mortgage']:
    mean_val = np.mean(mortgage_info_df[column])
    mortgage_info_df[column] = [x if pd.notnull(x) else mean_val
                                for x in mortgage_info_df[column]]

# %%
mortgage_info_df[(mortgage_info_df['median_mortgage_value'] == '-') |
                  mortgage_info_df['percent_mortgage'].isna() |
                  mortgage_info_df['percent_no_mortgage'].isna()]
# Out:
# Empty DataFrame
# Columns: [ct_key, percent_mortgage, percent_no_mortgage, median_mortgage_value]
# Index: []

# %%
plt.figure(figsize=(20, 10))
plt.hist(mortgage_info_df['median_mortgage_value'] / 1000, bins=20)
plt.xlabel('median_mortgage_value (thousands of $)')
plt.ylabel('humber of census tracts')
plt.show()

# %%
ct_stats_df = ct_stats_df.merge(mortgage_info_df, on='ct_key', how='left')

# %% [markdown]
# ### Age of homes

# %%
# YEAR STRUCTURE BUILT
year_built_df = read_in_dataset('year_built')

# %%
column_to_new_column = {'2014 or later': '2014 or later',
                        '2010 to 2013': '2010-2013',
                        '2000 to 2009': '2000-2009'}

column_to_new_column = {'Estimate!!Total!!Built ' + column: 'built ' + new_column
                        for column, new_column in column_to_new_column.items()}

column_to_new_column['Estimate!!Total'] = 'total_households'

# %%
year_built_df = year_built_df[['ct_key'] + list(column_to_new_column)]
year_built_df.rename(column_to_new_column, axis=1, inplace=True)

# %%
for column in column_to_new_column.values():
    if column != 'total_households':
        year_built_df[column] = year_built_df[column] / year_built_df['total_households']

year_built_df.drop(columns=['total_households'], inplace=True)

# %%
for column in year_built_df.columns:
    if column != 'ct_key':
        plt.figure(figsize=(20, 10))
        plt.hist(year_built_df[column], bins=20)
        plt.xlabel(column)
        plt.ylabel('humber of census tracts')
        plt.show()

# %%
ct_stats_df = ct_stats_df.merge(year_built_df, on='ct_key', how='left')

# %% [markdown]
# ### Clean census-tract data

# %%
my_column_start = list(ct_stats_df.columns).index('census_population')
my_columns = ct_stats_df.columns[my_column_start:]
all_outlier_census_tracts = []
for column in my_columns:
    lower_extreme, upper_extreme = np.quantile(ct_stats_df[column], [0.02, 0.98])
    outlier_census_tracts = ct_stats_df[(ct_stats_df[column] <= lower_extreme) | 
                                        (ct_stats_df[column] >= upper_extreme)]['ct_key']
    all_outlier_census_tracts.extend(outlier_census_tracts)

# %%
census_tracts_ranked = Counter(all_outlier_census_tracts).most_common(50)
worst_census_tracts = [x[0] for x in census_tracts_ranked]

# %%
outlier_num_lst = [x[1] / len(my_columns) for x in census_tracts_ranked]
plt.figure(figsize=(20, 10))
plt.plot(outlier_num_lst)
plt.xlabel('worst census tract ranking')
plt.ylabel('fraction of features that are outliers')
plt.axvline(x=10, color='r', linestyle='--')
plt.show()

# %%
neighborhoood_scout_columns_to_new_columns = {
    'rent.ct': 'median_rental_price',
    'grrent_yield.ct': 'average_annual_rent_as_percentage_of_property_value',
    'frm.ct': 'farm_score',
    'pop_density.ct': 'pop_density',
    'den.ct': 'densely_urban_score',
    'urb.ct': 'urban_score',
    'sub.ct': 'suburban_score',
    'rur.ct': 'rural_score',
    'rmt.ct': 'remote_score',
    'new_pct.ct': 'built 1995 or later',
    'est_pct.ct': 'built 1970-1994',
    'old_pct.ct': 'built 1940-1969',
    'his_pct.ct': 'built before 1940',
    'det_pct.ct': 'single_family_detached_pct',
    'att_pct.ct': 'rowhouses_and_attached_homes_pct',
    'sap_pct.ct': 'small_apt_buildings_pct',
    'lap_pct.ct': 'complexes/high_rise_apt_pct',
    'mob_pct.ct': 'mobile_home_pct',
    'bed0_pct.ct': '0_bedroom_pct',
    'bed1_pct.ct': '1_bedroom_pct',
    'bed2_pct.ct': '2_bedroom_pct',
    'bed3_pct.ct': '3_bedroom_pct',
    'bed4_pct.ct': '4_bedroom_pct',
    'bed5_pct.ct': '5_bedroom_pct',
    'own_pct.ct': 'homeownership_rate',
    'rnt_pct.ct': 'rental_rate',
    'seasonal_pct.ct': 'seasonal_housing_pct',
    'vacant_pct.ct': 'vacant_homes_pct',
    'family_fr.ct': 'family_friendly_score',
    'ft_homebuyer.ct': 'first_time_homebuyer_score',
    'luxury.ct': 'luxury_communities_score',
    'retire_fr.ct': 'retirement_friendly_score',
    'young_sng_pro.ct': 'young_single_professional_score',
    'college_fr.ct': 'college_student_friendly_score',
    'commtime15_pct.ct': 'commute_under_15_min_pct',
    'commtime30_pct.ct': 'commute_15-30_min_pct',
    'commtime45_pct.ct': 'commute_30-45_min_pct',
    'commtime60_pct.ct': 'commute_45-60_min_pct',
    'commtime90_pct.ct': 'commute_over_60_min_pct',
    'pt_violent.ct': 'violent_crime_rate',
    'pt_property.ct': 'property_crime_rate',
    'education_score.ct': 'standardized_test_score_percentile',
    'college_grads.ct': 'pct_pop_at_least_college_degree',
    'children_poverty.ct': 'children_poverty_pct',
    'puptch.sd': 'student_to_teacher_ratio_sd',
    'stcls_total.sd': 'state_index_total_achievement_sd',
    'uscls_total.sd': 'national_index_total_achievement_sd',
    'usrpct_total.sd': 'national_percentile_total_achievement_sd',
    'strpct_total.sd': 'state_percentile_total_achievement_sd',
    'avg_member.sd': 'average_number_of_students_per_school_sd',
    'member.sc': 'number_of_students_sc',
    'puptch.sc': 'student_to_teacher_ratio_sc',
    'stcls_total.sc': 'state_index_total_achievement_sc',
    'uscls_total.sc': 'national_index_total_achievement_sc',
    'usrpct_total.sc': 'national_percentile_total_achievement_sc',
    'strpct_total.sc': 'state_percentile_total_achievement_sc',
}

# %%
ct_stats_df.rename(neighborhoood_scout_columns_to_new_columns, axis=1, inplace=True)

# %%
ct_stats_df[ct_stats_df['ct_key'].isin(worst_census_tracts[:10])]
# Out:
#           ct_key  median_rental_price  \
# 187  13089021204               1266.0
# 254  13089022402               2108.0
# 375  13121000600               2127.0
# 378  13121001002               1671.0
# 401  13121003800               1042.0
# 424  13121006602               1140.0
# 426  13121006802                811.0
# 436  13121007603                971.0
# 445  13121007807               1115.0
# 446  13121007808                871.0
#
#      average_annual_rent_as_percentage_of_property_value  rent_br3.ct  \
# 187                                           4.241111         1815.0
# 254                                           5.807680         2632.0
# 375                                          11.633190         2723.0
# 378                                           6.434471         3176.0
# 401                                           6.181228         1329.0
# 424                                          12.641548         1495.0
# 426                                          15.574190          811.0
# 436                                           9.564516         1462.0
# 445                                          17.160844         1183.0
# 446                                          10.697203          973.0
#
#      rent_br2.ct  rent_br1.ct  rent_br0.ct  cos.ct  lake.ct  farm_score  \
# 187       1302.0       1165.0       1063.0     100      100         100
# 254       2099.0       2026.0       1797.0     100      100         100
# 375       2468.0       1946.0       1438.0     100      100         100
# 378       2113.0       1609.0       1473.0     100      100         100
# 401       1042.0          NaN          NaN     100      100         100
# 424       1171.0        817.0          NaN     100      100         100
# 426        636.0          NaN          NaN     100      100         100
# 436       1025.0        908.0          NaN     100      100         100
# 445       1111.0        490.0          NaN     100      100         100
# 446        832.0          NaN          NaN     100      100         100
#
#       pop_density  densely_urban_score  urban_score  suburban_score  \
# 187   3515.993307                   39           19               1
# 254   4849.492820                   28            8              12
# 375   9304.796076                   12            8              28
# 378   9216.717513                   12            8              28
# 401  12308.263342                    9           10              31
# 424   4605.754130                   30           10              10
# 426   6986.582204                   18            2              22
# 436   3528.342392                   39           19               1
# 445   2784.101453                   46           26               0
# 446   6838.258725                   19            1              21
#
#      rural_score  remote_score  built 1995 or later  built 1970-1994  \
# 187           51            61             0.000000        36.636971
# 254           62            72            38.521401        24.902724
# 375           78            88            78.021309        10.745814
# 378           78            88            85.811966        10.085470
# 401           81            91            28.571429        22.500000
# 424           60            70             1.800327        31.423895
# 426           72            82             6.379310        44.482759
# 436           51            61            11.221853        39.497970
# 445           44            54            11.396574        21.475626
# 446           71            81             5.241090        22.431866
#
#      built 1940-1969  built before 1940  single_family_detached_pct  \
# 187        63.363029           0.000000                    6.904232
# 254        32.607004           3.968872                   11.984436
# 375         6.879756           4.353120                    7.123288
# 378         0.683761           3.418803                    0.512821
# 401        33.928571          15.000000                   35.357143
# 424        53.191489          13.584288                   51.063830
# 426        45.689655           3.448276                   32.758621
# 436        47.286822           1.993355                   13.953488
# 445        66.600791           0.527009                   60.606061
# 446        70.440252           1.886792                   13.522013
#
#      rowhouses_and_attached_homes_pct  small_apt_buildings_pct  \
# 187                          2.672606                19.376392
# 254                          0.000000                 4.980545
# 375                          5.175038                 7.153729
# 378                          0.000000                 0.683761
# 401                         10.357143                22.857143
# 424                          1.309329                28.477905
# 426                          0.000000                 2.413793
# 436                          0.000000                13.215209
# 445                          0.000000                 3.293808
# 446                          0.000000                 5.555556
#
#      complexes/high_rise_apt_pct  mobile_home_pct  oth_pct.ct  0_bedroom_pct  \
# 187                    67.706013         3.340757    0.000000      11.804009
# 254                    83.035019         0.000000    0.000000      24.513619
# 375                    80.547945         0.000000    0.000000       8.066971
# 378                    98.803419         0.000000    0.000000      23.760684
# 401                    31.428571         0.000000    0.000000      22.500000
# 424                    19.148936         0.000000    0.000000       1.309329
# 426                    62.931034         0.000000    1.896552       3.275862
# 436                    71.059432         1.771872    0.000000       2.104097
# 445                    31.291173         4.808959    0.000000       0.658762
# 446                    80.922432         0.000000    0.000000       2.725367
#
#      1_bedroom_pct  2_bedroom_pct  3_bedroom_pct  4_bedroom_pct  \
# 187      24.832962      55.011136       8.351893       0.000000
# 254      28.482490      35.953307       6.926070       1.789883
# 375      48.036530      30.928463       6.727549       5.905632
# 378      44.786325      28.717949       2.051282       0.683761
# 401       3.928571      32.500000      23.571429       5.714286
# 424      20.949264      42.553191      26.350245       8.183306
# 426       3.448276      27.758621      46.724138      18.793103
# 436      44.038391      41.122185       8.785530       2.141011
# 445       6.324111      41.633729      36.297760      13.965744
# 446       3.616352      57.861635      34.538784       0.838574
#
#      5_bedroom_pct  base_pct.ct  dorms_pct.ct  incarc_pct.ct  \
# 187       0.000000     0.000000      0.000000            0.0
# 254       2.334630     0.000000     65.859523            0.0
# 375       0.334855     0.000000     17.624447            0.0
# 378       0.000000     0.000000     86.888361            0.0
# 401      11.785714     0.000000     87.849761            0.0
# 424       0.654664     0.000000      0.000000            0.0
# 426       0.000000     0.000000      0.000000            0.0
# 436       1.808786     1.815642      0.000000            0.0
# 445       1.119895     0.000000      0.000000            0.0
# 446       0.419287     0.000000      0.000000            0.0
#
#      publichou_pct.ct  homeownership_rate  rental_rate  seasonal_housing_pct  \
# 187               0.0            0.000000   100.000000              0.000000
# 254               0.0            1.809263    98.190737              7.081712
# 375               0.0           16.035286    83.964714              5.144597
# 378               0.0            0.176749    99.823251              4.444444
# 401               0.0            0.928811    99.071189              8.928571
# 424               0.0           21.197380    78.802620              0.000000
# 426               0.0           12.874780    87.125220              0.000000
# 436               0.0            7.732486    92.267514              0.000000
# 445               0.0           29.870130    70.129870              0.000000
# 446               0.0           10.860367    89.139633              0.000000
#
#      vacant_homes_pct  family_friendly_score  first_time_homebuyer_score  \
# 187          9.354120              85.872584                  100.000000
# 254         17.665370              96.237180                  100.000000
# 375         17.016743              93.704804                   48.429075
# 378         15.555556              89.063488                  100.000000
# 401         43.214286              96.465396                   50.649316
# 424         24.713584              97.479997                   75.639518
# 426          2.241379              99.061014                   94.191970
# 436         18.530823              99.733289                   86.782611
# 445         28.985507              97.467624                   65.478845
# 446         25.681342              99.909263                   91.333901
#
#      luxury_communities_score  vac_home.ct  retirement_friendly_score  \
# 187                 97.107896        100.0                  99.810278
# 254                 32.380429        100.0                  93.013281
# 375                 20.558763        100.0                  90.522148
# 378                 38.851055        100.0                  89.103357
# 401                 62.773637        100.0                  94.184608
# 424                 98.059780        100.0                  99.221865
# 426                 96.293486        100.0                  99.815777
# 436                 94.368613        100.0                  97.900685
# 445                 85.329253        100.0                  89.455305
# 446                 91.922795        100.0                  99.615057
#
#      young_single_professional_score  college_student_friendly_score  \
# 187                        51.314745                       99.007396
# 254                        14.016474                       30.383019
# 375                         5.387648                       20.546344
# 378                        20.661376                        4.391102
# 401                        24.015310                        4.307240
# 424                        58.230159                       60.440210
# 426                        47.550680                       94.405950
# 436                        43.023331                       60.306855
# 445                        46.427227                       94.874756
# 446                        46.926502                       95.410927
#
#      commute_under_15_min_pct  commute_15-30_min_pct  commute_30-45_min_pct  \
# 187                 14.779006              47.997238              23.618785
# 254                 48.723187              32.788560              13.687436
# 375                 29.794150              44.691224              15.465872
# 378                 47.588611              43.521209               4.997095
# 401                 51.635282              26.660059              13.478692
# 424                  7.184466              33.592233              22.135922
# 426                  9.497207              52.234637              18.715084
# 436                  0.962199              34.226804              11.890034
# 445                 26.225166              13.377483              27.284768
# 446                  4.984177              27.768987              16.455696
#
#      commute_45-60_min_pct  commute_over_60_min_pct  count_violent.ct  \
# 187              13.604972                 0.000000              39.0
# 254               3.268641                 1.532176              11.0
# 375               9.100758                 0.947996              14.0
# 378               3.602557                 0.290529               2.0
# 401               8.225966                 0.000000               3.0
# 424              26.213592                10.873786              18.0
# 426              15.363128                 4.189944              65.0
# 436              25.429553                27.491409              90.0
# 445              28.211921                 4.900662              62.0
# 446              28.639241                22.151899             145.0
#
#      count_property.ct  count_total.ct  violent_crime_rate  \
# 187              276.0           315.0            8.550756
# 254              269.0           280.0            3.238390
# 375              328.0           342.0            2.690755
# 378              155.0           157.0            0.316706
# 401              113.0           116.0            0.756239
# 424               75.0            93.0           15.943313
# 426              229.0           294.0           33.197140
# 436              451.0           541.0           20.949721
# 445              197.0           259.0           19.897304
# 446              490.0           635.0           33.673943
#
#      property_crime_rate  pt_total.ct  standardized_test_score_percentile  \
# 187            60.513045    69.063802                           15.919281
# 254            79.193347    82.431736                           58.198582
# 375            63.040554    65.731309                           68.193145
# 378            24.544735    24.861441                           68.193145
# 401            28.485001    29.241240                           11.311490
# 424            66.430469    82.373782                           15.377845
# 426           116.956078   150.153218                            9.453588
# 436           104.981378   125.931099                            6.470429
# 445            63.222080    83.119384                            3.226592
# 446           113.794705   147.468648                            4.341928
#
#      pct_pop_at_least_college_degree  children_poverty_pct    leaid  \
# 187                         0.040387              0.622642  1301740
# 254                         0.698039              0.040650  1301740
# 375                         0.794985              0.254545  1300120
# 378                         0.674242              0.000000  1300120
# 401                         0.357934              0.000000  1300120
# 424                         0.049296              0.777126  1300120
# 426                         0.051750              0.913374  1300120
# 436                         0.089334              0.817003  1300120
# 445                         0.144206              0.710048  1300120
# 446                         0.097679              0.950226  1300120
#
#      student_to_teacher_ratio_sd  state_index_total_achievement_sd  \
# 187                    14.061512                               5.0
# 254                    14.061512                               5.0
# 375                    13.064528                               4.0
# 378                    13.064528                               4.0
# 401                    13.064528                               4.0
# 424                    13.064528                               4.0
# 426                    13.064528                               4.0
# 436                    13.064528                               4.0
# 445                    13.064528                               4.0
# 446                    13.064528                               4.0
#
#      national_index_total_achievement_sd  \
# 187                                  3.0
# 254                                  3.0
# 375                                  3.0
# 378                                  3.0
# 401                                  3.0
# 424                                  3.0
# 426                                  3.0
# 436                                  3.0
# 445                                  3.0
# 446                                  3.0
#
#      national_percentile_total_achievement_sd  \
# 187                                 28.735415
# 254                                 28.735415
# 375                                 26.117944
# 378                                 26.117944
# 401                                 26.117944
# 424                                 26.117944
# 426                                 26.117944
# 436                                 26.117944
# 445                                 26.117944
# 446                                 26.117944
#
#      state_percentile_total_achievement_sd  \
# 187                              43.540670
# 254                              43.540670
# 375                              37.799043
# 378                              37.799043
# 401                              37.799043
# 424                              37.799043
# 426                              37.799043
# 436                              37.799043
# 445                              37.799043
# 446                              37.799043
#
#      average_number_of_students_per_school_sd  number_of_students_sc  \
# 187                                762.815385             974.366667
# 254                                762.815385            1325.000000
# 375                                588.505618             507.600000
# 378                                588.505618             659.800000
# 401                                588.505618             538.714286
# 424                                588.505618             458.000000
# 426                                588.505618             402.785714
# 436                                588.505618             468.312500
# 445                                588.505618             434.000000
# 446                                588.505618             632.535714
#
#      student_to_teacher_ratio_sc  state_index_total_achievement_sc  \
# 187                    13.817717                          5.383333
# 254                    14.722222                          9.000000
# 375                    13.050249                          2.500000
# 378                    12.495713                          3.750000
# 401                    13.711978                          2.571429
# 424                    11.450000                          1.000000
# 426                    12.168038                          2.642857
# 436                    12.624161                          2.437500
# 445                    13.272171                          1.000000
# 446                    13.674009                          2.723214
#
#      national_index_total_achievement_sc  \
# 187                             4.766667
# 254                             7.000000
# 375                             2.200000
# 378                             3.100000
# 401                             2.142857
# 424                             1.000000
# 426                             2.214286
# 436                             2.250000
# 445                             1.000000
# 446                             2.419643
#
#      national_percentile_total_achievement_sc  \
# 187                                 43.304873
# 254                                 69.638645
# 375                                 16.133769
# 378                                 25.643492
# 401                                 17.067679
# 424                                  7.045196
# 426                                 17.617852
# 436                                 17.311811
# 445                                  2.219301
# 446                                 17.800338
#
#      state_percentile_total_achievement_sc  census_population       <18  \
# 187                              48.462728               3308  0.376360
# 254                              80.339806               6725  0.027955
# 375                              18.596576               7646  0.018310
# 378                              30.136340               7063  0.012884
# 401                              22.052273               4075  0.021104
# 424                               8.437146               1195  0.307950
# 426                              20.633503               2272  0.592870
# 436                              20.614232               4735  0.230201
# 445                               0.792752               3368  0.366686
# 446                              21.769108               4456  0.440978
#
#         18-24     25-34     35-49     50-59     60-64     65-74       75+  \
# 187  0.092201  0.261185  0.198307  0.035973  0.000000  0.020556  0.015417
# 254  0.782454  0.062751  0.027658  0.023197  0.002825  0.020967  0.052193
# 375  0.538321  0.299895  0.091682  0.017656  0.017918  0.016218  0.000000
# 378  0.912360  0.055217  0.015008  0.002973  0.001557  0.000000  0.000000
# 401  0.912393  0.025276  0.021104  0.012761  0.000982  0.001963  0.004417
# 424  0.097908  0.148117  0.209205  0.130544  0.033473  0.027615  0.045188
# 426  0.117958  0.112676  0.102993  0.033011  0.003521  0.026408  0.010563
# 436  0.062936  0.263992  0.085111  0.127350  0.073073  0.098205  0.059134
# 445  0.067102  0.145784  0.189727  0.089667  0.010689  0.066508  0.063836
# 446  0.143178  0.112882  0.119165  0.090664  0.026032  0.023564  0.043537
#
#      Hispanic     White     Black     Asian  linear_pop_trend_since_2010  \
# 187  0.855200  0.041717  0.034764  0.042926                    -0.018883
# 254  0.074796  0.455911  0.165502  0.260818                     0.023832
# 375  0.057416  0.484175  0.165969  0.256212                     0.058100
# 378  0.079003  0.455897  0.220586  0.209401                    -0.030347
# 401  0.059877  0.161227  0.693988  0.066258                     0.007278
# 424  0.012552  0.001674  0.982427  0.000000                     0.093813
# 426  0.008803  0.000000  0.965229  0.000000                     0.044475
# 436  0.005913  0.009081  0.972545  0.010137                    -0.013130
# 445  0.022862  0.005048  0.946259  0.000000                     0.018704
# 446  0.048923  0.000000  0.951077  0.000000                     0.022178
#
#      avg_annual_pop_change_since_2010  linear_pop_trend_since_2014  \
# 187                         -0.026499                    -0.060781
# 254                          0.027243                     0.048358
# 375                          0.080000                     0.045262
# 378                         -0.039258                    -0.015974
# 401                          0.000657                     0.022284
# 424                          0.054260                     0.017874
# 426                          0.045467                     0.048138
# 436                         -0.007742                     0.004226
# 445                          0.007695                     0.048669
# 446                          0.026957                     0.007629
#
#      avg_annual_pop_change_since_2014  annual_births_per_resident  \
# 187                         -0.068351                    0.023881
# 254                          0.046923                    0.000000
# 375                          0.049688                    0.000000
# 378                         -0.016360                    0.000000
# 401                          0.020103                    0.000000
# 424                          0.031726                    0.014226
# 426                          0.044835                    0.047975
# 436                          0.002954                    0.005913
# 445                          0.044842                    0.016924
# 446                          0.011526                    0.034111
#
#      workforce_fraction       car   carpool  public_transportation      walk  \
# 187            0.440145  0.179258  0.444368               0.269918  0.088599
# 254            0.116134  0.523688  0.035851               0.039693  0.235595
# 375            0.490453  0.609067  0.082667               0.058933  0.152267
# 378            0.083534  0.494915  0.055932               0.032203  0.274576
# 401            0.041963  0.456140  0.000000               0.304094  0.163743
# 424            0.446862  0.331461  0.018727               0.528090  0.046816
# 426            0.157570  0.603352  0.100559               0.254190  0.000000
# 436            0.307286  0.329897  0.055670               0.614433  0.000000
# 445            0.241390  0.633456  0.040590               0.217712  0.036900
# 446            0.286131  0.312941  0.105098               0.538039  0.023529
#
#           WFH  other_mode_of_transit  median_household_income  \
# 187  0.005495               0.012363                  26630.0
# 254  0.069142               0.096031                  39375.0
# 375  0.073333               0.023733                  53728.0
# 378  0.061017               0.081356                  31389.0
# 401  0.076023               0.000000                  21181.0
# 424  0.041199               0.033708                  18534.0
# 426  0.000000               0.041899                  11736.0
# 436  0.000000               0.000000                  13982.0
# 445  0.071341               0.000000                  20792.0
# 446  0.008627               0.011765                  13263.0
#
#      median_family_income  median_nonfamily_income  mean_household_income  \
# 187               25046.0                  26875.0                34536.0
# 254              124375.0                  31250.0                62561.0
# 375               96850.0                  47147.0                68300.0
# 378               41071.0                  30714.0                40434.0
# 401               37361.0                  18750.0                26596.0
# 424               17396.0                  19038.0                28014.0
# 426                9779.0                  13618.0                27170.0
# 436               15833.0                  13038.0                23389.0
# 445               22232.0                  20271.0                29665.0
# 446               12131.0                  17232.0                25573.0
#
#      mean_family_income  mean_nonfamily_income  family_households_fraction  \
# 187             28306.0                39397.0                    0.642506
# 254            133607.0                47230.0                    0.176749
# 375            131238.0                57818.0                    0.140499
# 378             62712.0                38787.0                    0.068826
# 401             41217.0                21516.0                    0.257862
# 424             31138.0                24392.0                    0.395652
# 426             26869.0                22742.0                    0.772487
# 436             25932.0                21028.0                    0.343453
# 445             30629.0                24952.0                    0.602041
# 446             18784.0                37149.0                    0.657264
#
#      nonfamily_households_fraction  above_poverty_line  below_poverty_line  \
# 187                       0.357494                69.4                25.9
# 254                       0.823251                66.4                33.6
# 375                       0.859501                71.9                28.2
# 378                       0.931174                60.5                40.4
# 401                       0.742138                56.6                35.0
# 424                       0.604348                53.9                29.3
# 426                       0.227513                29.3                25.6
# 436                       0.656547                47.9                21.4
# 445                       0.397959                59.1                23.6
# 446                       0.342736                34.4                35.4
#
#      STEM_jobs  education&health_care  total_households  avg_family_size  \
# 187       16.8                    1.5               814             4.52
# 254        7.8                   60.9              1058             2.77
# 375       24.2                   26.7              2726             2.44
# 378        6.8                   53.7               494             2.29
# 401        3.7                   39.6               159             3.76
# 424       11.9                   16.8               460             4.21
# 426        4.5                    7.5               567             4.86
# 436        4.9                   14.7              2207             3.35
# 445        3.8                   30.6              1078             4.35
# 446       13.2                   24.2              1418             4.07
#
#      avg_nonfamily_size  avg_household_size     <200k  200-300k  300-400k  \
# 187                2.67                4.06       NaN       NaN       NaN
# 254                1.50                1.74  0.000000  0.057143  0.371429
# 375                2.30                2.33  0.548583  0.271255  0.026316
# 378                1.75                1.78  0.000000  0.000000  0.428571
# 401                1.27                2.23  1.000000  0.000000  0.000000
# 424                1.25                2.58  0.763636  0.145455  0.090909
# 426                3.16                4.01  1.000000  0.000000  0.000000
# 436                1.26                2.13  0.481928  0.518072  0.000000
# 445                1.89                3.12  0.873016  0.000000  0.000000
# 446                1.24                3.14  0.672727  0.327273  0.000000
#
#      400-500k  500-750k  750-1000k       >1M  married  \
# 187       NaN       NaN        NaN       NaN     34.6
# 254  0.414286  0.157143        0.0  0.000000      7.0
# 375  0.076923  0.076923        0.0  0.000000     12.2
# 378  0.571429  0.000000        0.0  0.000000      1.1
# 401  0.000000  0.000000        0.0  0.000000      2.4
# 424  0.000000  0.000000        0.0  0.000000     11.1
# 426  0.000000  0.000000        0.0  0.000000      9.5
# 436  0.000000  0.000000        0.0  0.000000     17.8
# 445  0.000000  0.000000        0.0  0.126984     13.2
# 446  0.000000  0.000000        0.0  0.000000      7.1
#
#      divorced/separated/widowed  never_married  percent_mortgage  \
# 187                         5.6           59.8          0.716968
# 254                         6.1           86.9          0.842857
# 375                         4.4           83.4          0.745731
# 378                         0.7           98.2          1.000000
# 401                         1.2           96.4          0.529412
# 424                        29.5           59.3          0.561224
# 426                        12.4           78.2          0.452055
# 436                        28.5           53.8          0.901163
# 445                        26.2           60.6          0.329193
# 446                        17.1           75.9          0.409091
#
#      percent_no_mortgage  median_mortgage_value  built 2014 or later  \
# 187             0.283032          255158.173077             0.000000
# 254             0.157143          436200.000000             0.031128
# 375             0.254269          187500.000000             0.145814
# 378             0.000000          255158.173077             0.013675
# 401             0.470588          255158.173077             0.050000
# 424             0.438776           97900.000000             0.000000
# 426             0.547945          255158.173077             0.029310
# 436             0.098837          255158.173077             0.000000
# 445             0.670807           59100.000000             0.000000
# 446             0.590909           82000.000000             0.000000
#
#      built 2010-2013  built 2000-2009
# 187         0.000000         0.000000
# 254         0.205447         0.148638
# 375         0.088280         0.546119
# 378         0.350427         0.494017
# 401         0.221429         0.014286
# 424         0.000000         0.018003
# 426         0.000000         0.034483
# 436         0.065338         0.046881
# 445         0.083004         0.030962
# 446         0.000000         0.052411

# %% [markdown]
# The following census tracts have a rental rate that is above 90% so let's ignore them:
# `13089021204`, `13089022402`, `13121001002`, `13121003800`, `13121007603`
#
# The following census tracts have an extremely high fraction of residents under 18 years old:
# `13121006802`, `13121007807`, `13121007808`
#
# But this isn't enough grounds to ignore these census tracts.

# %%
census_tracts_to_ignore = [13089021204, 13089022402, 13121001002, 13121003800, 13121007603]

# %%
ct_stats_df_cleaned = ct_stats_df[~ct_stats_df['ct_key'].isin(census_tracts_to_ignore)]

# %%
ct_stats_df_cleaned.drop(columns=['rent_br3.ct', 'rent_br2.ct', 'rent_br1.ct', 'rent_br0.ct',
                                  'above_poverty_line', 'percent_no_mortgage'], inplace=True)

# %%
ct_stats_df_cleaned.isna().sum()
# Out:
# ct_key                                                 0
# median_rental_price                                    1
# average_annual_rent_as_percentage_of_property_value    5
# cos.ct                                                 0
# lake.ct                                                0
# farm_score                                             0
# pop_density                                            0
# densely_urban_score                                    0
# urban_score                                            0
# suburban_score                                         0
# rural_score                                            0
# remote_score                                           0
# built 1995 or later                                    0
# built 1970-1994                                        0
# built 1940-1969                                        0
# built before 1940                                      0
# single_family_detached_pct                             0
# rowhouses_and_attached_homes_pct                       0
# small_apt_buildings_pct                                0
# complexes/high_rise_apt_pct                            0
# mobile_home_pct                                        0
# oth_pct.ct                                             0
# 0_bedroom_pct                                          0
# 1_bedroom_pct                                          0
# 2_bedroom_pct                                          0
# 3_bedroom_pct                                          0
# 4_bedroom_pct                                          0
# 5_bedroom_pct                                          0
# base_pct.ct                                            0
# dorms_pct.ct                                           0
# incarc_pct.ct                                          0
# publichou_pct.ct                                       0
# homeownership_rate                                     0
# rental_rate                                            0
# seasonal_housing_pct                                   0
# vacant_homes_pct                                       0
# family_friendly_score                                  0
# first_time_homebuyer_score                             0
# luxury_communities_score                               0
# vac_home.ct                                            0
# retirement_friendly_score                              0
# young_single_professional_score                        0
# college_student_friendly_score                         0
# commute_under_15_min_pct                               0
# commute_15-30_min_pct                                  0
# commute_30-45_min_pct                                  0
# commute_45-60_min_pct                                  0
# commute_over_60_min_pct                                0
# count_violent.ct                                       1
# count_property.ct                                      1
# count_total.ct                                         1
# violent_crime_rate                                     0
# property_crime_rate                                    0
# pt_total.ct                                            0
# standardized_test_score_percentile                     0
# pct_pop_at_least_college_degree                        0
# children_poverty_pct                                   0
# leaid                                                  0
# student_to_teacher_ratio_sd                            0
# state_index_total_achievement_sd                       0
# national_index_total_achievement_sd                    0
# national_percentile_total_achievement_sd               0
# state_percentile_total_achievement_sd                  0
# average_number_of_students_per_school_sd               0
# number_of_students_sc                                  0
# student_to_teacher_ratio_sc                            0
# state_index_total_achievement_sc                       0
# national_index_total_achievement_sc                    0
# national_percentile_total_achievement_sc               0
# state_percentile_total_achievement_sc                  0
# census_population                                      0
# <18                                                    0
# 18-24                                                  0
# 25-34                                                  0
# 35-49                                                  0
# 50-59                                                  0
# 60-64                                                  0
# 65-74                                                  0
# 75+                                                    0
# Hispanic                                               0
# White                                                  0
# Black                                                  0
# Asian                                                  0
# linear_pop_trend_since_2010                            0
# avg_annual_pop_change_since_2010                       0
# linear_pop_trend_since_2014                            0
# avg_annual_pop_change_since_2014                       0
# annual_births_per_resident                             0
# workforce_fraction                                     0
# car                                                    0
# carpool                                                0
# public_transportation                                  0
# walk                                                   0
# WFH                                                    0
# other_mode_of_transit                                  0
# median_household_income                                0
# median_family_income                                   0
# median_nonfamily_income                                0
# mean_household_income                                  0
# mean_family_income                                     0
# mean_nonfamily_income                                  0
# family_households_fraction                             0
# nonfamily_households_fraction                          0
# below_poverty_line                                     0
# STEM_jobs                                              0
# education&health_care                                  0
# total_households                                       0
# avg_family_size                                        0
# avg_nonfamily_size                                     0
# avg_household_size                                     0
# <200k                                                  2
# 200-300k                                               2
# 300-400k                                               2
# 400-500k                                               2
# 500-750k                                               2
# 750-1000k                                              2
# >1M                                                    2
# married                                                0
# divorced/separated/widowed                             0
# never_married                                          0
# percent_mortgage                                       0
# median_mortgage_value                                  0
# built 2014 or later                                    0
# built 2010-2013                                        0
# built 2000-2009                                        0
# dtype: int64

# %%
columns_to_impute_mean = ['median_rental_price', 'average_annual_rent_as_percentage_of_property_value',
                          'count_violent.ct', 'count_property.ct', 'count_total.ct']

for column in columns_to_impute_mean:
    ct_stats_df_cleaned[column] = [x if pd.notnull(x) else np.mean(ct_stats_df_cleaned[column])
                                   for x in ct_stats_df_cleaned[column]]

# %%
ct_stats_df_cleaned[ct_stats_df_cleaned['<200k'].isna()][['ct_key', 'rental_rate']]
# Out:
#           ct_key  rental_rate
# 114  13067030414   100.000000
# 231  13089021813    99.388646

# %% [markdown]
# `13067030414` and `13089021813` are over 99% rent so we ignore them

# %%
ct_stats_df_cleaned = ct_stats_df_cleaned[~ct_stats_df_cleaned['ct_key'].isin([13067030414, 13089021813])]

# %%
ct_stats_df.shape
# Out:
# (637, 131)

# %%
ct_stats_df_cleaned.shape
# Out:
# (630, 125)

# %%
ct_stats_df_cleaned.isna().sum()
# Out:
# ct_key                                                 0
# median_rental_price                                    0
# average_annual_rent_as_percentage_of_property_value    0
# cos.ct                                                 0
# lake.ct                                                0
# farm_score                                             0
# pop_density                                            0
# densely_urban_score                                    0
# urban_score                                            0
# suburban_score                                         0
# rural_score                                            0
# remote_score                                           0
# built 1995 or later                                    0
# built 1970-1994                                        0
# built 1940-1969                                        0
# built before 1940                                      0
# single_family_detached_pct                             0
# rowhouses_and_attached_homes_pct                       0
# small_apt_buildings_pct                                0
# complexes/high_rise_apt_pct                            0
# mobile_home_pct                                        0
# oth_pct.ct                                             0
# 0_bedroom_pct                                          0
# 1_bedroom_pct                                          0
# 2_bedroom_pct                                          0
# 3_bedroom_pct                                          0
# 4_bedroom_pct                                          0
# 5_bedroom_pct                                          0
# base_pct.ct                                            0
# dorms_pct.ct                                           0
# incarc_pct.ct                                          0
# publichou_pct.ct                                       0
# homeownership_rate                                     0
# rental_rate                                            0
# seasonal_housing_pct                                   0
# vacant_homes_pct                                       0
# family_friendly_score                                  0
# first_time_homebuyer_score                             0
# luxury_communities_score                               0
# vac_home.ct                                            0
# retirement_friendly_score                              0
# young_single_professional_score                        0
# college_student_friendly_score                         0
# commute_under_15_min_pct                               0
# commute_15-30_min_pct                                  0
# commute_30-45_min_pct                                  0
# commute_45-60_min_pct                                  0
# commute_over_60_min_pct                                0
# count_violent.ct                                       0
# count_property.ct                                      0
# count_total.ct                                         0
# violent_crime_rate                                     0
# property_crime_rate                                    0
# pt_total.ct                                            0
# standardized_test_score_percentile                     0
# pct_pop_at_least_college_degree                        0
# children_poverty_pct                                   0
# leaid                                                  0
# student_to_teacher_ratio_sd                            0
# state_index_total_achievement_sd                       0
# national_index_total_achievement_sd                    0
# national_percentile_total_achievement_sd               0
# state_percentile_total_achievement_sd                  0
# average_number_of_students_per_school_sd               0
# number_of_students_sc                                  0
# student_to_teacher_ratio_sc                            0
# state_index_total_achievement_sc                       0
# national_index_total_achievement_sc                    0
# national_percentile_total_achievement_sc               0
# state_percentile_total_achievement_sc                  0
# census_population                                      0
# <18                                                    0
# 18-24                                                  0
# 25-34                                                  0
# 35-49                                                  0
# 50-59                                                  0
# 60-64                                                  0
# 65-74                                                  0
# 75+                                                    0
# Hispanic                                               0
# White                                                  0
# Black                                                  0
# Asian                                                  0
# linear_pop_trend_since_2010                            0
# avg_annual_pop_change_since_2010                       0
# linear_pop_trend_since_2014                            0
# avg_annual_pop_change_since_2014                       0
# annual_births_per_resident                             0
# workforce_fraction                                     0
# car                                                    0
# carpool                                                0
# public_transportation                                  0
# walk                                                   0
# WFH                                                    0
# other_mode_of_transit                                  0
# median_household_income                                0
# median_family_income                                   0
# median_nonfamily_income                                0
# mean_household_income                                  0
# mean_family_income                                     0
# mean_nonfamily_income                                  0
# family_households_fraction                             0
# nonfamily_households_fraction                          0
# below_poverty_line                                     0
# STEM_jobs                                              0
# education&health_care                                  0
# total_households                                       0
# avg_family_size                                        0
# avg_nonfamily_size                                     0
# avg_household_size                                     0
# <200k                                                  0
# 200-300k                                               0
# 300-400k                                               0
# 400-500k                                               0
# 500-750k                                               0
# 750-1000k                                              0
# >1M                                                    0
# married                                                0
# divorced/separated/widowed                             0
# never_married                                          0
# percent_mortgage                                       0
# median_mortgage_value                                  0
# built 2014 or later                                    0
# built 2010-2013                                        0
# built 2000-2009                                        0
# dtype: int64

# %%
my_column_start = list(ct_stats_df_cleaned.columns).index('census_population')
neighborhood_scout_columns = list(ct_stats_df_cleaned.columns)[1:my_column_start]

# %%
plt.rcParams.update({'font.size': 11})
fig, axs = plt.subplots(nrows=int(np.ceil(len(neighborhood_scout_columns) / 2)), ncols=2)
fig.set_figheight(15)
fig.set_figwidth(15)
fig.subplots_adjust(bottom=-8)
cnt = 0
for column in neighborhood_scout_columns:
    
    row_idx = int(cnt / 2)
    col_idx = cnt % 2
    
    axs[row_idx, col_idx].hist(ct_stats_df_cleaned[column])
    axs[row_idx, col_idx].set_title(column)
    
    cnt += 1

plt.rcParams.update({'font.size': 22})

# %% [markdown]
# Neighborhood Scout columns to drop:
#
# `cos.ct`: all census tracts have same score
#
# `lake.ct`: the vast majority of census tracts have the same score
#
# `oth_pct.ct`: value is 0 for vast majority of census tracts and statistic doesn't tell us much
#
# `base_pct.ct`: values is 0 except for one census tract
#
# `dorms_pct.ct`: vast majority of values are 0
#
# `incarc_pct.ct`: vast majority of values of 0
#
# `publichou_pct.ct`: vast majority of values are 0
#
# `vac_home.ct`: vatst majority of scores are 100
#
# `count_violent.ct`: raw count that isn't normalized
#
# `count_property.ct`: raw count that isn't normalized
#
# `count_total.ct`: raw count that isn't normalized
#
# `pt_total.ct`: already broken up into violent crime rate and property crime rate
#
# `leaid`: meaningless

# %%
neighborhood_scout_columns_to_drop = [
    'cos.ct', 'lake.ct', 'oth_pct.ct', 'base_pct.ct', 'dorms_pct.ct', 'incarc_pct.ct', 'publichou_pct.ct',
    'vac_home.ct', 'count_violent.ct', 'count_property.ct', 'count_total.ct', 'pt_total.ct', 'leaid'
]
ct_stats_df_cleaned.drop(columns=neighborhood_scout_columns_to_drop, inplace=True)

# %%
ct_stats_df_cleaned.shape
# Out:
# (630, 112)

# %%
plt.figure(figsize=(20, 10))
plt.hist(100 * ct_stats_df_cleaned['children_poverty_pct'] - ct_stats_df_cleaned['below_poverty_line'])
plt.xlabel('below_poverty_line')
plt.ylabel('number of census tracts')
plt.show()

# %%
ct_stats_df_cleaned.drop(columns=['below_poverty_line'], inplace=True)

# %%
plt.figure(figsize=(20, 10))
plt.hist(ct_stats_df_cleaned['census_population'] / ct_stats_df_cleaned['total_households'], bins=20)
plt.xlabel('ratio of population to number of households')
plt.ylabel('number of census tracts')
plt.show()

# %%
ct_stats_df_cleaned.to_csv(f'{market_area}_census_tract_data.csv', index=False)

# %%
redundant_columns = [
    'densely_urban_score', 'remote_score', 'built 2000-2009', 'state_index_total_achievement_sd',
    'national_index_total_achievement_sd', 'state_percentile_total_achievement_sd', 
    'state_index_total_achievement_sc', 'state_percentile_total_achievement_sc', 
    'national_index_total_achievement_sc', 'avg_annual_pop_change_since_2010',
    'linear_pop_trend_since_2014', 'avg_annual_pop_change_since_2014',
    'mean_household_income', 'median_family_income', 'mean_family_income', 'vacancy_rate',
    'standardized_test_score_percentile'
]

# %%
ct_stats_df_cleaned.drop(columns=redundant_columns, inplace=True, errors='ignore')

# %%
ct_stats_df_cleaned.to_csv(f'{market_area}_census_tract_data_removed_redundant_features.csv', index=False)

# %% [markdown]
# ### MLS Listing Data

# %%
market_area_listing_dates_df = pd.read_csv(f'{market_area}_listing_dates_cleaned.csv')
market_area_listing_dates_df['zipcode'] = market_area_listing_dates_df['zipcode'].astype(str)

# %%
for event in 'list sale withdrawn expired cancelled'.split():
    column = event + '_date'
    market_area_listing_dates_df[column] = pd.to_datetime(market_area_listing_dates_df[column]).dt.date

# %%
market_area_listing_dates_df.head()
# Out:
#    property_id zipcode   latitude  longitude   list_date   sale_date  \
# 0     21376370   30101  34.063270 -84.682380  2016-03-01  2016-03-17
# 1     22047872   30034  33.683546 -84.225701  2016-03-01  2016-09-19
# 2    570251994   30075  34.104636 -84.398276  2016-03-01         NaT
# 3     20877170   30067  33.959711 -84.418946  2016-03-01  2016-07-05
# 4     20919674   30066  34.061751 -84.485969  2016-03-01  2016-05-31
#
#   withdrawn_date expired_date cancelled_date current_status  sale_price
# 0            NaT          NaT            NaT           Sale    180000.0
# 1            NaT          NaT            NaT           Sale     49000.0
# 2            NaT   2016-03-07            NaT        Expired         NaN
# 3            NaT          NaT            NaT           Sale    425000.0
# 4            NaT          NaT            NaT           Sale    190000.0

# %%
# shapefile of all census tracts
census_tracts_shapes = gpd.read_file('neighborhood_scout_data/ct_18states shapefile/ct_18states.shp')
census_tracts_shapes['ct_key'] = census_tracts_shapes['CT_KEY'].astype(int)
census_tracts_shapes.drop(columns='CT_KEY', inplace=True)

# limit analysis to census tracts in state
statewide_census_tracts_shapes = census_tracts_shapes[census_tracts_shapes['ct_key'].
                                                      isin(statewide_census_tracts)]
statewide_census_tracts_shapes.shape
# Out:
# (1964, 2)

# %%
# convert the latitude and longitude of each listing to a Point
geometry = [Point(xy) for xy in zip(market_area_listing_dates_df.longitude, 
                                    market_area_listing_dates_df.latitude)]
gdf = gpd.GeoDataFrame(market_area_listing_dates_df, crs='EPSG:4269', geometry=geometry)

# identify the census tract that each listing lies within
merged_file = gpd.sjoin(gdf, statewide_census_tracts_shapes, how='left', op='within')
market_area_listing_dates_ct_df = pd.DataFrame(merged_file)

# %%
market_area_listing_dates_ct_df.head()
# Out:
#    property_id zipcode   latitude  longitude   list_date   sale_date  \
# 0     21376370   30101  34.063270 -84.682380  2016-03-01  2016-03-17
# 1     22047872   30034  33.683546 -84.225701  2016-03-01  2016-09-19
# 2    570251994   30075  34.104636 -84.398276  2016-03-01         NaT
# 3     20877170   30067  33.959711 -84.418946  2016-03-01  2016-07-05
# 4     20919674   30066  34.061751 -84.485969  2016-03-01  2016-05-31
#
#   withdrawn_date expired_date cancelled_date current_status  sale_price  \
# 0            NaT          NaT            NaT           Sale    180000.0
# 1            NaT          NaT            NaT           Sale     49000.0
# 2            NaT   2016-03-07            NaT        Expired         NaN
# 3            NaT          NaT            NaT           Sale    425000.0
# 4            NaT          NaT            NaT           Sale    190000.0
#
#                      geometry  index_right        ct_key
# 0  POINT (-84.68238 34.06327)      15479.0  1.306703e+10
# 1  POINT (-84.22570 33.68355)      16857.0  1.308902e+10
# 2  POINT (-84.39828 34.10464)      16422.0  1.312101e+10
# 3  POINT (-84.41895 33.95971)      15556.0  1.306703e+10
# 4  POINT (-84.48597 34.06175)      15544.0  1.306703e+10

# %%
plt.figure(figsize=(20, 10))
plt.hist([x / 1e6 for x in market_area_listing_dates_ct_df['sale_price'] if pd.notnull(x) and x < 2e6], bins=30)
plt.xlabel('sale price')
plt.ylabel('number of listings')
plt.show()

# %%
market_area_listing_dates_ct_df.isna().sum()
# Out:
# property_id            0
# zipcode                0
# latitude            5315
# longitude           5327
# list_date              0
# sale_date         128790
# withdrawn_date    332018
# expired_date      358485
# cancelled_date    372235
# current_status         0
# sale_price        129095
# geometry               0
# index_right         5603
# ct_key              5603
# dtype: int64

# %%
len(market_area_listing_dates_ct_df)
# Out:
# 372744

# %%
# ignore the listings that aren't matched up with a census tracts
market_area_listing_dates_ct_df = market_area_listing_dates_ct_df[market_area_listing_dates_ct_df['ct_key'].notna()]

# %%
market_area_listing_dates_ct_df.isna().sum()
# Out:
# property_id            0
# zipcode                0
# latitude               0
# longitude              0
# list_date              0
# sale_date         126818
# withdrawn_date    326978
# expired_date      353523
# cancelled_date    366651
# current_status         0
# sale_price        127123
# geometry               0
# index_right            0
# ct_key                 0
# dtype: int64

# %%
final_census_tracts = set(ct_stats_df_cleaned['ct_key'])

# %%
print(len(market_area_listing_dates_ct_df))
market_area_listing_dates_ct_df = market_area_listing_dates_ct_df[
    market_area_listing_dates_ct_df['ct_key'].isin(final_census_tracts)]
print(len(market_area_listing_dates_ct_df))
# Out:
# 367141
# 366514

# %%
market_area_listing_dates_ct_df.to_csv(f'{market_area}_listing_dates_with_ct.csv', index=False)
